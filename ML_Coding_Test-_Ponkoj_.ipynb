# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\cspon\Downloads\ML Coding Test Dataset.csv")
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER   TAX_VALUE MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0  505 398 kr       12 885 kr
# 1       58.435657   8.747802       4203.0  608 500 kr       18 030 kr
# 2       58.246155   7.945707       4223.0  537 010 kr             NaN
# 3       58.149666   7.998533       4204.0  306 175 kr        6 108 kr
# 4       58.171501   7.985000       4204.0  822 362 kr             NaN
# ...           ...        ...          ...         ...             ...
# 166763  59.928799  11.462000       3026.0  829 012 kr       14 832 kr
# 166764  60.253101  11.199300       3035.0  851 750 kr       14 101 kr
# 166765  59.217022  10.960440       3004.0  437 962 kr             NaN
# 166766  59.945599  10.953300       3029.0         NaN             NaN
# 166767  60.068615  11.012928       3032.0         NaN        8 779 kr
#
#        PRIMARY_ROOM_AREA USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  BUILT_YEAR  \
# ...

# %%
df.columns.tolist()
# Out:
# ['LATITUDE',
#  'LONGITUDE',
#  'CITY_NUMBER',
#  'TAX_VALUE',
#  'MUNICIPAL_TAXES',
#  'PRIMARY_ROOM_AREA',
#  'USABLE_FLOOR_SPACE',
#  'GROSS_AREA',
#  'BEDROOMS',
#  'BUILT_YEAR',
#  'ENERGY_LABEL',
#  'TOTAL_PRICE']

# %%
df['TOTAL_PRICE'] = df['TOTAL_PRICE'].str.replace('kr','')
df['TAX_VALUE'] = df['TAX_VALUE'].str.replace('kr','')
df['MUNICIPAL_TAXES'] = df['MUNICIPAL_TAXES'].str.replace('kr','')
df['PRIMARY_ROOM_AREA'] = df['PRIMARY_ROOM_AREA'].str.replace('m²','')
df['USABLE_FLOOR_SPACE'] = df['USABLE_FLOOR_SPACE'].str.replace('m²','')
df['GROSS_AREA'] = df['GROSS_AREA'].str.replace('m²','')
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER TAX_VALUE MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0  505 398          12 885
# 1       58.435657   8.747802       4203.0  608 500          18 030
# 2       58.246155   7.945707       4223.0  537 010              NaN
# 3       58.149666   7.998533       4204.0  306 175           6 108
# 4       58.171501   7.985000       4204.0  822 362              NaN
# ...           ...        ...          ...       ...             ...
# 166763  59.928799  11.462000       3026.0  829 012          14 832
# 166764  60.253101  11.199300       3035.0  851 750          14 101
# 166765  59.217022  10.960440       3004.0  437 962              NaN
# 166766  59.945599  10.953300       3029.0       NaN             NaN
# 166767  60.068615  11.012928       3032.0       NaN          8 779
#
#        PRIMARY_ROOM_AREA USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  BUILT_YEAR  \
# 0                   160                181        193        3.0      1961.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166768 entries, 0 to 166767
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   LATITUDE            166768 non-null  float64
#  1   LONGITUDE           166768 non-null  float64
#  2   CITY_NUMBER         166624 non-null  float64
#  3   TAX_VALUE           136381 non-null  object
#  4   MUNICIPAL_TAXES     93184 non-null   object
#  5   PRIMARY_ROOM_AREA   165095 non-null  object
#  6   USABLE_FLOOR_SPACE  165499 non-null  object
#  7   GROSS_AREA          117358 non-null  object
#  8   BEDROOMS            160814 non-null  float64
#  9   BUILT_YEAR          164584 non-null  float64
#  10  ENERGY_LABEL        127615 non-null  object
#  11  TOTAL_PRICE         166768 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 15.3+ MB

# %%
df['TOTAL_PRICE']=df.TOTAL_PRICE.str.split().str.join("").astype(float)
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER TAX_VALUE MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0  505 398          12 885
# 1       58.435657   8.747802       4203.0  608 500          18 030
# 2       58.246155   7.945707       4223.0  537 010              NaN
# 3       58.149666   7.998533       4204.0  306 175           6 108
# 4       58.171501   7.985000       4204.0  822 362              NaN
# ...           ...        ...          ...       ...             ...
# 166763  59.928799  11.462000       3026.0  829 012          14 832
# 166764  60.253101  11.199300       3035.0  851 750          14 101
# 166765  59.217022  10.960440       3004.0  437 962              NaN
# 166766  59.945599  10.953300       3029.0       NaN             NaN
# 166767  60.068615  11.012928       3032.0       NaN          8 779
#
#        PRIMARY_ROOM_AREA USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  BUILT_YEAR  \
# 0                   160                181        193        3.0      1961.0
# ...

# %%
df['TAX_VALUE']=df.TAX_VALUE.str.split().str.join("").astype(float)
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0   505398.0         12 885
# 1       58.435657   8.747802       4203.0   608500.0         18 030
# 2       58.246155   7.945707       4223.0   537010.0             NaN
# 3       58.149666   7.998533       4204.0   306175.0          6 108
# 4       58.171501   7.985000       4204.0   822362.0             NaN
# ...           ...        ...          ...        ...             ...
# 166763  59.928799  11.462000       3026.0   829012.0         14 832
# 166764  60.253101  11.199300       3035.0   851750.0         14 101
# 166765  59.217022  10.960440       3004.0   437962.0             NaN
# 166766  59.945599  10.953300       3029.0        NaN             NaN
# 166767  60.068615  11.012928       3032.0        NaN          8 779
#
#        PRIMARY_ROOM_AREA USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  BUILT_YEAR  \
# ...

# %%
df['MUNICIPAL_TAXES']=df.MUNICIPAL_TAXES.str.split().str.join("").astype(float)
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0   505398.0          12885.0
# 1       58.435657   8.747802       4203.0   608500.0          18030.0
# 2       58.246155   7.945707       4223.0   537010.0              NaN
# 3       58.149666   7.998533       4204.0   306175.0           6108.0
# 4       58.171501   7.985000       4204.0   822362.0              NaN
# ...           ...        ...          ...        ...              ...
# 166763  59.928799  11.462000       3026.0   829012.0          14832.0
# 166764  60.253101  11.199300       3035.0   851750.0          14101.0
# 166765  59.217022  10.960440       3004.0   437962.0              NaN
# 166766  59.945599  10.953300       3029.0        NaN              NaN
# 166767  60.068615  11.012928       3032.0        NaN           8779.0
#
#        PRIMARY_ROOM_AREA USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  BUILT_YEAR  \
# ...

# %%
df['PRIMARY_ROOM_AREA']=df['PRIMARY_ROOM_AREA'].astype(float)
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0   505398.0          12885.0
# 1       58.435657   8.747802       4203.0   608500.0          18030.0
# 2       58.246155   7.945707       4223.0   537010.0              NaN
# 3       58.149666   7.998533       4204.0   306175.0           6108.0
# 4       58.171501   7.985000       4204.0   822362.0              NaN
# ...           ...        ...          ...        ...              ...
# 166763  59.928799  11.462000       3026.0   829012.0          14832.0
# 166764  60.253101  11.199300       3035.0   851750.0          14101.0
# 166765  59.217022  10.960440       3004.0   437962.0              NaN
# 166766  59.945599  10.953300       3029.0        NaN              NaN
# 166767  60.068615  11.012928       3032.0        NaN           8779.0
#
#         PRIMARY_ROOM_AREA USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  BUILT_YEAR  \
# ...

# %%
df['USABLE_FLOOR_SPACE']=df['USABLE_FLOOR_SPACE'].astype(float)
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0   505398.0          12885.0
# 1       58.435657   8.747802       4203.0   608500.0          18030.0
# 2       58.246155   7.945707       4223.0   537010.0              NaN
# 3       58.149666   7.998533       4204.0   306175.0           6108.0
# 4       58.171501   7.985000       4204.0   822362.0              NaN
# ...           ...        ...          ...        ...              ...
# 166763  59.928799  11.462000       3026.0   829012.0          14832.0
# 166764  60.253101  11.199300       3035.0   851750.0          14101.0
# 166765  59.217022  10.960440       3004.0   437962.0              NaN
# 166766  59.945599  10.953300       3029.0        NaN              NaN
# 166767  60.068615  11.012928       3032.0        NaN           8779.0
#
#         PRIMARY_ROOM_AREA  USABLE_FLOOR_SPACE GROSS_AREA  BEDROOMS  \
# ...

# %%
df['GROSS_AREA']=df['GROSS_AREA'].astype(float)
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0   505398.0          12885.0
# 1       58.435657   8.747802       4203.0   608500.0          18030.0
# 2       58.246155   7.945707       4223.0   537010.0              NaN
# 3       58.149666   7.998533       4204.0   306175.0           6108.0
# 4       58.171501   7.985000       4204.0   822362.0              NaN
# ...           ...        ...          ...        ...              ...
# 166763  59.928799  11.462000       3026.0   829012.0          14832.0
# 166764  60.253101  11.199300       3035.0   851750.0          14101.0
# 166765  59.217022  10.960440       3004.0   437962.0              NaN
# 166766  59.945599  10.953300       3029.0        NaN              NaN
# 166767  60.068615  11.012928       3032.0        NaN           8779.0
#
#         PRIMARY_ROOM_AREA  USABLE_FLOOR_SPACE  GROSS_AREA  BEDROOMS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166768 entries, 0 to 166767
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   LATITUDE            166768 non-null  float64
#  1   LONGITUDE           166768 non-null  float64
#  2   CITY_NUMBER         166624 non-null  float64
#  3   TAX_VALUE           136381 non-null  float64
#  4   MUNICIPAL_TAXES     93184 non-null   float64
#  5   PRIMARY_ROOM_AREA   165095 non-null  float64
#  6   USABLE_FLOOR_SPACE  165499 non-null  float64
#  7   GROSS_AREA          117358 non-null  float64
#  8   BEDROOMS            160814 non-null  float64
#  9   BUILT_YEAR          164584 non-null  float64
#  10  ENERGY_LABEL        127615 non-null  object
#  11  TOTAL_PRICE         166768 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 15.3+ MB

# %%
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  \
# 0       58.297768   7.834061       4223.0   505398.0          12885.0
# 1       58.435657   8.747802       4203.0   608500.0          18030.0
# 2       58.246155   7.945707       4223.0   537010.0              NaN
# 3       58.149666   7.998533       4204.0   306175.0           6108.0
# 4       58.171501   7.985000       4204.0   822362.0              NaN
# ...           ...        ...          ...        ...              ...
# 166763  59.928799  11.462000       3026.0   829012.0          14832.0
# 166764  60.253101  11.199300       3035.0   851750.0          14101.0
# 166765  59.217022  10.960440       3004.0   437962.0              NaN
# 166766  59.945599  10.953300       3029.0        NaN              NaN
# 166767  60.068615  11.012928       3032.0        NaN           8779.0
#
#         PRIMARY_ROOM_AREA  USABLE_FLOOR_SPACE  GROSS_AREA  BEDROOMS  \
# ...

# %%
df.isnull().sum()
# Out:
# LATITUDE                  0
# LONGITUDE                 0
# CITY_NUMBER             144
# TAX_VALUE             30387
# MUNICIPAL_TAXES       73584
# PRIMARY_ROOM_AREA      1673
# USABLE_FLOOR_SPACE     1269
# GROSS_AREA            49410
# BEDROOMS               5954
# BUILT_YEAR             2184
# ENERGY_LABEL          39153
# TOTAL_PRICE               0
# dtype: int64

# %%
df= df.dropna()

# %%
df
# Out:
#          LATITUDE  LONGITUDE  CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  \
# 1       58.435657   8.747802       4203.0   608500.0          18030.0
# 3       58.149666   7.998533       4204.0   306175.0           6108.0
# 10      58.147900   7.993700       4204.0   714467.0           7934.0
# 12      58.652817   8.940897       4213.0   523465.0          18814.0
# 13      58.121178   7.940788       4204.0   948258.0          13914.0
# ...           ...        ...          ...        ...              ...
# 166757  59.749199  10.015300       3005.0   415116.0           2990.0
# 166760  59.749298  10.400700       3025.0   619515.0           8525.0
# 166761  59.285698  11.114003       3003.0   673720.0           9374.0
# 166762  59.976364  11.243559       3030.0   881083.0          16230.0
# 166764  60.253101  11.199300       3035.0   851750.0          14101.0
#
#         PRIMARY_ROOM_AREA  USABLE_FLOOR_SPACE  GROSS_AREA  BEDROOMS  \
# ...

# %%
df.describe().T
# Out:
#                       count          mean           std       min  \
# LATITUDE            49123.0  6.171523e+01  3.583931e+00       0.0
# LONGITUDE           49123.0  1.016152e+01  4.846398e+00       0.0
# CITY_NUMBER         49123.0  3.311048e+03  1.503949e+03     301.0
# TAX_VALUE           49123.0  8.225208e+05  5.450698e+05       0.0
# MUNICIPAL_TAXES     49123.0  1.326820e+04  8.330983e+03       0.0
# PRIMARY_ROOM_AREA   49123.0  1.354754e+02  6.692844e+01      20.0
# USABLE_FLOOR_SPACE  49123.0  1.574857e+02  8.829135e+01      20.0
# GROSS_AREA          49123.0  1.734305e+02  9.587102e+01       3.0
# BEDROOMS            49123.0  3.191438e+00  1.369143e+00       0.0
# BUILT_YEAR          49123.0  1.976526e+03  3.611058e+01    1650.0
# TOTAL_PRICE         49123.0  4.087313e+06  3.686187e+06  298622.0
#
#                              25%           50%           75%           max
# LATITUDE            5.918006e+01  6.030880e+01  6.314500e+01  7.099513e+01
# ...

# %%
df.shape
# Out:
# (49123, 12)

# %%
corrmat = df.corr()
cmap = sns.diverging_palette(260,-10,s=50, l=75, n=6, as_cmap=True)
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
# Out:
# <AxesSubplot:>

# %%
df=df.drop(['LATITUDE', 'LONGITUDE'], axis=1)
df
# Out:
#         CITY_NUMBER  TAX_VALUE  MUNICIPAL_TAXES  PRIMARY_ROOM_AREA  \
# 1            4203.0   608500.0          18030.0              132.0
# 3            4204.0   306175.0           6108.0               32.0
# 10           4204.0   714467.0           7934.0               73.0
# 12           4213.0   523465.0          18814.0              165.0
# 13           4204.0   948258.0          13914.0              172.0
# ...             ...        ...              ...                ...
# 166757       3005.0   415116.0           2990.0               45.0
# 166760       3025.0   619515.0           8525.0               70.0
# 166761       3003.0   673720.0           9374.0               98.0
# 166762       3030.0   881083.0          16230.0               91.0
# 166764       3035.0   851750.0          14101.0              165.0
#
#         USABLE_FLOOR_SPACE  GROSS_AREA  BEDROOMS  BUILT_YEAR ENERGY_LABEL  \
# 1                    159.0       176.0       3.0      1964.0            F
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49123 entries, 1 to 166764
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CITY_NUMBER         49123 non-null  float64
#  1   TAX_VALUE           49123 non-null  float64
#  2   MUNICIPAL_TAXES     49123 non-null  float64
#  3   PRIMARY_ROOM_AREA   49123 non-null  float64
#  4   USABLE_FLOOR_SPACE  49123 non-null  float64
#  5   GROSS_AREA          49123 non-null  float64
#  6   BEDROOMS            49123 non-null  float64
#  7   BUILT_YEAR          49123 non-null  float64
#  8   ENERGY_LABEL        49123 non-null  object
#  9   TOTAL_PRICE         49123 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 4.1+ MB

# %%
categorical_cols = ['CITY_NUMBER', 'ENERGY_LABEL'] 
df = pd.get_dummies(df, columns = categorical_cols)

# %%
df
# Out:
#         TAX_VALUE  MUNICIPAL_TAXES  PRIMARY_ROOM_AREA  USABLE_FLOOR_SPACE  \
# 1        608500.0          18030.0              132.0               159.0
# 3        306175.0           6108.0               32.0                32.0
# 10       714467.0           7934.0               73.0                73.0
# 12       523465.0          18814.0              165.0               182.0
# 13       948258.0          13914.0              172.0               172.0
# ...           ...              ...                ...                 ...
# 166757   415116.0           2990.0               45.0                45.0
# 166760   619515.0           8525.0               70.0                70.0
# 166761   673720.0           9374.0               98.0                98.0
# 166762   881083.0          16230.0               91.0               102.0
# 166764   851750.0          14101.0              165.0               232.0
#
#         GROSS_AREA  BEDROOMS  BUILT_YEAR  TOTAL_PRICE  CITY_NUMBER_301.0  \
# ...

# %%
y=df['TOTAL_PRICE']
X= df.drop(['TOTAL_PRICE'],axis=1)

# %%
from sklearn.model_selection import train_test_split     #data splitting
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=20)

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
scaler.fit(X_train)  
X_train = scaler.transform(X_train)  
# apply same transformation to test data
X_test = scaler.transform(X_test)

# %%
from numpy import sqrt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
n_features = X_train.shape[1]
print(n_features)
# Out:
# 336

# %%
# define model
model = Sequential()
model.add(Dense(1000, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dense(250, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(100, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(75, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(50, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(20, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation = 'relu'))

# %%
# compile the model
model.compile(optimizer='Adamax', loss='mse')

# %%
# fit the model
model.fit(X_train, y_train, epochs=1000, batch_size=250, verbose=2)
# Out:
# Epoch 1/1000
# 158/158 - 2s - loss: 29184441188352.0000
# Epoch 2/1000
# 158/158 - 1s - loss: 12815753543680.0000
# Epoch 3/1000
# 158/158 - 1s - loss: 5697892777984.0000
# Epoch 4/1000
# 158/158 - 1s - loss: 4538632765440.0000
# Epoch 5/1000
# 158/158 - 1s - loss: 3942176784384.0000
# Epoch 6/1000
# 158/158 - 1s - loss: 3608385421312.0000
# Epoch 7/1000
# 158/158 - 1s - loss: 3390491328512.0000
# Epoch 8/1000
# 158/158 - 1s - loss: 3238170722304.0000
# Epoch 9/1000
# 158/158 - 1s - loss: 3112204238848.0000
# Epoch 10/1000
# 158/158 - 1s - loss: 3014786285568.0000
# Epoch 11/1000
# 158/158 - 1s - loss: 2918093946880.0000
# Epoch 12/1000
# 158/158 - 1s - loss: 2832435773440.0000
# Epoch 13/1000
# 158/158 - 1s - loss: 2761218850816.0000
# Epoch 14/1000
# 158/158 - 1s - loss: 2695631732736.0000
# Epoch 15/1000
# 158/158 - 1s - loss: 2632959655936.0000
# Epoch 16/1000
# 158/158 - 1s - loss: 2588221374464.0000
# Epoch 17/1000
# 158/158 - 1s - loss: 2540096454656.0000
# Epoch 18/1000
# ...

# %%
# evaluate the model
error = model.evaluate(X_test, y_test, verbose=0)
print('MSE: %.3f, RMSE: %.3f' % (error, sqrt(error)))
# Out:
# MSE: 1849499451392.000, RMSE: 1359963.033
