# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# A time series is a sequence of observations taken sequentially in time.
# Components of Time Series
#
# Time series analysis provides a body of techniques to better understand a dataset.
#
# Perhaps the most useful of these is the decomposition of a time series into 4 constituent parts:
#
#     Level: The baseline value for the series if it were a straight line.
#     Trend: The optional and often linear increasing or decreasing behavior of the series over time.
#     Seasonality: The optional repeating patterns or cycles of behavior over time.
#     Noise: The optional variability in the observations that cannot be explained by the model.
#
# Time series data often requires cleaning, scaling, and even transformation.

# %% [markdown]
# # Time Series Forecasting as Supervised Learning

# %% [markdown]
# Supervised Machine Learning:
# Sliding Window For Time Series Data

# %%
# time, measure
# 1, 100
# 2, 110
# 3, 108
# 4, 115
# 5, 120

# X, y
# ?, 100
# 100, 110
# 110, 108
# 108, 115
# 115, 120
# 120, ?

# %% [markdown]
# Sliding Window With Multivariate Time Series Data:

# %%
# time, measure1, measure2
# 1, 0.2, 88
# 2, 0.5, 89
# 3, 0.7, 87
# 4, 0.4, 88
# 5, 1.0, 90

# X1, X2, X3, y
# ?, ?, 0.2 , 88
# 0.2, 88, 0.5, 89
# 0.5, 89, 0.7, 87
# 0.7, 87, 0.4, 88
# 0.4, 88, 1.0, 90
# 1.0, 90, ?, ?

# X1, X2, X3, y
# ?, ?, 0.2 , 88
# 0.2, 88, 0.5, 89
# 0.5, 89, 0.7, 87
# 0.7, 87, 0.4, 88
# 0.4, 88, 1.0, 90
# 1.0, 90, ?, ?

# %% [markdown]
# Sliding Window With Multi-Step Forecasting

# %%
# time, measure
# 1, 100
# 2, 110
# 3, 108
# 4, 115
# 5, 120

# X1, y1, y2
# ? 100, 110
# 100, 110, 108
# 110, 108, 115
# 108, 115, 120
# 115, 120, ?
# 120, ?, ?

# %% [markdown]
# ## How to Load and Explore Time Series Data in Python:

# %% [markdown]
# loading data:

# %%
# Load birth data using read_csv
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('dataset.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(type(series))
print(series.head())
# Out:
# <class 'pandas.core.series.Series'>
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: Births, dtype: int64

# %% [markdown]
# Exploring Time Series Data:

# %%
print(series.head(10))
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# Name: Births, dtype: int64

# %%
# Number of Observations
print(series.size)
# Out:
# 365

# %%
# Querying By Time
print(series['1959-01'])
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: Births, dtype: int64

# %%
# Descriptive Statistics:
print(series.describe())
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: Births, dtype: float64

# %%
# plotting time series:
pyplot.plot(series)
pyplot.show()

# %% [markdown]
# ### How to Normalize and Standardize Time Series Data in Python

# %%
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
# load the dataset and print the first 5 rows
series = read_csv('temperature_dataset.csv', header=0, index_col=0)
print(series.head())
# prepare data for normalization
values = series.values
values = values.reshape((len(values), 1))
# train the normalization
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))
# normalize the dataset and print the first 5 rows
normalized = scaler.transform(values)
for i in range(5):
	print(normalized[i])
# inverse transform and print the first 5 rows
inversed = scaler.inverse_transform(normalized)
for i in range(5):
	print(inversed[i])
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# Min: 0.000000, Max: 26.300000
# [0.78707224]
# [0.68060837]
# [0.7148289]
# [0.55513308]
# [0.60076046]
# [20.7]
# [17.9]
# [18.8]
# [14.6]
# [15.8]

# %%
series.hist()
pyplot.show()

# %%
# Standardize time series data
from pandas import read_csv
from sklearn.preprocessing import StandardScaler
from math import sqrt
# load the dataset and print the first 5 rows
series = read_csv('dataset.csv', header=0, index_col=0)
print(series.head())
# prepare data for standardization
values = series.values
values = values.reshape((len(values), 1))
# train the standardization
scaler = StandardScaler()
scaler = scaler.fit(values)
print('Mean: %f, StandardDeviation: %f' % (scaler.mean_, sqrt(scaler.var_)))
# standardization the dataset and print the first 5 rows
normalized = scaler.transform(values)
for i in range(5):
	print(normalized[i])
# inverse transform and print the first 5 rows
inversed = scaler.inverse_transform(normalized)
for i in range(5):
	print(inversed[i])
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# Mean: 41.980822, StandardDeviation: 7.338184
# [-0.95130099]
# [-1.36012148]
# [-1.63266846]
# [-1.49639497]
# [0.27516045]
# [35.]
# [32.]
# [30.]
# [31.]
# [44.]

# %% [markdown]
# ### Basic Feature Engineering With Time Series Data in Python

# %% [markdown]
# Feature Engineering for Time Series

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
print(dataframe.head(5))
# Out:
#    month  day  temperature
# 0      1    1         20.7
# 1      1    2         17.9
# 2      1    3         18.8
# 3      1    4         14.6
# 4      1    5         15.8

# %% [markdown]
# Lag Features:

# %%
temps = DataFrame(series.values)
dataframe = concat([temps.shift(1), temps], axis=1)
dataframe.columns = ['t-1', 't+1']
print(dataframe.head(5))
# Out:
#     t-1   t+1
# 0   NaN  20.7
# 1  20.7  17.9
# 2  17.9  18.8
# 3  18.8  14.6
# 4  14.6  15.8

# %%
temps = DataFrame(series.values)
dataframe = concat([temps.shift(3), temps.shift(2), temps.shift(1), temps], axis=1)
dataframe.columns = ['t-3', 't-2', 't-1', 't+1']
print(dataframe.head(5))
# Out:
#     t-3   t-2   t-1   t+1
# 0   NaN   NaN   NaN  20.7
# 1   NaN   NaN  20.7  17.9
# 2   NaN  20.7  17.9  18.8
# 3  20.7  17.9  18.8  14.6
# 4  17.9  18.8  14.6  15.8

# %%
temps = DataFrame(series.values)
shifted = temps.shift(1)
window = shifted.rolling(window=2)
means = window.mean()
dataframe = concat([means, temps], axis=1)
dataframe.columns = ['mean(t-2,t-1)', 't+1']
print(dataframe.head(5))
# Out:
#    mean(t-2,t-1)   t+1
# 0            NaN  20.7
# 1            NaN  17.9
# 2          19.30  18.8
# 3          18.35  14.6
# 4          16.70  15.8

# %%
temps = DataFrame(series.values)
width = 3
shifted = temps.shift(width - 1)
window = shifted.rolling(window=width)
dataframe = concat([window.min(), window.mean(), window.max(), temps], axis=1)
dataframe.columns = ['min', 'mean', 'max', 't+1']
print(dataframe.head(5))
# Out:
#     min       mean   max   t+1
# 0   NaN        NaN   NaN  20.7
# 1   NaN        NaN   NaN  17.9
# 2   NaN        NaN   NaN  18.8
# 3   NaN        NaN   NaN  14.6
# 4  17.9  19.133333  20.7  15.8

# %% [markdown]
# Expanding Window Statistics

# %%
temps = DataFrame(series.values)
window = temps.expanding()
dataframe = concat([window.min(), window.mean(), window.max(), temps.shift(-1)], axis=1)
dataframe.columns = ['min', 'mean', 'max', 't+1']
print(dataframe.head(5))
# Out:
#     min       mean   max   t+1
# 0  20.7  20.700000  20.7  17.9
# 1  17.9  19.300000  20.7  18.8
# 2  17.9  19.133333  20.7  14.6
# 3  14.6  18.000000  20.7  15.8
# 4  14.6  17.560000  20.7  15.8

# %% [markdown]
# ### How To Resample and Interpolate Your Time Series Data With Python

# %% [markdown]
# Load the Shampoo Sales Dataset

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
# <ipython-input-15-b22d4efe88dd>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64

# %%
upsampled = series.resample('D')
print(upsampledp.head(32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6b666b86990a> in <module>
#       1 upsampled = series.resample('D')
# ----> 2 print(upsampledp.head(32))
#
# NameError: name 'upsampledp' is not defined

# %%
upsampled = series.resample('D')
interpolated = upsampled.interpolate(method='linear')
print(interpolated.head(32))
# Out:
# Month
# 1901-01-01    266.000000
# 1901-01-02    262.125806
# 1901-01-03    258.251613
# 1901-01-04    254.377419
# 1901-01-05    250.503226
# 1901-01-06    246.629032
# 1901-01-07    242.754839
# 1901-01-08    238.880645
# 1901-01-09    235.006452
# 1901-01-10    231.132258
# 1901-01-11    227.258065
# 1901-01-12    223.383871
# 1901-01-13    219.509677
# 1901-01-14    215.635484
# 1901-01-15    211.761290
# 1901-01-16    207.887097
# 1901-01-17    204.012903
# 1901-01-18    200.138710
# 1901-01-19    196.264516
# 1901-01-20    192.390323
# 1901-01-21    188.516129
# 1901-01-22    184.641935
# 1901-01-23    180.767742
# 1901-01-24    176.893548
# 1901-01-25    173.019355
# 1901-01-26    169.145161
# 1901-01-27    165.270968
# 1901-01-28    161.396774
# 1901-01-29    157.522581
# 1901-01-30    153.648387
# 1901-01-31    149.774194
# 1901-02-01    145.900000
# Freq: D, Name: Sales, dtype: float64

# %%
upsampled = series.resample('D')
interpolated = upsampled.interpolate(method='spline', order=2)
print(interpolated.head(32))
interpolated.plot()
pyplot.show()
# Out:
# Month
# 1901-01-01    266.000000
# 1901-01-02    258.630160
# 1901-01-03    251.560886
# 1901-01-04    244.720748
# 1901-01-05    238.109746
# 1901-01-06    231.727880
# 1901-01-07    225.575149
# 1901-01-08    219.651553
# 1901-01-09    213.957094
# 1901-01-10    208.491770
# 1901-01-11    203.255582
# 1901-01-12    198.248529
# 1901-01-13    193.470612
# 1901-01-14    188.921831
# 1901-01-15    184.602185
# 1901-01-16    180.511676
# 1901-01-17    176.650301
# 1901-01-18    173.018063
# 1901-01-19    169.614960
# 1901-01-20    166.440993
# 1901-01-21    163.496161
# 1901-01-22    160.780465
# 1901-01-23    158.293905
# 1901-01-24    156.036481
# 1901-01-25    154.008192
# 1901-01-26    152.209039
# 1901-01-27    150.639021
# 1901-01-28    149.298139
# 1901-01-29    148.186393
# 1901-01-30    147.303783
# 1901-01-31    146.650308
# 1901-02-01    145.900000
# Freq: D, Name: Sales, dtype: float64

# %%
resample = series.resample('Q')
quarterly_mean_sales = resample.mean()
print(quarterly_mean_sales.head())
quarterly_mean_sales.plot()
pyplot.show()
# Out:
# Month
# 1901-03-31    198.333333
# 1901-06-30    156.033333
# 1901-09-30    216.366667
# 1901-12-31    215.100000
# 1902-03-31    184.633333
# Freq: Q-DEC, Name: Sales, dtype: float64

# %%
resample = series.resample('A')
quarterly_mean_sales = resample.sum()
print(quarterly_mean_sales.head())
quarterly_mean_sales.plot()
pyplot.show()
# Out:
# Month
# 1901-12-31    2357.5
# 1902-12-31    3153.5
# 1903-12-31    5742.6
# Freq: A-DEC, Name: Sales, dtype: float64

# %% [markdown]
# ### How To Backtest Machine Learning Models for Time Series Forecasting

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('monthly-sunspots.csv', header=0, index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#          Sunspots
# Month
# 1749-01      58.0
# 1749-02      62.6
# 1749-03      70.0
# 1749-04      55.7
# 1749-05      85.0

# %%
X = series.values
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]
print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 2820
# Training Observations: 1861
# Testing Observations: 959

# %%
pyplot.plot(train)
pyplot.plot([None for i in train] + [x for x in test])
pyplot.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Multiple Train-Test Splits

# %%
from sklearn.model_selection import TimeSeriesSplit
from matplotlib import pyplot
series = read_csv('monthly-sunspots.csv', header=0, index_col=0)
X = series.values
splits = TimeSeriesSplit(n_splits=3)
pyplot.figure(1)
index = 1
for train_index, test_index in splits.split(X):
	train = X[train_index]
	test = X[test_index]
	print('Observations: %d' % (len(train) + len(test)))
	print('Training Observations: %d' % (len(train)))
	print('Testing Observations: %d' % (len(test)))
	pyplot.subplot(310 + index)
	pyplot.plot(train)
	pyplot.plot([None for i in train] + [x for x in test])
	index += 1
pyplot.show()
# Out:
# Observations: 1410
# Training Observations: 705
# Testing Observations: 705
# Observations: 2115
# Training Observations: 1410
# Testing Observations: 705
# Observations: 2820
# Training Observations: 2115
# Testing Observations: 705
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Walk Forward Validation

# %%
X = series.values
n_train = 500
n_records = len(X)
for i in range(n_train, n_records):
	train, test = X[0:i], X[i:i+1]
	print('train=%d, test=%d' % (len(train), len(test)))
# Out:
# train=500, test=1
# train=501, test=1
# train=502, test=1
# train=503, test=1
# train=504, test=1
# train=505, test=1
# train=506, test=1
# train=507, test=1
# train=508, test=1
# train=509, test=1
# train=510, test=1
# train=511, test=1
# train=512, test=1
# train=513, test=1
# train=514, test=1
# train=515, test=1
# train=516, test=1
# train=517, test=1
# train=518, test=1
# train=519, test=1
# train=520, test=1
# train=521, test=1
# train=522, test=1
# train=523, test=1
# train=524, test=1
# train=525, test=1
# train=526, test=1
# train=527, test=1
# train=528, test=1
# train=529, test=1
# train=530, test=1
# train=531, test=1
# train=532, test=1
# train=533, test=1
# train=534, test=1
# train=535, test=1
# train=536, test=1
# train=537, test=1
# train=538, test=1
# train=539, test=1
# train=540, test=1
# train=541, test=1
# train=542, test=1
# train=543, test=1
# train=544, test=1
# train=545, test=1
# train=546, test=1
# train=547, test=1
# train=548, test=1
# train=549, test=1
# train=550, test=1
# train=551, test=1
# train=552, test=1
# train=553, test=1
# train=554, test=1
# train=555, test=1
# train=556, test=1
# train=557, test=1
# train=558, test=1
# train=559, test=1
# train=560, test=1
# train=561, test=1
# train=562, test=1
# train=563, test=1
# train=564, test=1
# train=565, test=1
# train=566, test=1
# train=567, test=1
# train=568, test=1
# train=569, test=1
# train=570, test=1
# train=571, test=1
# train=572, test=1
# train=573, test=1
# train=574, test=1
# train=575, test=1
# train=576, test=1
# train=577, test=1
# train=578, test=1
# train=579, test=1
# train=580, test=1
# train=581, test=1
# train=582, test=1
# train=583, test=1
# train=584, test=1
# train=585, test=1
# train=586, test=1
# train=587, test=1
# train=588, test=1
# train=589, test=1
# train=590, test=1
# train=591, test=1
# train=592, test=1
# train=593, test=1
# train=594, test=1
# train=595, test=1
# train=596, test=1
# train=597, test=1
# train=598, test=1
# train=599, test=1
# train=600, test=1
# train=601, test=1
# train=602, test=1
# train=603, test=1
# train=604, test=1
# train=605, test=1
# train=606, test=1
# train=607, test=1
# train=608, test=1
# train=609, test=1
# train=610, test=1
# train=611, test=1
# train=612, test=1
# train=613, test=1
# train=614, test=1
# train=615, test=1
# train=616, test=1
# train=617, test=1
# train=618, test=1
# train=619, test=1
# train=620, test=1
# train=621, test=1
# train=622, test=1
# train=623, test=1
# train=624, test=1
# train=625, test=1
# train=626, test=1
# train=627, test=1
# train=628, test=1
# train=629, test=1
# train=630, test=1
# train=631, test=1
# train=632, test=1
# train=633, test=1
# train=634, test=1
# train=635, test=1
# train=636, test=1
# train=637, test=1
# train=638, test=1
# train=639, test=1
# train=640, test=1
# train=641, test=1
# train=642, test=1
# train=643, test=1
# train=644, test=1
# train=645, test=1
# train=646, test=1
# train=647, test=1
# train=648, test=1
# train=649, test=1
# train=650, test=1
# train=651, test=1
# train=652, test=1
# train=653, test=1
# train=654, test=1
# train=655, test=1
# train=656, test=1
# train=657, test=1
# train=658, test=1
# train=659, test=1
# train=660, test=1
# train=661, test=1
# train=662, test=1
# train=663, test=1
# train=664, test=1
# train=665, test=1
# train=666, test=1
# train=667, test=1
# train=668, test=1
# train=669, test=1
# train=670, test=1
# train=671, test=1
# train=672, test=1
# train=673, test=1
# train=674, test=1
# train=675, test=1
# train=676, test=1
# train=677, test=1
# train=678, test=1
# train=679, test=1
# train=680, test=1
# train=681, test=1
# train=682, test=1
# train=683, test=1
# train=684, test=1
# train=685, test=1
# train=686, test=1
# train=687, test=1
# train=688, test=1
# train=689, test=1
# train=690, test=1
# train=691, test=1
# train=692, test=1
# train=693, test=1
# train=694, test=1
# train=695, test=1
# train=696, test=1
# train=697, test=1
# train=698, test=1
# train=699, test=1
# train=700, test=1
# train=701, test=1
# train=702, test=1
# train=703, test=1
# train=704, test=1
# train=705, test=1
# train=706, test=1
# train=707, test=1
# train=708, test=1
# train=709, test=1
# train=710, test=1
# train=711, test=1
# train=712, test=1
# train=713, test=1
# train=714, test=1
# train=715, test=1
# train=716, test=1
# train=717, test=1
# train=718, test=1
# train=719, test=1
# train=720, test=1
# train=721, test=1
# train=722, test=1
# train=723, test=1
# train=724, test=1
# train=725, test=1
# train=726, test=1
# train=727, test=1
# train=728, test=1
# train=729, test=1
# train=730, test=1
# train=731, test=1
# train=732, test=1
# train=733, test=1
# train=734, test=1
# train=735, test=1
# train=736, test=1
# train=737, test=1
# train=738, test=1
# train=739, test=1
# train=740, test=1
# train=741, test=1
# train=742, test=1
# train=743, test=1
# train=744, test=1
# train=745, test=1
# train=746, test=1
# train=747, test=1
# train=748, test=1
# train=749, test=1
# train=750, test=1
# train=751, test=1
# train=752, test=1
# train=753, test=1
# train=754, test=1
# train=755, test=1
# train=756, test=1
# train=757, test=1
# train=758, test=1
# train=759, test=1
# train=760, test=1
# train=761, test=1
# train=762, test=1
# train=763, test=1
# train=764, test=1
# train=765, test=1
# train=766, test=1
# train=767, test=1
# train=768, test=1
# train=769, test=1
# train=770, test=1
# train=771, test=1
# train=772, test=1
# train=773, test=1
# train=774, test=1
# train=775, test=1
# train=776, test=1
# train=777, test=1
# train=778, test=1
# train=779, test=1
# train=780, test=1
# train=781, test=1
# train=782, test=1
# train=783, test=1
# train=784, test=1
# train=785, test=1
# train=786, test=1
# train=787, test=1
# train=788, test=1
# train=789, test=1
# train=790, test=1
# train=791, test=1
# train=792, test=1
# train=793, test=1
# train=794, test=1
# train=795, test=1
# train=796, test=1
# train=797, test=1
# train=798, test=1
# train=799, test=1
# train=800, test=1
# train=801, test=1
# train=802, test=1
# train=803, test=1
# train=804, test=1
# train=805, test=1
# train=806, test=1
# train=807, test=1
# train=808, test=1
# train=809, test=1
# train=810, test=1
# train=811, test=1
# train=812, test=1
# train=813, test=1
# train=814, test=1
# train=815, test=1
# train=816, test=1
# train=817, test=1
# train=818, test=1
# train=819, test=1
# train=820, test=1
# train=821, test=1
# train=822, test=1
# train=823, test=1
# train=824, test=1
# train=825, test=1
# train=826, test=1
# train=827, test=1
# train=828, test=1
# train=829, test=1
# train=830, test=1
# train=831, test=1
# train=832, test=1
# train=833, test=1
# train=834, test=1
# train=835, test=1
# train=836, test=1
# train=837, test=1
# train=838, test=1
# train=839, test=1
# train=840, test=1
# train=841, test=1
# train=842, test=1
# train=843, test=1
# train=844, test=1
# train=845, test=1
# train=846, test=1
# train=847, test=1
# train=848, test=1
# train=849, test=1
# train=850, test=1
# train=851, test=1
# train=852, test=1
# train=853, test=1
# train=854, test=1
# train=855, test=1
# train=856, test=1
# train=857, test=1
# train=858, test=1
# train=859, test=1
# train=860, test=1
# train=861, test=1
# train=862, test=1
# train=863, test=1
# train=864, test=1
# train=865, test=1
# train=866, test=1
# train=867, test=1
# train=868, test=1
# train=869, test=1
# train=870, test=1
# train=871, test=1
# train=872, test=1
# train=873, test=1
# train=874, test=1
# train=875, test=1
# train=876, test=1
# train=877, test=1
# train=878, test=1
# train=879, test=1
# train=880, test=1
# train=881, test=1
# train=882, test=1
# train=883, test=1
# train=884, test=1
# train=885, test=1
# train=886, test=1
# train=887, test=1
# train=888, test=1
# train=889, test=1
# train=890, test=1
# train=891, test=1
# train=892, test=1
# train=893, test=1
# train=894, test=1
# train=895, test=1
# train=896, test=1
# train=897, test=1
# train=898, test=1
# train=899, test=1
# train=900, test=1
# train=901, test=1
# train=902, test=1
# train=903, test=1
# train=904, test=1
# train=905, test=1
# train=906, test=1
# train=907, test=1
# train=908, test=1
# train=909, test=1
# train=910, test=1
# train=911, test=1
# train=912, test=1
# train=913, test=1
# train=914, test=1
# train=915, test=1
# train=916, test=1
# train=917, test=1
# train=918, test=1
# train=919, test=1
# train=920, test=1
# train=921, test=1
# train=922, test=1
# train=923, test=1
# train=924, test=1
# train=925, test=1
# train=926, test=1
# train=927, test=1
# train=928, test=1
# train=929, test=1
# train=930, test=1
# train=931, test=1
# train=932, test=1
# train=933, test=1
# train=934, test=1
# train=935, test=1
# train=936, test=1
# train=937, test=1
# train=938, test=1
# train=939, test=1
# train=940, test=1
# train=941, test=1
# train=942, test=1
# train=943, test=1
# train=944, test=1
# train=945, test=1
# train=946, test=1
# train=947, test=1
# train=948, test=1
# train=949, test=1
# train=950, test=1
# train=951, test=1
# train=952, test=1
# train=953, test=1
# train=954, test=1
# train=955, test=1
# train=956, test=1
# train=957, test=1
# train=958, test=1
# train=959, test=1
# train=960, test=1
# train=961, test=1
# train=962, test=1
# train=963, test=1
# train=964, test=1
# train=965, test=1
# train=966, test=1
# train=967, test=1
# train=968, test=1
# train=969, test=1
# train=970, test=1
# train=971, test=1
# train=972, test=1
# train=973, test=1
# train=974, test=1
# train=975, test=1
# train=976, test=1
# train=977, test=1
# train=978, test=1
# train=979, test=1
# train=980, test=1
# train=981, test=1
# train=982, test=1
# train=983, test=1
# train=984, test=1
# train=985, test=1
# train=986, test=1
# train=987, test=1
# train=988, test=1
# train=989, test=1
# train=990, test=1
# train=991, test=1
# train=992, test=1
# train=993, test=1
# train=994, test=1
# train=995, test=1
# train=996, test=1
# train=997, test=1
# train=998, test=1
# train=999, test=1
# train=1000, test=1
# train=1001, test=1
# train=1002, test=1
# train=1003, test=1
# train=1004, test=1
# train=1005, test=1
# train=1006, test=1
# train=1007, test=1
# train=1008, test=1
# train=1009, test=1
# train=1010, test=1
# train=1011, test=1
# train=1012, test=1
# train=1013, test=1
# train=1014, test=1
# train=1015, test=1
# train=1016, test=1
# train=1017, test=1
# train=1018, test=1
# train=1019, test=1
# train=1020, test=1
# train=1021, test=1
# train=1022, test=1
# train=1023, test=1
# train=1024, test=1
# train=1025, test=1
# train=1026, test=1
# train=1027, test=1
# train=1028, test=1
# train=1029, test=1
# train=1030, test=1
# train=1031, test=1
# train=1032, test=1
# train=1033, test=1
# train=1034, test=1
# train=1035, test=1
# train=1036, test=1
# train=1037, test=1
# train=1038, test=1
# train=1039, test=1
# train=1040, test=1
# train=1041, test=1
# train=1042, test=1
# train=1043, test=1
# train=1044, test=1
# train=1045, test=1
# train=1046, test=1
# train=1047, test=1
# train=1048, test=1
# train=1049, test=1
# train=1050, test=1
# train=1051, test=1
# train=1052, test=1
# train=1053, test=1
# train=1054, test=1
# train=1055, test=1
# train=1056, test=1
# train=1057, test=1
# train=1058, test=1
# train=1059, test=1
# train=1060, test=1
# train=1061, test=1
# train=1062, test=1
# train=1063, test=1
# train=1064, test=1
# train=1065, test=1
# train=1066, test=1
# train=1067, test=1
# train=1068, test=1
# train=1069, test=1
# train=1070, test=1
# train=1071, test=1
# train=1072, test=1
# train=1073, test=1
# train=1074, test=1
# train=1075, test=1
# train=1076, test=1
# train=1077, test=1
# train=1078, test=1
# train=1079, test=1
# train=1080, test=1
# train=1081, test=1
# train=1082, test=1
# train=1083, test=1
# train=1084, test=1
# train=1085, test=1
# train=1086, test=1
# train=1087, test=1
# train=1088, test=1
# train=1089, test=1
# train=1090, test=1
# train=1091, test=1
# train=1092, test=1
# train=1093, test=1
# train=1094, test=1
# train=1095, test=1
# train=1096, test=1
# train=1097, test=1
# train=1098, test=1
# train=1099, test=1
# train=1100, test=1
# train=1101, test=1
# train=1102, test=1
# train=1103, test=1
# train=1104, test=1
# train=1105, test=1
# train=1106, test=1
# train=1107, test=1
# train=1108, test=1
# train=1109, test=1
# train=1110, test=1
# train=1111, test=1
# train=1112, test=1
# train=1113, test=1
# train=1114, test=1
# train=1115, test=1
# train=1116, test=1
# train=1117, test=1
# train=1118, test=1
# train=1119, test=1
# train=1120, test=1
# train=1121, test=1
# train=1122, test=1
# train=1123, test=1
# train=1124, test=1
# train=1125, test=1
# train=1126, test=1
# train=1127, test=1
# train=1128, test=1
# train=1129, test=1
# train=1130, test=1
# train=1131, test=1
# train=1132, test=1
# train=1133, test=1
# train=1134, test=1
# train=1135, test=1
# train=1136, test=1
# train=1137, test=1
# train=1138, test=1
# train=1139, test=1
# train=1140, test=1
# train=1141, test=1
# train=1142, test=1
# train=1143, test=1
# train=1144, test=1
# train=1145, test=1
# train=1146, test=1
# train=1147, test=1
# train=1148, test=1
# train=1149, test=1
# train=1150, test=1
# train=1151, test=1
# train=1152, test=1
# train=1153, test=1
# train=1154, test=1
# train=1155, test=1
# train=1156, test=1
# train=1157, test=1
# train=1158, test=1
# train=1159, test=1
# train=1160, test=1
# train=1161, test=1
# train=1162, test=1
# train=1163, test=1
# train=1164, test=1
# train=1165, test=1
# train=1166, test=1
# train=1167, test=1
# train=1168, test=1
# train=1169, test=1
# train=1170, test=1
# train=1171, test=1
# train=1172, test=1
# train=1173, test=1
# train=1174, test=1
# train=1175, test=1
# train=1176, test=1
# train=1177, test=1
# train=1178, test=1
# train=1179, test=1
# train=1180, test=1
# train=1181, test=1
# train=1182, test=1
# train=1183, test=1
# train=1184, test=1
# train=1185, test=1
# train=1186, test=1
# train=1187, test=1
# train=1188, test=1
# train=1189, test=1
# train=1190, test=1
# train=1191, test=1
# train=1192, test=1
# train=1193, test=1
# train=1194, test=1
# train=1195, test=1
# train=1196, test=1
# train=1197, test=1
# train=1198, test=1
# train=1199, test=1
# train=1200, test=1
# train=1201, test=1
# train=1202, test=1
# train=1203, test=1
# train=1204, test=1
# train=1205, test=1
# train=1206, test=1
# train=1207, test=1
# train=1208, test=1
# train=1209, test=1
# train=1210, test=1
# train=1211, test=1
# train=1212, test=1
# train=1213, test=1
# train=1214, test=1
# train=1215, test=1
# train=1216, test=1
# train=1217, test=1
# train=1218, test=1
# train=1219, test=1
# train=1220, test=1
# train=1221, test=1
# train=1222, test=1
# train=1223, test=1
# train=1224, test=1
# train=1225, test=1
# train=1226, test=1
# train=1227, test=1
# train=1228, test=1
# train=1229, test=1
# train=1230, test=1
# train=1231, test=1
# train=1232, test=1
# train=1233, test=1
# train=1234, test=1
# train=1235, test=1
# train=1236, test=1
# train=1237, test=1
# train=1238, test=1
# train=1239, test=1
# train=1240, test=1
# train=1241, test=1
# train=1242, test=1
# train=1243, test=1
# train=1244, test=1
# train=1245, test=1
# train=1246, test=1
# train=1247, test=1
# train=1248, test=1
# train=1249, test=1
# train=1250, test=1
# train=1251, test=1
# train=1252, test=1
# train=1253, test=1
# train=1254, test=1
# train=1255, test=1
# train=1256, test=1
# train=1257, test=1
# train=1258, test=1
# train=1259, test=1
# train=1260, test=1
# train=1261, test=1
# train=1262, test=1
# train=1263, test=1
# train=1264, test=1
# train=1265, test=1
# train=1266, test=1
# train=1267, test=1
# train=1268, test=1
# train=1269, test=1
# train=1270, test=1
# train=1271, test=1
# train=1272, test=1
# train=1273, test=1
# train=1274, test=1
# train=1275, test=1
# train=1276, test=1
# train=1277, test=1
# train=1278, test=1
# train=1279, test=1
# train=1280, test=1
# train=1281, test=1
# train=1282, test=1
# train=1283, test=1
# train=1284, test=1
# train=1285, test=1
# train=1286, test=1
# train=1287, test=1
# train=1288, test=1
# train=1289, test=1
# train=1290, test=1
# train=1291, test=1
# train=1292, test=1
# train=1293, test=1
# train=1294, test=1
# train=1295, test=1
# train=1296, test=1
# train=1297, test=1
# train=1298, test=1
# train=1299, test=1
# train=1300, test=1
# train=1301, test=1
# train=1302, test=1
# train=1303, test=1
# train=1304, test=1
# train=1305, test=1
# train=1306, test=1
# train=1307, test=1
# train=1308, test=1
# train=1309, test=1
# train=1310, test=1
# train=1311, test=1
# train=1312, test=1
# train=1313, test=1
# train=1314, test=1
# train=1315, test=1
# train=1316, test=1
# train=1317, test=1
# train=1318, test=1
# train=1319, test=1
# train=1320, test=1
# train=1321, test=1
# train=1322, test=1
# train=1323, test=1
# train=1324, test=1
# train=1325, test=1
# train=1326, test=1
# train=1327, test=1
# train=1328, test=1
# train=1329, test=1
# train=1330, test=1
# train=1331, test=1
# train=1332, test=1
# train=1333, test=1
# train=1334, test=1
# train=1335, test=1
# train=1336, test=1
# train=1337, test=1
# train=1338, test=1
# train=1339, test=1
# train=1340, test=1
# train=1341, test=1
# train=1342, test=1
# train=1343, test=1
# train=1344, test=1
# train=1345, test=1
# train=1346, test=1
# train=1347, test=1
# train=1348, test=1
# train=1349, test=1
# train=1350, test=1
# train=1351, test=1
# train=1352, test=1
# train=1353, test=1
# train=1354, test=1
# train=1355, test=1
# train=1356, test=1
# train=1357, test=1
# train=1358, test=1
# train=1359, test=1
# train=1360, test=1
# train=1361, test=1
# train=1362, test=1
# train=1363, test=1
# train=1364, test=1
# train=1365, test=1
# train=1366, test=1
# train=1367, test=1
# train=1368, test=1
# train=1369, test=1
# train=1370, test=1
# train=1371, test=1
# train=1372, test=1
# train=1373, test=1
# train=1374, test=1
# train=1375, test=1
# train=1376, test=1
# train=1377, test=1
# train=1378, test=1
# train=1379, test=1
# train=1380, test=1
# train=1381, test=1
# train=1382, test=1
# train=1383, test=1
# train=1384, test=1
# train=1385, test=1
# train=1386, test=1
# train=1387, test=1
# train=1388, test=1
# train=1389, test=1
# train=1390, test=1
# train=1391, test=1
# train=1392, test=1
# train=1393, test=1
# train=1394, test=1
# train=1395, test=1
# train=1396, test=1
# train=1397, test=1
# train=1398, test=1
# train=1399, test=1
# train=1400, test=1
# train=1401, test=1
# train=1402, test=1
# train=1403, test=1
# train=1404, test=1
# train=1405, test=1
# train=1406, test=1
# train=1407, test=1
# train=1408, test=1
# train=1409, test=1
# train=1410, test=1
# train=1411, test=1
# train=1412, test=1
# train=1413, test=1
# train=1414, test=1
# train=1415, test=1
# train=1416, test=1
# train=1417, test=1
# train=1418, test=1
# train=1419, test=1
# train=1420, test=1
# train=1421, test=1
# train=1422, test=1
# train=1423, test=1
# train=1424, test=1
# train=1425, test=1
# train=1426, test=1
# train=1427, test=1
# train=1428, test=1
# train=1429, test=1
# train=1430, test=1
# train=1431, test=1
# train=1432, test=1
# train=1433, test=1
# train=1434, test=1
# train=1435, test=1
# train=1436, test=1
# train=1437, test=1
# train=1438, test=1
# train=1439, test=1
# train=1440, test=1
# train=1441, test=1
# train=1442, test=1
# train=1443, test=1
# train=1444, test=1
# train=1445, test=1
# train=1446, test=1
# train=1447, test=1
# train=1448, test=1
# train=1449, test=1
# train=1450, test=1
# train=1451, test=1
# train=1452, test=1
# train=1453, test=1
# train=1454, test=1
# train=1455, test=1
# train=1456, test=1
# train=1457, test=1
# train=1458, test=1
# train=1459, test=1
# train=1460, test=1
# train=1461, test=1
# train=1462, test=1
# train=1463, test=1
# train=1464, test=1
# train=1465, test=1
# train=1466, test=1
# train=1467, test=1
# train=1468, test=1
# train=1469, test=1
# train=1470, test=1
# train=1471, test=1
# train=1472, test=1
# train=1473, test=1
# train=1474, test=1
# train=1475, test=1
# train=1476, test=1
# train=1477, test=1
# train=1478, test=1
# train=1479, test=1
# train=1480, test=1
# train=1481, test=1
# train=1482, test=1
# train=1483, test=1
# train=1484, test=1
# train=1485, test=1
# train=1486, test=1
# train=1487, test=1
# train=1488, test=1
# train=1489, test=1
# train=1490, test=1
# train=1491, test=1
# train=1492, test=1
# train=1493, test=1
# train=1494, test=1
# train=1495, test=1
# train=1496, test=1
# train=1497, test=1
# train=1498, test=1
# train=1499, test=1
# train=1500, test=1
# train=1501, test=1
# train=1502, test=1
# train=1503, test=1
# train=1504, test=1
# train=1505, test=1
# train=1506, test=1
# train=1507, test=1
# train=1508, test=1
# train=1509, test=1
# train=1510, test=1
# train=1511, test=1
# train=1512, test=1
# train=1513, test=1
# train=1514, test=1
# train=1515, test=1
# train=1516, test=1
# train=1517, test=1
# train=1518, test=1
# train=1519, test=1
# train=1520, test=1
# train=1521, test=1
# train=1522, test=1
# train=1523, test=1
# train=1524, test=1
# train=1525, test=1
# train=1526, test=1
# train=1527, test=1
# train=1528, test=1
# train=1529, test=1
# train=1530, test=1
# train=1531, test=1
# train=1532, test=1
# train=1533, test=1
# train=1534, test=1
# train=1535, test=1
# train=1536, test=1
# train=1537, test=1
# train=1538, test=1
# train=1539, test=1
# train=1540, test=1
# train=1541, test=1
# train=1542, test=1
# train=1543, test=1
# train=1544, test=1
# train=1545, test=1
# train=1546, test=1
# train=1547, test=1
# train=1548, test=1
# train=1549, test=1
# train=1550, test=1
# train=1551, test=1
# train=1552, test=1
# train=1553, test=1
# train=1554, test=1
# train=1555, test=1
# train=1556, test=1
# train=1557, test=1
# train=1558, test=1
# train=1559, test=1
# train=1560, test=1
# train=1561, test=1
# train=1562, test=1
# train=1563, test=1
# train=1564, test=1
# train=1565, test=1
# train=1566, test=1
# train=1567, test=1
# train=1568, test=1
# train=1569, test=1
# train=1570, test=1
# train=1571, test=1
# train=1572, test=1
# train=1573, test=1
# train=1574, test=1
# train=1575, test=1
# train=1576, test=1
# train=1577, test=1
# train=1578, test=1
# train=1579, test=1
# train=1580, test=1
# train=1581, test=1
# train=1582, test=1
# train=1583, test=1
# train=1584, test=1
# train=1585, test=1
# train=1586, test=1
# train=1587, test=1
# train=1588, test=1
# train=1589, test=1
# train=1590, test=1
# train=1591, test=1
# train=1592, test=1
# train=1593, test=1
# train=1594, test=1
# train=1595, test=1
# train=1596, test=1
# train=1597, test=1
# train=1598, test=1
# train=1599, test=1
# train=1600, test=1
# train=1601, test=1
# train=1602, test=1
# train=1603, test=1
# train=1604, test=1
# train=1605, test=1
# train=1606, test=1
# train=1607, test=1
# train=1608, test=1
# train=1609, test=1
# train=1610, test=1
# train=1611, test=1
# train=1612, test=1
# train=1613, test=1
# train=1614, test=1
# train=1615, test=1
# train=1616, test=1
# train=1617, test=1
# train=1618, test=1
# train=1619, test=1
# train=1620, test=1
# train=1621, test=1
# train=1622, test=1
# train=1623, test=1
# train=1624, test=1
# train=1625, test=1
# train=1626, test=1
# train=1627, test=1
# train=1628, test=1
# train=1629, test=1
# train=1630, test=1
# train=1631, test=1
# train=1632, test=1
# train=1633, test=1
# train=1634, test=1
# train=1635, test=1
# train=1636, test=1
# train=1637, test=1
# train=1638, test=1
# train=1639, test=1
# train=1640, test=1
# train=1641, test=1
# train=1642, test=1
# train=1643, test=1
# train=1644, test=1
# train=1645, test=1
# train=1646, test=1
# train=1647, test=1
# train=1648, test=1
# train=1649, test=1
# train=1650, test=1
# train=1651, test=1
# train=1652, test=1
# train=1653, test=1
# train=1654, test=1
# train=1655, test=1
# train=1656, test=1
# train=1657, test=1
# train=1658, test=1
# train=1659, test=1
# train=1660, test=1
# train=1661, test=1
# train=1662, test=1
# train=1663, test=1
# train=1664, test=1
# train=1665, test=1
# train=1666, test=1
# train=1667, test=1
# train=1668, test=1
# train=1669, test=1
# train=1670, test=1
# train=1671, test=1
# train=1672, test=1
# train=1673, test=1
# train=1674, test=1
# train=1675, test=1
# train=1676, test=1
# train=1677, test=1
# train=1678, test=1
# train=1679, test=1
# train=1680, test=1
# train=1681, test=1
# train=1682, test=1
# train=1683, test=1
# train=1684, test=1
# train=1685, test=1
# train=1686, test=1
# train=1687, test=1
# train=1688, test=1
# train=1689, test=1
# train=1690, test=1
# train=1691, test=1
# train=1692, test=1
# train=1693, test=1
# train=1694, test=1
# train=1695, test=1
# train=1696, test=1
# train=1697, test=1
# train=1698, test=1
# train=1699, test=1
# train=1700, test=1
# train=1701, test=1
# train=1702, test=1
# train=1703, test=1
# train=1704, test=1
# train=1705, test=1
# train=1706, test=1
# train=1707, test=1
# train=1708, test=1
# train=1709, test=1
# train=1710, test=1
# train=1711, test=1
# train=1712, test=1
# train=1713, test=1
# train=1714, test=1
# train=1715, test=1
# train=1716, test=1
# train=1717, test=1
# train=1718, test=1
# train=1719, test=1
# train=1720, test=1
# train=1721, test=1
# train=1722, test=1
# train=1723, test=1
# train=1724, test=1
# train=1725, test=1
# train=1726, test=1
# train=1727, test=1
# train=1728, test=1
# train=1729, test=1
# train=1730, test=1
# train=1731, test=1
# train=1732, test=1
# train=1733, test=1
# train=1734, test=1
# train=1735, test=1
# train=1736, test=1
# train=1737, test=1
# train=1738, test=1
# train=1739, test=1
# train=1740, test=1
# train=1741, test=1
# train=1742, test=1
# train=1743, test=1
# train=1744, test=1
# train=1745, test=1
# train=1746, test=1
# train=1747, test=1
# train=1748, test=1
# train=1749, test=1
# train=1750, test=1
# train=1751, test=1
# train=1752, test=1
# train=1753, test=1
# train=1754, test=1
# train=1755, test=1
# train=1756, test=1
# train=1757, test=1
# train=1758, test=1
# train=1759, test=1
# train=1760, test=1
# train=1761, test=1
# train=1762, test=1
# train=1763, test=1
# train=1764, test=1
# train=1765, test=1
# train=1766, test=1
# train=1767, test=1
# train=1768, test=1
# train=1769, test=1
# train=1770, test=1
# train=1771, test=1
# train=1772, test=1
# train=1773, test=1
# train=1774, test=1
# train=1775, test=1
# train=1776, test=1
# train=1777, test=1
# train=1778, test=1
# train=1779, test=1
# train=1780, test=1
# train=1781, test=1
# train=1782, test=1
# train=1783, test=1
# train=1784, test=1
# train=1785, test=1
# train=1786, test=1
# train=1787, test=1
# train=1788, test=1
# train=1789, test=1
# train=1790, test=1
# train=1791, test=1
# train=1792, test=1
# train=1793, test=1
# train=1794, test=1
# train=1795, test=1
# train=1796, test=1
# train=1797, test=1
# train=1798, test=1
# train=1799, test=1
# train=1800, test=1
# train=1801, test=1
# train=1802, test=1
# train=1803, test=1
# train=1804, test=1
# train=1805, test=1
# train=1806, test=1
# train=1807, test=1
# train=1808, test=1
# train=1809, test=1
# train=1810, test=1
# train=1811, test=1
# train=1812, test=1
# train=1813, test=1
# train=1814, test=1
# train=1815, test=1
# train=1816, test=1
# train=1817, test=1
# train=1818, test=1
# train=1819, test=1
# train=1820, test=1
# train=1821, test=1
# train=1822, test=1
# train=1823, test=1
# train=1824, test=1
# train=1825, test=1
# train=1826, test=1
# train=1827, test=1
# train=1828, test=1
# train=1829, test=1
# train=1830, test=1
# train=1831, test=1
# train=1832, test=1
# train=1833, test=1
# train=1834, test=1
# train=1835, test=1
# train=1836, test=1
# train=1837, test=1
# train=1838, test=1
# train=1839, test=1
# train=1840, test=1
# train=1841, test=1
# train=1842, test=1
# train=1843, test=1
# train=1844, test=1
# train=1845, test=1
# train=1846, test=1
# train=1847, test=1
# train=1848, test=1
# train=1849, test=1
# train=1850, test=1
# train=1851, test=1
# train=1852, test=1
# train=1853, test=1
# train=1854, test=1
# train=1855, test=1
# train=1856, test=1
# train=1857, test=1
# train=1858, test=1
# train=1859, test=1
# train=1860, test=1
# train=1861, test=1
# train=1862, test=1
# train=1863, test=1
# train=1864, test=1
# train=1865, test=1
# train=1866, test=1
# train=1867, test=1
# train=1868, test=1
# train=1869, test=1
# train=1870, test=1
# train=1871, test=1
# train=1872, test=1
# train=1873, test=1
# train=1874, test=1
# train=1875, test=1
# train=1876, test=1
# train=1877, test=1
# train=1878, test=1
# train=1879, test=1
# train=1880, test=1
# train=1881, test=1
# train=1882, test=1
# train=1883, test=1
# train=1884, test=1
# train=1885, test=1
# train=1886, test=1
# train=1887, test=1
# train=1888, test=1
# train=1889, test=1
# train=1890, test=1
# train=1891, test=1
# train=1892, test=1
# train=1893, test=1
# train=1894, test=1
# train=1895, test=1
# train=1896, test=1
# train=1897, test=1
# train=1898, test=1
# train=1899, test=1
# train=1900, test=1
# train=1901, test=1
# train=1902, test=1
# train=1903, test=1
# train=1904, test=1
# train=1905, test=1
# train=1906, test=1
# train=1907, test=1
# train=1908, test=1
# train=1909, test=1
# train=1910, test=1
# train=1911, test=1
# train=1912, test=1
# train=1913, test=1
# train=1914, test=1
# train=1915, test=1
# train=1916, test=1
# train=1917, test=1
# train=1918, test=1
# train=1919, test=1
# train=1920, test=1
# train=1921, test=1
# train=1922, test=1
# train=1923, test=1
# train=1924, test=1
# train=1925, test=1
# train=1926, test=1
# train=1927, test=1
# train=1928, test=1
# train=1929, test=1
# train=1930, test=1
# train=1931, test=1
# train=1932, test=1
# train=1933, test=1
# train=1934, test=1
# train=1935, test=1
# train=1936, test=1
# train=1937, test=1
# train=1938, test=1
# train=1939, test=1
# train=1940, test=1
# train=1941, test=1
# train=1942, test=1
# train=1943, test=1
# train=1944, test=1
# train=1945, test=1
# train=1946, test=1
# train=1947, test=1
# train=1948, test=1
# train=1949, test=1
# train=1950, test=1
# train=1951, test=1
# train=1952, test=1
# train=1953, test=1
# train=1954, test=1
# train=1955, test=1
# train=1956, test=1
# train=1957, test=1
# train=1958, test=1
# train=1959, test=1
# train=1960, test=1
# train=1961, test=1
# train=1962, test=1
# train=1963, test=1
# train=1964, test=1
# train=1965, test=1
# train=1966, test=1
# train=1967, test=1
# train=1968, test=1
# train=1969, test=1
# train=1970, test=1
# train=1971, test=1
# train=1972, test=1
# train=1973, test=1
# train=1974, test=1
# train=1975, test=1
# train=1976, test=1
# train=1977, test=1
# train=1978, test=1
# train=1979, test=1
# train=1980, test=1
# train=1981, test=1
# train=1982, test=1
# train=1983, test=1
# train=1984, test=1
# train=1985, test=1
# train=1986, test=1
# train=1987, test=1
# train=1988, test=1
# train=1989, test=1
# train=1990, test=1
# train=1991, test=1
# train=1992, test=1
# train=1993, test=1
# train=1994, test=1
# train=1995, test=1
# train=1996, test=1
# train=1997, test=1
# train=1998, test=1
# train=1999, test=1
# train=2000, test=1
# train=2001, test=1
# train=2002, test=1
# train=2003, test=1
# train=2004, test=1
# train=2005, test=1
# train=2006, test=1
# train=2007, test=1
# train=2008, test=1
# train=2009, test=1
# train=2010, test=1
# train=2011, test=1
# train=2012, test=1
# train=2013, test=1
# train=2014, test=1
# train=2015, test=1
# train=2016, test=1
# train=2017, test=1
# train=2018, test=1
# train=2019, test=1
# train=2020, test=1
# train=2021, test=1
# train=2022, test=1
# train=2023, test=1
# train=2024, test=1
# train=2025, test=1
# train=2026, test=1
# train=2027, test=1
# train=2028, test=1
# train=2029, test=1
# train=2030, test=1
# train=2031, test=1
# train=2032, test=1
# train=2033, test=1
# train=2034, test=1
# train=2035, test=1
# train=2036, test=1
# train=2037, test=1
# train=2038, test=1
# train=2039, test=1
# train=2040, test=1
# train=2041, test=1
# train=2042, test=1
# train=2043, test=1
# train=2044, test=1
# train=2045, test=1
# train=2046, test=1
# train=2047, test=1
# train=2048, test=1
# train=2049, test=1
# train=2050, test=1
# train=2051, test=1
# train=2052, test=1
# train=2053, test=1
# train=2054, test=1
# train=2055, test=1
# train=2056, test=1
# train=2057, test=1
# train=2058, test=1
# train=2059, test=1
# train=2060, test=1
# train=2061, test=1
# train=2062, test=1
# train=2063, test=1
# train=2064, test=1
# train=2065, test=1
# train=2066, test=1
# train=2067, test=1
# train=2068, test=1
# train=2069, test=1
# train=2070, test=1
# train=2071, test=1
# train=2072, test=1
# train=2073, test=1
# train=2074, test=1
# train=2075, test=1
# train=2076, test=1
# train=2077, test=1
# train=2078, test=1
# train=2079, test=1
# train=2080, test=1
# train=2081, test=1
# train=2082, test=1
# train=2083, test=1
# train=2084, test=1
# train=2085, test=1
# train=2086, test=1
# train=2087, test=1
# train=2088, test=1
# train=2089, test=1
# train=2090, test=1
# train=2091, test=1
# train=2092, test=1
# train=2093, test=1
# train=2094, test=1
# train=2095, test=1
# train=2096, test=1
# train=2097, test=1
# train=2098, test=1
# train=2099, test=1
# train=2100, test=1
# train=2101, test=1
# train=2102, test=1
# train=2103, test=1
# train=2104, test=1
# train=2105, test=1
# train=2106, test=1
# train=2107, test=1
# train=2108, test=1
# train=2109, test=1
# train=2110, test=1
# train=2111, test=1
# train=2112, test=1
# train=2113, test=1
# train=2114, test=1
# train=2115, test=1
# train=2116, test=1
# train=2117, test=1
# train=2118, test=1
# train=2119, test=1
# train=2120, test=1
# train=2121, test=1
# train=2122, test=1
# train=2123, test=1
# train=2124, test=1
# train=2125, test=1
# train=2126, test=1
# train=2127, test=1
# train=2128, test=1
# train=2129, test=1
# train=2130, test=1
# train=2131, test=1
# train=2132, test=1
# train=2133, test=1
# train=2134, test=1
# train=2135, test=1
# train=2136, test=1
# train=2137, test=1
# train=2138, test=1
# train=2139, test=1
# train=2140, test=1
# train=2141, test=1
# train=2142, test=1
# train=2143, test=1
# train=2144, test=1
# train=2145, test=1
# train=2146, test=1
# train=2147, test=1
# train=2148, test=1
# train=2149, test=1
# train=2150, test=1
# train=2151, test=1
# train=2152, test=1
# train=2153, test=1
# train=2154, test=1
# train=2155, test=1
# train=2156, test=1
# train=2157, test=1
# train=2158, test=1
# train=2159, test=1
# train=2160, test=1
# train=2161, test=1
# train=2162, test=1
# train=2163, test=1
# train=2164, test=1
# train=2165, test=1
# train=2166, test=1
# train=2167, test=1
# train=2168, test=1
# train=2169, test=1
# train=2170, test=1
# train=2171, test=1
# train=2172, test=1
# train=2173, test=1
# train=2174, test=1
# train=2175, test=1
# train=2176, test=1
# train=2177, test=1
# train=2178, test=1
# train=2179, test=1
# train=2180, test=1
# train=2181, test=1
# train=2182, test=1
# train=2183, test=1
# train=2184, test=1
# train=2185, test=1
# train=2186, test=1
# train=2187, test=1
# train=2188, test=1
# train=2189, test=1
# train=2190, test=1
# train=2191, test=1
# train=2192, test=1
# train=2193, test=1
# train=2194, test=1
# train=2195, test=1
# train=2196, test=1
# train=2197, test=1
# train=2198, test=1
# train=2199, test=1
# train=2200, test=1
# train=2201, test=1
# train=2202, test=1
# train=2203, test=1
# train=2204, test=1
# train=2205, test=1
# train=2206, test=1
# train=2207, test=1
# train=2208, test=1
# train=2209, test=1
# train=2210, test=1
# train=2211, test=1
# train=2212, test=1
# train=2213, test=1
# train=2214, test=1
# train=2215, test=1
# train=2216, test=1
# train=2217, test=1
# train=2218, test=1
# train=2219, test=1
# train=2220, test=1
# train=2221, test=1
# train=2222, test=1
# train=2223, test=1
# train=2224, test=1
# train=2225, test=1
# train=2226, test=1
# train=2227, test=1
# train=2228, test=1
# train=2229, test=1
# train=2230, test=1
# train=2231, test=1
# train=2232, test=1
# train=2233, test=1
# train=2234, test=1
# train=2235, test=1
# train=2236, test=1
# train=2237, test=1
# train=2238, test=1
# train=2239, test=1
# train=2240, test=1
# train=2241, test=1
# train=2242, test=1
# train=2243, test=1
# train=2244, test=1
# train=2245, test=1
# train=2246, test=1
# train=2247, test=1
# train=2248, test=1
# train=2249, test=1
# train=2250, test=1
# train=2251, test=1
# train=2252, test=1
# train=2253, test=1
# train=2254, test=1
# train=2255, test=1
# train=2256, test=1
# train=2257, test=1
# train=2258, test=1
# train=2259, test=1
# train=2260, test=1
# train=2261, test=1
# train=2262, test=1
# train=2263, test=1
# train=2264, test=1
# train=2265, test=1
# train=2266, test=1
# train=2267, test=1
# train=2268, test=1
# train=2269, test=1
# train=2270, test=1
# train=2271, test=1
# train=2272, test=1
# train=2273, test=1
# train=2274, test=1
# train=2275, test=1
# train=2276, test=1
# train=2277, test=1
# train=2278, test=1
# train=2279, test=1
# train=2280, test=1
# train=2281, test=1
# train=2282, test=1
# train=2283, test=1
# train=2284, test=1
# train=2285, test=1
# train=2286, test=1
# train=2287, test=1
# train=2288, test=1
# train=2289, test=1
# train=2290, test=1
# train=2291, test=1
# train=2292, test=1
# train=2293, test=1
# train=2294, test=1
# train=2295, test=1
# train=2296, test=1
# train=2297, test=1
# train=2298, test=1
# train=2299, test=1
# train=2300, test=1
# train=2301, test=1
# train=2302, test=1
# train=2303, test=1
# train=2304, test=1
# train=2305, test=1
# train=2306, test=1
# train=2307, test=1
# train=2308, test=1
# train=2309, test=1
# train=2310, test=1
# train=2311, test=1
# train=2312, test=1
# train=2313, test=1
# train=2314, test=1
# train=2315, test=1
# train=2316, test=1
# train=2317, test=1
# train=2318, test=1
# train=2319, test=1
# train=2320, test=1
# train=2321, test=1
# train=2322, test=1
# train=2323, test=1
# train=2324, test=1
# train=2325, test=1
# train=2326, test=1
# train=2327, test=1
# train=2328, test=1
# train=2329, test=1
# train=2330, test=1
# train=2331, test=1
# train=2332, test=1
# train=2333, test=1
# train=2334, test=1
# train=2335, test=1
# train=2336, test=1
# train=2337, test=1
# train=2338, test=1
# train=2339, test=1
# train=2340, test=1
# train=2341, test=1
# train=2342, test=1
# train=2343, test=1
# train=2344, test=1
# train=2345, test=1
# train=2346, test=1
# train=2347, test=1
# train=2348, test=1
# train=2349, test=1
# train=2350, test=1
# train=2351, test=1
# train=2352, test=1
# train=2353, test=1
# train=2354, test=1
# train=2355, test=1
# train=2356, test=1
# train=2357, test=1
# train=2358, test=1
# train=2359, test=1
# train=2360, test=1
# train=2361, test=1
# train=2362, test=1
# train=2363, test=1
# train=2364, test=1
# train=2365, test=1
# train=2366, test=1
# train=2367, test=1
# train=2368, test=1
# train=2369, test=1
# train=2370, test=1
# train=2371, test=1
# train=2372, test=1
# train=2373, test=1
# train=2374, test=1
# train=2375, test=1
# train=2376, test=1
# train=2377, test=1
# train=2378, test=1
# train=2379, test=1
# train=2380, test=1
# train=2381, test=1
# train=2382, test=1
# train=2383, test=1
# train=2384, test=1
# train=2385, test=1
# train=2386, test=1
# train=2387, test=1
# train=2388, test=1
# train=2389, test=1
# train=2390, test=1
# train=2391, test=1
# train=2392, test=1
# train=2393, test=1
# train=2394, test=1
# train=2395, test=1
# train=2396, test=1
# train=2397, test=1
# train=2398, test=1
# train=2399, test=1
# train=2400, test=1
# train=2401, test=1
# train=2402, test=1
# train=2403, test=1
# train=2404, test=1
# train=2405, test=1
# train=2406, test=1
# train=2407, test=1
# train=2408, test=1
# train=2409, test=1
# train=2410, test=1
# train=2411, test=1
# train=2412, test=1
# train=2413, test=1
# train=2414, test=1
# train=2415, test=1
# train=2416, test=1
# train=2417, test=1
# train=2418, test=1
# train=2419, test=1
# train=2420, test=1
# train=2421, test=1
# train=2422, test=1
# train=2423, test=1
# train=2424, test=1
# train=2425, test=1
# train=2426, test=1
# train=2427, test=1
# train=2428, test=1
# train=2429, test=1
# train=2430, test=1
# train=2431, test=1
# train=2432, test=1
# train=2433, test=1
# train=2434, test=1
# train=2435, test=1
# train=2436, test=1
# train=2437, test=1
# train=2438, test=1
# train=2439, test=1
# train=2440, test=1
# train=2441, test=1
# train=2442, test=1
# train=2443, test=1
# train=2444, test=1
# train=2445, test=1
# train=2446, test=1
# train=2447, test=1
# train=2448, test=1
# train=2449, test=1
# train=2450, test=1
# train=2451, test=1
# train=2452, test=1
# train=2453, test=1
# train=2454, test=1
# train=2455, test=1
# train=2456, test=1
# train=2457, test=1
# train=2458, test=1
# train=2459, test=1
# train=2460, test=1
# train=2461, test=1
# train=2462, test=1
# train=2463, test=1
# train=2464, test=1
# train=2465, test=1
# train=2466, test=1
# train=2467, test=1
# train=2468, test=1
# train=2469, test=1
# train=2470, test=1
# train=2471, test=1
# train=2472, test=1
# train=2473, test=1
# train=2474, test=1
# train=2475, test=1
# train=2476, test=1
# train=2477, test=1
# train=2478, test=1
# train=2479, test=1
# train=2480, test=1
# train=2481, test=1
# train=2482, test=1
# train=2483, test=1
# train=2484, test=1
# train=2485, test=1
# train=2486, test=1
# train=2487, test=1
# train=2488, test=1
# train=2489, test=1
# train=2490, test=1
# train=2491, test=1
# train=2492, test=1
# train=2493, test=1
# train=2494, test=1
# train=2495, test=1
# train=2496, test=1
# train=2497, test=1
# train=2498, test=1
# train=2499, test=1
# train=2500, test=1
# train=2501, test=1
# train=2502, test=1
# train=2503, test=1
# train=2504, test=1
# train=2505, test=1
# train=2506, test=1
# train=2507, test=1
# train=2508, test=1
# train=2509, test=1
# train=2510, test=1
# train=2511, test=1
# train=2512, test=1
# train=2513, test=1
# train=2514, test=1
# train=2515, test=1
# train=2516, test=1
# train=2517, test=1
# train=2518, test=1
# train=2519, test=1
# train=2520, test=1
# train=2521, test=1
# train=2522, test=1
# train=2523, test=1
# train=2524, test=1
# train=2525, test=1
# train=2526, test=1
# train=2527, test=1
# train=2528, test=1
# train=2529, test=1
# train=2530, test=1
# train=2531, test=1
# train=2532, test=1
# train=2533, test=1
# train=2534, test=1
# train=2535, test=1
# train=2536, test=1
# train=2537, test=1
# train=2538, test=1
# train=2539, test=1
# train=2540, test=1
# train=2541, test=1
# train=2542, test=1
# train=2543, test=1
# train=2544, test=1
# train=2545, test=1
# train=2546, test=1
# train=2547, test=1
# train=2548, test=1
# train=2549, test=1
# train=2550, test=1
# train=2551, test=1
# train=2552, test=1
# train=2553, test=1
# train=2554, test=1
# train=2555, test=1
# train=2556, test=1
# train=2557, test=1
# train=2558, test=1
# train=2559, test=1
# train=2560, test=1
# train=2561, test=1
# train=2562, test=1
# train=2563, test=1
# train=2564, test=1
# train=2565, test=1
# train=2566, test=1
# train=2567, test=1
# train=2568, test=1
# train=2569, test=1
# train=2570, test=1
# train=2571, test=1
# train=2572, test=1
# train=2573, test=1
# train=2574, test=1
# train=2575, test=1
# train=2576, test=1
# train=2577, test=1
# train=2578, test=1
# train=2579, test=1
# train=2580, test=1
# train=2581, test=1
# train=2582, test=1
# train=2583, test=1
# train=2584, test=1
# train=2585, test=1
# train=2586, test=1
# train=2587, test=1
# train=2588, test=1
# train=2589, test=1
# train=2590, test=1
# train=2591, test=1
# train=2592, test=1
# train=2593, test=1
# train=2594, test=1
# train=2595, test=1
# train=2596, test=1
# train=2597, test=1
# train=2598, test=1
# train=2599, test=1
# train=2600, test=1
# train=2601, test=1
# train=2602, test=1
# train=2603, test=1
# train=2604, test=1
# train=2605, test=1
# train=2606, test=1
# train=2607, test=1
# train=2608, test=1
# train=2609, test=1
# train=2610, test=1
# train=2611, test=1
# train=2612, test=1
# train=2613, test=1
# train=2614, test=1
# train=2615, test=1
# train=2616, test=1
# train=2617, test=1
# train=2618, test=1
# train=2619, test=1
# train=2620, test=1
# train=2621, test=1
# train=2622, test=1
# train=2623, test=1
# train=2624, test=1
# train=2625, test=1
# train=2626, test=1
# train=2627, test=1
# train=2628, test=1
# train=2629, test=1
# train=2630, test=1
# train=2631, test=1
# train=2632, test=1
# train=2633, test=1
# train=2634, test=1
# train=2635, test=1
# train=2636, test=1
# train=2637, test=1
# train=2638, test=1
# train=2639, test=1
# train=2640, test=1
# train=2641, test=1
# train=2642, test=1
# train=2643, test=1
# train=2644, test=1
# train=2645, test=1
# train=2646, test=1
# train=2647, test=1
# train=2648, test=1
# train=2649, test=1
# train=2650, test=1
# train=2651, test=1
# train=2652, test=1
# train=2653, test=1
# train=2654, test=1
# train=2655, test=1
# train=2656, test=1
# train=2657, test=1
# train=2658, test=1
# train=2659, test=1
# train=2660, test=1
# train=2661, test=1
# train=2662, test=1
# train=2663, test=1
# train=2664, test=1
# train=2665, test=1
# train=2666, test=1
# train=2667, test=1
# train=2668, test=1
# train=2669, test=1
# train=2670, test=1
# train=2671, test=1
# train=2672, test=1
# train=2673, test=1
# train=2674, test=1
# train=2675, test=1
# train=2676, test=1
# train=2677, test=1
# train=2678, test=1
# train=2679, test=1
# train=2680, test=1
# train=2681, test=1
# train=2682, test=1
# train=2683, test=1
# train=2684, test=1
# train=2685, test=1
# train=2686, test=1
# train=2687, test=1
# train=2688, test=1
# train=2689, test=1
# train=2690, test=1
# train=2691, test=1
# train=2692, test=1
# train=2693, test=1
# train=2694, test=1
# train=2695, test=1
# train=2696, test=1
# train=2697, test=1
# train=2698, test=1
# train=2699, test=1
# train=2700, test=1
# train=2701, test=1
# train=2702, test=1
# train=2703, test=1
# train=2704, test=1
# train=2705, test=1
# train=2706, test=1
# train=2707, test=1
# train=2708, test=1
# train=2709, test=1
# train=2710, test=1
# train=2711, test=1
# train=2712, test=1
# train=2713, test=1
# train=2714, test=1
# train=2715, test=1
# train=2716, test=1
# train=2717, test=1
# train=2718, test=1
# train=2719, test=1
# train=2720, test=1
# train=2721, test=1
# train=2722, test=1
# train=2723, test=1
# train=2724, test=1
# train=2725, test=1
# train=2726, test=1
# train=2727, test=1
# train=2728, test=1
# train=2729, test=1
# train=2730, test=1
# train=2731, test=1
# train=2732, test=1
# train=2733, test=1
# train=2734, test=1
# train=2735, test=1
# train=2736, test=1
# train=2737, test=1
# train=2738, test=1
# train=2739, test=1
# train=2740, test=1
# train=2741, test=1
# train=2742, test=1
# train=2743, test=1
# train=2744, test=1
# train=2745, test=1
# train=2746, test=1
# train=2747, test=1
# train=2748, test=1
# train=2749, test=1
# train=2750, test=1
# train=2751, test=1
# train=2752, test=1
# train=2753, test=1
# train=2754, test=1
# train=2755, test=1
# train=2756, test=1
# train=2757, test=1
# train=2758, test=1
# train=2759, test=1
# train=2760, test=1
# train=2761, test=1
# train=2762, test=1
# train=2763, test=1
# train=2764, test=1
# train=2765, test=1
# train=2766, test=1
# train=2767, test=1
# train=2768, test=1
# train=2769, test=1
# train=2770, test=1
# train=2771, test=1
# train=2772, test=1
# train=2773, test=1
# train=2774, test=1
# train=2775, test=1
# train=2776, test=1
# train=2777, test=1
# train=2778, test=1
# train=2779, test=1
# train=2780, test=1
# train=2781, test=1
# train=2782, test=1
# train=2783, test=1
# train=2784, test=1
# train=2785, test=1
# train=2786, test=1
# train=2787, test=1
# train=2788, test=1
# train=2789, test=1
# train=2790, test=1
# train=2791, test=1
# train=2792, test=1
# train=2793, test=1
# train=2794, test=1
# train=2795, test=1
# train=2796, test=1
# train=2797, test=1
# train=2798, test=1
# train=2799, test=1
# train=2800, test=1
# train=2801, test=1
# train=2802, test=1
# train=2803, test=1
# train=2804, test=1
# train=2805, test=1
# train=2806, test=1
# train=2807, test=1
# train=2808, test=1
# train=2809, test=1
# train=2810, test=1
# train=2811, test=1
# train=2812, test=1
# train=2813, test=1
# train=2814, test=1
# train=2815, test=1
# train=2816, test=1
# train=2817, test=1
# train=2818, test=1
# train=2819, test=1

# %% [markdown]
# ### How To Backtest Machine Learning Models for Time Series Forecasting

# %%
print(series.head())
series.plot()
pyplot.show()
# Out:
#          Sunspots
# Month
# 1749-01      58.0
# 1749-02      62.6
# 1749-03      70.0
# 1749-04      55.7
# 1749-05      85.0

# %%
X = series.values
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]
print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 2820
# Training Observations: 1861
# Testing Observations: 959

# %%
X = series.values
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]
print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
pyplot.plot(train)
pyplot.plot([None for i in train] + [x for x in test])
pyplot.show()
# Out:
# Observations: 2820
# Training Observations: 1861
# Testing Observations: 959
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Multiple Train-Test Splits

# %%
X = series.values
splits = TimeSeriesSplit(n_splits=3)
pyplot.figure(1)
index = 1
for train_index, test_index in splits.split(X):
	train = X[train_index]
	test = X[test_index]
	print('Observations: %d' % (len(train) + len(test)))
	print('Training Observations: %d' % (len(train)))
	print('Testing Observations: %d' % (len(test)))
	pyplot.subplot(310 + index)
	pyplot.plot(train)
	pyplot.plot([None for i in train] + [x for x in test])
	index += 1
pyplot.show()
# Out:
# Observations: 1410
# Training Observations: 705
# Testing Observations: 705
# Observations: 2115
# Training Observations: 1410
# Testing Observations: 705
# Observations: 2820
# Training Observations: 2115
# Testing Observations: 705
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Walk Forward Validation

# %%
X = series.values
n_train = 500
n_records = len(X)
for i in range(n_train, n_records):
	train, test = X[0:i], X[i:i+1]
	print('train=%d, test=%d' % (len(train), len(test)))
# Out:
# train=500, test=1
# train=501, test=1
# train=502, test=1
# train=503, test=1
# train=504, test=1
# train=505, test=1
# train=506, test=1
# train=507, test=1
# train=508, test=1
# train=509, test=1
# train=510, test=1
# train=511, test=1
# train=512, test=1
# train=513, test=1
# train=514, test=1
# train=515, test=1
# train=516, test=1
# train=517, test=1
# train=518, test=1
# train=519, test=1
# train=520, test=1
# train=521, test=1
# train=522, test=1
# train=523, test=1
# train=524, test=1
# train=525, test=1
# train=526, test=1
# train=527, test=1
# train=528, test=1
# train=529, test=1
# train=530, test=1
# train=531, test=1
# train=532, test=1
# train=533, test=1
# train=534, test=1
# train=535, test=1
# train=536, test=1
# train=537, test=1
# train=538, test=1
# train=539, test=1
# train=540, test=1
# train=541, test=1
# train=542, test=1
# train=543, test=1
# train=544, test=1
# train=545, test=1
# train=546, test=1
# train=547, test=1
# train=548, test=1
# train=549, test=1
# train=550, test=1
# train=551, test=1
# train=552, test=1
# train=553, test=1
# train=554, test=1
# train=555, test=1
# train=556, test=1
# train=557, test=1
# train=558, test=1
# train=559, test=1
# train=560, test=1
# train=561, test=1
# train=562, test=1
# train=563, test=1
# train=564, test=1
# train=565, test=1
# train=566, test=1
# train=567, test=1
# train=568, test=1
# train=569, test=1
# train=570, test=1
# train=571, test=1
# train=572, test=1
# train=573, test=1
# train=574, test=1
# train=575, test=1
# train=576, test=1
# train=577, test=1
# train=578, test=1
# train=579, test=1
# train=580, test=1
# train=581, test=1
# train=582, test=1
# train=583, test=1
# train=584, test=1
# train=585, test=1
# train=586, test=1
# train=587, test=1
# train=588, test=1
# train=589, test=1
# train=590, test=1
# train=591, test=1
# train=592, test=1
# train=593, test=1
# train=594, test=1
# train=595, test=1
# train=596, test=1
# train=597, test=1
# train=598, test=1
# train=599, test=1
# train=600, test=1
# train=601, test=1
# train=602, test=1
# train=603, test=1
# train=604, test=1
# train=605, test=1
# train=606, test=1
# train=607, test=1
# train=608, test=1
# train=609, test=1
# train=610, test=1
# train=611, test=1
# train=612, test=1
# train=613, test=1
# train=614, test=1
# train=615, test=1
# train=616, test=1
# train=617, test=1
# train=618, test=1
# train=619, test=1
# train=620, test=1
# train=621, test=1
# train=622, test=1
# train=623, test=1
# train=624, test=1
# train=625, test=1
# train=626, test=1
# train=627, test=1
# train=628, test=1
# train=629, test=1
# train=630, test=1
# train=631, test=1
# train=632, test=1
# train=633, test=1
# train=634, test=1
# train=635, test=1
# train=636, test=1
# train=637, test=1
# train=638, test=1
# train=639, test=1
# train=640, test=1
# train=641, test=1
# train=642, test=1
# train=643, test=1
# train=644, test=1
# train=645, test=1
# train=646, test=1
# train=647, test=1
# train=648, test=1
# train=649, test=1
# train=650, test=1
# train=651, test=1
# train=652, test=1
# train=653, test=1
# train=654, test=1
# train=655, test=1
# train=656, test=1
# train=657, test=1
# train=658, test=1
# train=659, test=1
# train=660, test=1
# train=661, test=1
# train=662, test=1
# train=663, test=1
# train=664, test=1
# train=665, test=1
# train=666, test=1
# train=667, test=1
# train=668, test=1
# train=669, test=1
# train=670, test=1
# train=671, test=1
# train=672, test=1
# train=673, test=1
# train=674, test=1
# train=675, test=1
# train=676, test=1
# train=677, test=1
# train=678, test=1
# train=679, test=1
# train=680, test=1
# train=681, test=1
# train=682, test=1
# train=683, test=1
# train=684, test=1
# train=685, test=1
# train=686, test=1
# train=687, test=1
# train=688, test=1
# train=689, test=1
# train=690, test=1
# train=691, test=1
# train=692, test=1
# train=693, test=1
# train=694, test=1
# train=695, test=1
# train=696, test=1
# train=697, test=1
# train=698, test=1
# train=699, test=1
# train=700, test=1
# train=701, test=1
# train=702, test=1
# train=703, test=1
# train=704, test=1
# train=705, test=1
# train=706, test=1
# train=707, test=1
# train=708, test=1
# train=709, test=1
# train=710, test=1
# train=711, test=1
# train=712, test=1
# train=713, test=1
# train=714, test=1
# train=715, test=1
# train=716, test=1
# train=717, test=1
# train=718, test=1
# train=719, test=1
# train=720, test=1
# train=721, test=1
# train=722, test=1
# train=723, test=1
# train=724, test=1
# train=725, test=1
# train=726, test=1
# train=727, test=1
# train=728, test=1
# train=729, test=1
# train=730, test=1
# train=731, test=1
# train=732, test=1
# train=733, test=1
# train=734, test=1
# train=735, test=1
# train=736, test=1
# train=737, test=1
# train=738, test=1
# train=739, test=1
# train=740, test=1
# train=741, test=1
# train=742, test=1
# train=743, test=1
# train=744, test=1
# train=745, test=1
# train=746, test=1
# train=747, test=1
# train=748, test=1
# train=749, test=1
# train=750, test=1
# train=751, test=1
# train=752, test=1
# train=753, test=1
# train=754, test=1
# train=755, test=1
# train=756, test=1
# train=757, test=1
# train=758, test=1
# train=759, test=1
# train=760, test=1
# train=761, test=1
# train=762, test=1
# train=763, test=1
# train=764, test=1
# train=765, test=1
# train=766, test=1
# train=767, test=1
# train=768, test=1
# train=769, test=1
# train=770, test=1
# train=771, test=1
# train=772, test=1
# train=773, test=1
# train=774, test=1
# train=775, test=1
# train=776, test=1
# train=777, test=1
# train=778, test=1
# train=779, test=1
# train=780, test=1
# train=781, test=1
# train=782, test=1
# train=783, test=1
# train=784, test=1
# train=785, test=1
# train=786, test=1
# train=787, test=1
# train=788, test=1
# train=789, test=1
# train=790, test=1
# train=791, test=1
# train=792, test=1
# train=793, test=1
# train=794, test=1
# train=795, test=1
# train=796, test=1
# train=797, test=1
# train=798, test=1
# train=799, test=1
# train=800, test=1
# train=801, test=1
# train=802, test=1
# train=803, test=1
# train=804, test=1
# train=805, test=1
# train=806, test=1
# train=807, test=1
# train=808, test=1
# train=809, test=1
# train=810, test=1
# train=811, test=1
# train=812, test=1
# train=813, test=1
# train=814, test=1
# train=815, test=1
# train=816, test=1
# train=817, test=1
# train=818, test=1
# train=819, test=1
# train=820, test=1
# train=821, test=1
# train=822, test=1
# train=823, test=1
# train=824, test=1
# train=825, test=1
# train=826, test=1
# train=827, test=1
# train=828, test=1
# train=829, test=1
# train=830, test=1
# train=831, test=1
# train=832, test=1
# train=833, test=1
# train=834, test=1
# train=835, test=1
# train=836, test=1
# train=837, test=1
# train=838, test=1
# train=839, test=1
# train=840, test=1
# train=841, test=1
# train=842, test=1
# train=843, test=1
# train=844, test=1
# train=845, test=1
# train=846, test=1
# train=847, test=1
# train=848, test=1
# train=849, test=1
# train=850, test=1
# train=851, test=1
# train=852, test=1
# train=853, test=1
# train=854, test=1
# train=855, test=1
# train=856, test=1
# train=857, test=1
# train=858, test=1
# train=859, test=1
# train=860, test=1
# train=861, test=1
# train=862, test=1
# train=863, test=1
# train=864, test=1
# train=865, test=1
# train=866, test=1
# train=867, test=1
# train=868, test=1
# train=869, test=1
# train=870, test=1
# train=871, test=1
# train=872, test=1
# train=873, test=1
# train=874, test=1
# train=875, test=1
# train=876, test=1
# train=877, test=1
# train=878, test=1
# train=879, test=1
# train=880, test=1
# train=881, test=1
# train=882, test=1
# train=883, test=1
# train=884, test=1
# train=885, test=1
# train=886, test=1
# train=887, test=1
# train=888, test=1
# train=889, test=1
# train=890, test=1
# train=891, test=1
# train=892, test=1
# train=893, test=1
# train=894, test=1
# train=895, test=1
# train=896, test=1
# train=897, test=1
# train=898, test=1
# train=899, test=1
# train=900, test=1
# train=901, test=1
# train=902, test=1
# train=903, test=1
# train=904, test=1
# train=905, test=1
# train=906, test=1
# train=907, test=1
# train=908, test=1
# train=909, test=1
# train=910, test=1
# train=911, test=1
# train=912, test=1
# train=913, test=1
# train=914, test=1
# train=915, test=1
# train=916, test=1
# train=917, test=1
# train=918, test=1
# train=919, test=1
# train=920, test=1
# train=921, test=1
# train=922, test=1
# train=923, test=1
# train=924, test=1
# train=925, test=1
# train=926, test=1
# train=927, test=1
# train=928, test=1
# train=929, test=1
# train=930, test=1
# train=931, test=1
# train=932, test=1
# train=933, test=1
# train=934, test=1
# train=935, test=1
# train=936, test=1
# train=937, test=1
# train=938, test=1
# train=939, test=1
# train=940, test=1
# train=941, test=1
# train=942, test=1
# train=943, test=1
# train=944, test=1
# train=945, test=1
# train=946, test=1
# train=947, test=1
# train=948, test=1
# train=949, test=1
# train=950, test=1
# train=951, test=1
# train=952, test=1
# train=953, test=1
# train=954, test=1
# train=955, test=1
# train=956, test=1
# train=957, test=1
# train=958, test=1
# train=959, test=1
# train=960, test=1
# train=961, test=1
# train=962, test=1
# train=963, test=1
# train=964, test=1
# train=965, test=1
# train=966, test=1
# train=967, test=1
# train=968, test=1
# train=969, test=1
# train=970, test=1
# train=971, test=1
# train=972, test=1
# train=973, test=1
# train=974, test=1
# train=975, test=1
# train=976, test=1
# train=977, test=1
# train=978, test=1
# train=979, test=1
# train=980, test=1
# train=981, test=1
# train=982, test=1
# train=983, test=1
# train=984, test=1
# train=985, test=1
# train=986, test=1
# train=987, test=1
# train=988, test=1
# train=989, test=1
# train=990, test=1
# train=991, test=1
# train=992, test=1
# train=993, test=1
# train=994, test=1
# train=995, test=1
# train=996, test=1
# train=997, test=1
# train=998, test=1
# train=999, test=1
# train=1000, test=1
# train=1001, test=1
# train=1002, test=1
# train=1003, test=1
# train=1004, test=1
# train=1005, test=1
# train=1006, test=1
# train=1007, test=1
# train=1008, test=1
# train=1009, test=1
# train=1010, test=1
# train=1011, test=1
# train=1012, test=1
# train=1013, test=1
# train=1014, test=1
# train=1015, test=1
# train=1016, test=1
# train=1017, test=1
# train=1018, test=1
# train=1019, test=1
# train=1020, test=1
# train=1021, test=1
# train=1022, test=1
# train=1023, test=1
# train=1024, test=1
# train=1025, test=1
# train=1026, test=1
# train=1027, test=1
# train=1028, test=1
# train=1029, test=1
# train=1030, test=1
# train=1031, test=1
# train=1032, test=1
# train=1033, test=1
# train=1034, test=1
# train=1035, test=1
# train=1036, test=1
# train=1037, test=1
# train=1038, test=1
# train=1039, test=1
# train=1040, test=1
# train=1041, test=1
# train=1042, test=1
# train=1043, test=1
# train=1044, test=1
# train=1045, test=1
# train=1046, test=1
# train=1047, test=1
# train=1048, test=1
# train=1049, test=1
# train=1050, test=1
# train=1051, test=1
# train=1052, test=1
# train=1053, test=1
# train=1054, test=1
# train=1055, test=1
# train=1056, test=1
# train=1057, test=1
# train=1058, test=1
# train=1059, test=1
# train=1060, test=1
# train=1061, test=1
# train=1062, test=1
# train=1063, test=1
# train=1064, test=1
# train=1065, test=1
# train=1066, test=1
# train=1067, test=1
# train=1068, test=1
# train=1069, test=1
# train=1070, test=1
# train=1071, test=1
# train=1072, test=1
# train=1073, test=1
# train=1074, test=1
# train=1075, test=1
# train=1076, test=1
# train=1077, test=1
# train=1078, test=1
# train=1079, test=1
# train=1080, test=1
# train=1081, test=1
# train=1082, test=1
# train=1083, test=1
# train=1084, test=1
# train=1085, test=1
# train=1086, test=1
# train=1087, test=1
# train=1088, test=1
# train=1089, test=1
# train=1090, test=1
# train=1091, test=1
# train=1092, test=1
# train=1093, test=1
# train=1094, test=1
# train=1095, test=1
# train=1096, test=1
# train=1097, test=1
# train=1098, test=1
# train=1099, test=1
# train=1100, test=1
# train=1101, test=1
# train=1102, test=1
# train=1103, test=1
# train=1104, test=1
# train=1105, test=1
# train=1106, test=1
# train=1107, test=1
# train=1108, test=1
# train=1109, test=1
# train=1110, test=1
# train=1111, test=1
# train=1112, test=1
# train=1113, test=1
# train=1114, test=1
# train=1115, test=1
# train=1116, test=1
# train=1117, test=1
# train=1118, test=1
# train=1119, test=1
# train=1120, test=1
# train=1121, test=1
# train=1122, test=1
# train=1123, test=1
# train=1124, test=1
# train=1125, test=1
# train=1126, test=1
# train=1127, test=1
# train=1128, test=1
# train=1129, test=1
# train=1130, test=1
# train=1131, test=1
# train=1132, test=1
# train=1133, test=1
# train=1134, test=1
# train=1135, test=1
# train=1136, test=1
# train=1137, test=1
# train=1138, test=1
# train=1139, test=1
# train=1140, test=1
# train=1141, test=1
# train=1142, test=1
# train=1143, test=1
# train=1144, test=1
# train=1145, test=1
# train=1146, test=1
# train=1147, test=1
# train=1148, test=1
# train=1149, test=1
# train=1150, test=1
# train=1151, test=1
# train=1152, test=1
# train=1153, test=1
# train=1154, test=1
# train=1155, test=1
# train=1156, test=1
# train=1157, test=1
# train=1158, test=1
# train=1159, test=1
# train=1160, test=1
# train=1161, test=1
# train=1162, test=1
# train=1163, test=1
# train=1164, test=1
# train=1165, test=1
# train=1166, test=1
# train=1167, test=1
# train=1168, test=1
# train=1169, test=1
# train=1170, test=1
# train=1171, test=1
# train=1172, test=1
# train=1173, test=1
# train=1174, test=1
# train=1175, test=1
# train=1176, test=1
# train=1177, test=1
# train=1178, test=1
# train=1179, test=1
# train=1180, test=1
# train=1181, test=1
# train=1182, test=1
# train=1183, test=1
# train=1184, test=1
# train=1185, test=1
# train=1186, test=1
# train=1187, test=1
# train=1188, test=1
# train=1189, test=1
# train=1190, test=1
# train=1191, test=1
# train=1192, test=1
# train=1193, test=1
# train=1194, test=1
# train=1195, test=1
# train=1196, test=1
# train=1197, test=1
# train=1198, test=1
# train=1199, test=1
# train=1200, test=1
# train=1201, test=1
# train=1202, test=1
# train=1203, test=1
# train=1204, test=1
# train=1205, test=1
# train=1206, test=1
# train=1207, test=1
# train=1208, test=1
# train=1209, test=1
# train=1210, test=1
# train=1211, test=1
# train=1212, test=1
# train=1213, test=1
# train=1214, test=1
# train=1215, test=1
# train=1216, test=1
# train=1217, test=1
# train=1218, test=1
# train=1219, test=1
# train=1220, test=1
# train=1221, test=1
# train=1222, test=1
# train=1223, test=1
# train=1224, test=1
# train=1225, test=1
# train=1226, test=1
# train=1227, test=1
# train=1228, test=1
# train=1229, test=1
# train=1230, test=1
# train=1231, test=1
# train=1232, test=1
# train=1233, test=1
# train=1234, test=1
# train=1235, test=1
# train=1236, test=1
# train=1237, test=1
# train=1238, test=1
# train=1239, test=1
# train=1240, test=1
# train=1241, test=1
# train=1242, test=1
# train=1243, test=1
# train=1244, test=1
# train=1245, test=1
# train=1246, test=1
# train=1247, test=1
# train=1248, test=1
# train=1249, test=1
# train=1250, test=1
# train=1251, test=1
# train=1252, test=1
# train=1253, test=1
# train=1254, test=1
# train=1255, test=1
# train=1256, test=1
# train=1257, test=1
# train=1258, test=1
# train=1259, test=1
# train=1260, test=1
# train=1261, test=1
# train=1262, test=1
# train=1263, test=1
# train=1264, test=1
# train=1265, test=1
# train=1266, test=1
# train=1267, test=1
# train=1268, test=1
# train=1269, test=1
# train=1270, test=1
# train=1271, test=1
# train=1272, test=1
# train=1273, test=1
# train=1274, test=1
# train=1275, test=1
# train=1276, test=1
# train=1277, test=1
# train=1278, test=1
# train=1279, test=1
# train=1280, test=1
# train=1281, test=1
# train=1282, test=1
# train=1283, test=1
# train=1284, test=1
# train=1285, test=1
# train=1286, test=1
# train=1287, test=1
# train=1288, test=1
# train=1289, test=1
# train=1290, test=1
# train=1291, test=1
# train=1292, test=1
# train=1293, test=1
# train=1294, test=1
# train=1295, test=1
# train=1296, test=1
# train=1297, test=1
# train=1298, test=1
# train=1299, test=1
# train=1300, test=1
# train=1301, test=1
# train=1302, test=1
# train=1303, test=1
# train=1304, test=1
# train=1305, test=1
# train=1306, test=1
# train=1307, test=1
# train=1308, test=1
# train=1309, test=1
# train=1310, test=1
# train=1311, test=1
# train=1312, test=1
# train=1313, test=1
# train=1314, test=1
# train=1315, test=1
# train=1316, test=1
# train=1317, test=1
# train=1318, test=1
# train=1319, test=1
# train=1320, test=1
# train=1321, test=1
# train=1322, test=1
# train=1323, test=1
# train=1324, test=1
# train=1325, test=1
# train=1326, test=1
# train=1327, test=1
# train=1328, test=1
# train=1329, test=1
# train=1330, test=1
# train=1331, test=1
# train=1332, test=1
# train=1333, test=1
# train=1334, test=1
# train=1335, test=1
# train=1336, test=1
# train=1337, test=1
# train=1338, test=1
# train=1339, test=1
# train=1340, test=1
# train=1341, test=1
# train=1342, test=1
# train=1343, test=1
# train=1344, test=1
# train=1345, test=1
# train=1346, test=1
# train=1347, test=1
# train=1348, test=1
# train=1349, test=1
# train=1350, test=1
# train=1351, test=1
# train=1352, test=1
# train=1353, test=1
# train=1354, test=1
# train=1355, test=1
# train=1356, test=1
# train=1357, test=1
# train=1358, test=1
# train=1359, test=1
# train=1360, test=1
# train=1361, test=1
# train=1362, test=1
# train=1363, test=1
# train=1364, test=1
# train=1365, test=1
# train=1366, test=1
# train=1367, test=1
# train=1368, test=1
# train=1369, test=1
# train=1370, test=1
# train=1371, test=1
# train=1372, test=1
# train=1373, test=1
# train=1374, test=1
# train=1375, test=1
# train=1376, test=1
# train=1377, test=1
# train=1378, test=1
# train=1379, test=1
# train=1380, test=1
# train=1381, test=1
# train=1382, test=1
# train=1383, test=1
# train=1384, test=1
# train=1385, test=1
# train=1386, test=1
# train=1387, test=1
# train=1388, test=1
# train=1389, test=1
# train=1390, test=1
# train=1391, test=1
# train=1392, test=1
# train=1393, test=1
# train=1394, test=1
# train=1395, test=1
# train=1396, test=1
# train=1397, test=1
# train=1398, test=1
# train=1399, test=1
# train=1400, test=1
# train=1401, test=1
# train=1402, test=1
# train=1403, test=1
# train=1404, test=1
# train=1405, test=1
# train=1406, test=1
# train=1407, test=1
# train=1408, test=1
# train=1409, test=1
# train=1410, test=1
# train=1411, test=1
# train=1412, test=1
# train=1413, test=1
# train=1414, test=1
# train=1415, test=1
# train=1416, test=1
# train=1417, test=1
# train=1418, test=1
# train=1419, test=1
# train=1420, test=1
# train=1421, test=1
# train=1422, test=1
# train=1423, test=1
# train=1424, test=1
# train=1425, test=1
# train=1426, test=1
# train=1427, test=1
# train=1428, test=1
# train=1429, test=1
# train=1430, test=1
# train=1431, test=1
# train=1432, test=1
# train=1433, test=1
# train=1434, test=1
# train=1435, test=1
# train=1436, test=1
# train=1437, test=1
# train=1438, test=1
# train=1439, test=1
# train=1440, test=1
# train=1441, test=1
# train=1442, test=1
# train=1443, test=1
# train=1444, test=1
# train=1445, test=1
# train=1446, test=1
# train=1447, test=1
# train=1448, test=1
# train=1449, test=1
# train=1450, test=1
# train=1451, test=1
# train=1452, test=1
# train=1453, test=1
# train=1454, test=1
# train=1455, test=1
# train=1456, test=1
# train=1457, test=1
# train=1458, test=1
# train=1459, test=1
# train=1460, test=1
# train=1461, test=1
# train=1462, test=1
# train=1463, test=1
# train=1464, test=1
# train=1465, test=1
# train=1466, test=1
# train=1467, test=1
# train=1468, test=1
# train=1469, test=1
# train=1470, test=1
# train=1471, test=1
# train=1472, test=1
# train=1473, test=1
# train=1474, test=1
# train=1475, test=1
# train=1476, test=1
# train=1477, test=1
# train=1478, test=1
# train=1479, test=1
# train=1480, test=1
# train=1481, test=1
# train=1482, test=1
# train=1483, test=1
# train=1484, test=1
# train=1485, test=1
# train=1486, test=1
# train=1487, test=1
# train=1488, test=1
# train=1489, test=1
# train=1490, test=1
# train=1491, test=1
# train=1492, test=1
# train=1493, test=1
# train=1494, test=1
# train=1495, test=1
# train=1496, test=1
# train=1497, test=1
# train=1498, test=1
# train=1499, test=1
# train=1500, test=1
# train=1501, test=1
# train=1502, test=1
# train=1503, test=1
# train=1504, test=1
# train=1505, test=1
# train=1506, test=1
# train=1507, test=1
# train=1508, test=1
# train=1509, test=1
# train=1510, test=1
# train=1511, test=1
# train=1512, test=1
# train=1513, test=1
# train=1514, test=1
# train=1515, test=1
# train=1516, test=1
# train=1517, test=1
# train=1518, test=1
# train=1519, test=1
# train=1520, test=1
# train=1521, test=1
# train=1522, test=1
# train=1523, test=1
# train=1524, test=1
# train=1525, test=1
# train=1526, test=1
# train=1527, test=1
# train=1528, test=1
# train=1529, test=1
# train=1530, test=1
# train=1531, test=1
# train=1532, test=1
# train=1533, test=1
# train=1534, test=1
# train=1535, test=1
# train=1536, test=1
# train=1537, test=1
# train=1538, test=1
# train=1539, test=1
# train=1540, test=1
# train=1541, test=1
# train=1542, test=1
# train=1543, test=1
# train=1544, test=1
# train=1545, test=1
# train=1546, test=1
# train=1547, test=1
# train=1548, test=1
# train=1549, test=1
# train=1550, test=1
# train=1551, test=1
# train=1552, test=1
# train=1553, test=1
# train=1554, test=1
# train=1555, test=1
# train=1556, test=1
# train=1557, test=1
# train=1558, test=1
# train=1559, test=1
# train=1560, test=1
# train=1561, test=1
# train=1562, test=1
# train=1563, test=1
# train=1564, test=1
# train=1565, test=1
# train=1566, test=1
# train=1567, test=1
# train=1568, test=1
# train=1569, test=1
# train=1570, test=1
# train=1571, test=1
# train=1572, test=1
# train=1573, test=1
# train=1574, test=1
# train=1575, test=1
# train=1576, test=1
# train=1577, test=1
# train=1578, test=1
# train=1579, test=1
# train=1580, test=1
# train=1581, test=1
# train=1582, test=1
# train=1583, test=1
# train=1584, test=1
# train=1585, test=1
# train=1586, test=1
# train=1587, test=1
# train=1588, test=1
# train=1589, test=1
# train=1590, test=1
# train=1591, test=1
# train=1592, test=1
# train=1593, test=1
# train=1594, test=1
# train=1595, test=1
# train=1596, test=1
# train=1597, test=1
# train=1598, test=1
# train=1599, test=1
# train=1600, test=1
# train=1601, test=1
# train=1602, test=1
# train=1603, test=1
# train=1604, test=1
# train=1605, test=1
# train=1606, test=1
# train=1607, test=1
# train=1608, test=1
# train=1609, test=1
# train=1610, test=1
# train=1611, test=1
# train=1612, test=1
# train=1613, test=1
# train=1614, test=1
# train=1615, test=1
# train=1616, test=1
# train=1617, test=1
# train=1618, test=1
# train=1619, test=1
# train=1620, test=1
# train=1621, test=1
# train=1622, test=1
# train=1623, test=1
# train=1624, test=1
# train=1625, test=1
# train=1626, test=1
# train=1627, test=1
# train=1628, test=1
# train=1629, test=1
# train=1630, test=1
# train=1631, test=1
# train=1632, test=1
# train=1633, test=1
# train=1634, test=1
# train=1635, test=1
# train=1636, test=1
# train=1637, test=1
# train=1638, test=1
# train=1639, test=1
# train=1640, test=1
# train=1641, test=1
# train=1642, test=1
# train=1643, test=1
# train=1644, test=1
# train=1645, test=1
# train=1646, test=1
# train=1647, test=1
# train=1648, test=1
# train=1649, test=1
# train=1650, test=1
# train=1651, test=1
# train=1652, test=1
# train=1653, test=1
# train=1654, test=1
# train=1655, test=1
# train=1656, test=1
# train=1657, test=1
# train=1658, test=1
# train=1659, test=1
# train=1660, test=1
# train=1661, test=1
# train=1662, test=1
# train=1663, test=1
# train=1664, test=1
# train=1665, test=1
# train=1666, test=1
# train=1667, test=1
# train=1668, test=1
# train=1669, test=1
# train=1670, test=1
# train=1671, test=1
# train=1672, test=1
# train=1673, test=1
# train=1674, test=1
# train=1675, test=1
# train=1676, test=1
# train=1677, test=1
# train=1678, test=1
# train=1679, test=1
# train=1680, test=1
# train=1681, test=1
# train=1682, test=1
# train=1683, test=1
# train=1684, test=1
# train=1685, test=1
# train=1686, test=1
# train=1687, test=1
# train=1688, test=1
# train=1689, test=1
# train=1690, test=1
# train=1691, test=1
# train=1692, test=1
# train=1693, test=1
# train=1694, test=1
# train=1695, test=1
# train=1696, test=1
# train=1697, test=1
# train=1698, test=1
# train=1699, test=1
# train=1700, test=1
# train=1701, test=1
# train=1702, test=1
# train=1703, test=1
# train=1704, test=1
# train=1705, test=1
# train=1706, test=1
# train=1707, test=1
# train=1708, test=1
# train=1709, test=1
# train=1710, test=1
# train=1711, test=1
# train=1712, test=1
# train=1713, test=1
# train=1714, test=1
# train=1715, test=1
# train=1716, test=1
# train=1717, test=1
# train=1718, test=1
# train=1719, test=1
# train=1720, test=1
# train=1721, test=1
# train=1722, test=1
# train=1723, test=1
# train=1724, test=1
# train=1725, test=1
# train=1726, test=1
# train=1727, test=1
# train=1728, test=1
# train=1729, test=1
# train=1730, test=1
# train=1731, test=1
# train=1732, test=1
# train=1733, test=1
# train=1734, test=1
# train=1735, test=1
# train=1736, test=1
# train=1737, test=1
# train=1738, test=1
# train=1739, test=1
# train=1740, test=1
# train=1741, test=1
# train=1742, test=1
# train=1743, test=1
# train=1744, test=1
# train=1745, test=1
# train=1746, test=1
# train=1747, test=1
# train=1748, test=1
# train=1749, test=1
# train=1750, test=1
# train=1751, test=1
# train=1752, test=1
# train=1753, test=1
# train=1754, test=1
# train=1755, test=1
# train=1756, test=1
# train=1757, test=1
# train=1758, test=1
# train=1759, test=1
# train=1760, test=1
# train=1761, test=1
# train=1762, test=1
# train=1763, test=1
# train=1764, test=1
# train=1765, test=1
# train=1766, test=1
# train=1767, test=1
# train=1768, test=1
# train=1769, test=1
# train=1770, test=1
# train=1771, test=1
# train=1772, test=1
# train=1773, test=1
# train=1774, test=1
# train=1775, test=1
# train=1776, test=1
# train=1777, test=1
# train=1778, test=1
# train=1779, test=1
# train=1780, test=1
# train=1781, test=1
# train=1782, test=1
# train=1783, test=1
# train=1784, test=1
# train=1785, test=1
# train=1786, test=1
# train=1787, test=1
# train=1788, test=1
# train=1789, test=1
# train=1790, test=1
# train=1791, test=1
# train=1792, test=1
# train=1793, test=1
# train=1794, test=1
# train=1795, test=1
# train=1796, test=1
# train=1797, test=1
# train=1798, test=1
# train=1799, test=1
# train=1800, test=1
# train=1801, test=1
# train=1802, test=1
# train=1803, test=1
# train=1804, test=1
# train=1805, test=1
# train=1806, test=1
# train=1807, test=1
# train=1808, test=1
# train=1809, test=1
# train=1810, test=1
# train=1811, test=1
# train=1812, test=1
# train=1813, test=1
# train=1814, test=1
# train=1815, test=1
# train=1816, test=1
# train=1817, test=1
# train=1818, test=1
# train=1819, test=1
# train=1820, test=1
# train=1821, test=1
# train=1822, test=1
# train=1823, test=1
# train=1824, test=1
# train=1825, test=1
# train=1826, test=1
# train=1827, test=1
# train=1828, test=1
# train=1829, test=1
# train=1830, test=1
# train=1831, test=1
# train=1832, test=1
# train=1833, test=1
# train=1834, test=1
# train=1835, test=1
# train=1836, test=1
# train=1837, test=1
# train=1838, test=1
# train=1839, test=1
# train=1840, test=1
# train=1841, test=1
# train=1842, test=1
# train=1843, test=1
# train=1844, test=1
# train=1845, test=1
# train=1846, test=1
# train=1847, test=1
# train=1848, test=1
# train=1849, test=1
# train=1850, test=1
# train=1851, test=1
# train=1852, test=1
# train=1853, test=1
# train=1854, test=1
# train=1855, test=1
# train=1856, test=1
# train=1857, test=1
# train=1858, test=1
# train=1859, test=1
# train=1860, test=1
# train=1861, test=1
# train=1862, test=1
# train=1863, test=1
# train=1864, test=1
# train=1865, test=1
# train=1866, test=1
# train=1867, test=1
# train=1868, test=1
# train=1869, test=1
# train=1870, test=1
# train=1871, test=1
# train=1872, test=1
# train=1873, test=1
# train=1874, test=1
# train=1875, test=1
# train=1876, test=1
# train=1877, test=1
# train=1878, test=1
# train=1879, test=1
# train=1880, test=1
# train=1881, test=1
# train=1882, test=1
# train=1883, test=1
# train=1884, test=1
# train=1885, test=1
# train=1886, test=1
# train=1887, test=1
# train=1888, test=1
# train=1889, test=1
# train=1890, test=1
# train=1891, test=1
# train=1892, test=1
# train=1893, test=1
# train=1894, test=1
# train=1895, test=1
# train=1896, test=1
# train=1897, test=1
# train=1898, test=1
# train=1899, test=1
# train=1900, test=1
# train=1901, test=1
# train=1902, test=1
# train=1903, test=1
# train=1904, test=1
# train=1905, test=1
# train=1906, test=1
# train=1907, test=1
# train=1908, test=1
# train=1909, test=1
# train=1910, test=1
# train=1911, test=1
# train=1912, test=1
# train=1913, test=1
# train=1914, test=1
# train=1915, test=1
# train=1916, test=1
# train=1917, test=1
# train=1918, test=1
# train=1919, test=1
# train=1920, test=1
# train=1921, test=1
# train=1922, test=1
# train=1923, test=1
# train=1924, test=1
# train=1925, test=1
# train=1926, test=1
# train=1927, test=1
# train=1928, test=1
# train=1929, test=1
# train=1930, test=1
# train=1931, test=1
# train=1932, test=1
# train=1933, test=1
# train=1934, test=1
# train=1935, test=1
# train=1936, test=1
# train=1937, test=1
# train=1938, test=1
# train=1939, test=1
# train=1940, test=1
# train=1941, test=1
# train=1942, test=1
# train=1943, test=1
# train=1944, test=1
# train=1945, test=1
# train=1946, test=1
# train=1947, test=1
# train=1948, test=1
# train=1949, test=1
# train=1950, test=1
# train=1951, test=1
# train=1952, test=1
# train=1953, test=1
# train=1954, test=1
# train=1955, test=1
# train=1956, test=1
# train=1957, test=1
# train=1958, test=1
# train=1959, test=1
# train=1960, test=1
# train=1961, test=1
# train=1962, test=1
# train=1963, test=1
# train=1964, test=1
# train=1965, test=1
# train=1966, test=1
# train=1967, test=1
# train=1968, test=1
# train=1969, test=1
# train=1970, test=1
# train=1971, test=1
# train=1972, test=1
# train=1973, test=1
# train=1974, test=1
# train=1975, test=1
# train=1976, test=1
# train=1977, test=1
# train=1978, test=1
# train=1979, test=1
# train=1980, test=1
# train=1981, test=1
# train=1982, test=1
# train=1983, test=1
# train=1984, test=1
# train=1985, test=1
# train=1986, test=1
# train=1987, test=1
# train=1988, test=1
# train=1989, test=1
# train=1990, test=1
# train=1991, test=1
# train=1992, test=1
# train=1993, test=1
# train=1994, test=1
# train=1995, test=1
# train=1996, test=1
# train=1997, test=1
# train=1998, test=1
# train=1999, test=1
# train=2000, test=1
# train=2001, test=1
# train=2002, test=1
# train=2003, test=1
# train=2004, test=1
# train=2005, test=1
# train=2006, test=1
# train=2007, test=1
# train=2008, test=1
# train=2009, test=1
# train=2010, test=1
# train=2011, test=1
# train=2012, test=1
# train=2013, test=1
# train=2014, test=1
# train=2015, test=1
# train=2016, test=1
# train=2017, test=1
# train=2018, test=1
# train=2019, test=1
# train=2020, test=1
# train=2021, test=1
# train=2022, test=1
# train=2023, test=1
# train=2024, test=1
# train=2025, test=1
# train=2026, test=1
# train=2027, test=1
# train=2028, test=1
# train=2029, test=1
# train=2030, test=1
# train=2031, test=1
# train=2032, test=1
# train=2033, test=1
# train=2034, test=1
# train=2035, test=1
# train=2036, test=1
# train=2037, test=1
# train=2038, test=1
# train=2039, test=1
# train=2040, test=1
# train=2041, test=1
# train=2042, test=1
# train=2043, test=1
# train=2044, test=1
# train=2045, test=1
# train=2046, test=1
# train=2047, test=1
# train=2048, test=1
# train=2049, test=1
# train=2050, test=1
# train=2051, test=1
# train=2052, test=1
# train=2053, test=1
# train=2054, test=1
# train=2055, test=1
# train=2056, test=1
# train=2057, test=1
# train=2058, test=1
# train=2059, test=1
# train=2060, test=1
# train=2061, test=1
# train=2062, test=1
# train=2063, test=1
# train=2064, test=1
# train=2065, test=1
# train=2066, test=1
# train=2067, test=1
# train=2068, test=1
# train=2069, test=1
# train=2070, test=1
# train=2071, test=1
# train=2072, test=1
# train=2073, test=1
# train=2074, test=1
# train=2075, test=1
# train=2076, test=1
# train=2077, test=1
# train=2078, test=1
# train=2079, test=1
# train=2080, test=1
# train=2081, test=1
# train=2082, test=1
# train=2083, test=1
# train=2084, test=1
# train=2085, test=1
# train=2086, test=1
# train=2087, test=1
# train=2088, test=1
# train=2089, test=1
# train=2090, test=1
# train=2091, test=1
# train=2092, test=1
# train=2093, test=1
# train=2094, test=1
# train=2095, test=1
# train=2096, test=1
# train=2097, test=1
# train=2098, test=1
# train=2099, test=1
# train=2100, test=1
# train=2101, test=1
# train=2102, test=1
# train=2103, test=1
# train=2104, test=1
# train=2105, test=1
# train=2106, test=1
# train=2107, test=1
# train=2108, test=1
# train=2109, test=1
# train=2110, test=1
# train=2111, test=1
# train=2112, test=1
# train=2113, test=1
# train=2114, test=1
# train=2115, test=1
# train=2116, test=1
# train=2117, test=1
# train=2118, test=1
# train=2119, test=1
# train=2120, test=1
# train=2121, test=1
# train=2122, test=1
# train=2123, test=1
# train=2124, test=1
# train=2125, test=1
# train=2126, test=1
# train=2127, test=1
# train=2128, test=1
# train=2129, test=1
# train=2130, test=1
# train=2131, test=1
# train=2132, test=1
# train=2133, test=1
# train=2134, test=1
# train=2135, test=1
# train=2136, test=1
# train=2137, test=1
# train=2138, test=1
# train=2139, test=1
# train=2140, test=1
# train=2141, test=1
# train=2142, test=1
# train=2143, test=1
# train=2144, test=1
# train=2145, test=1
# train=2146, test=1
# train=2147, test=1
# train=2148, test=1
# train=2149, test=1
# train=2150, test=1
# train=2151, test=1
# train=2152, test=1
# train=2153, test=1
# train=2154, test=1
# train=2155, test=1
# train=2156, test=1
# train=2157, test=1
# train=2158, test=1
# train=2159, test=1
# train=2160, test=1
# train=2161, test=1
# train=2162, test=1
# train=2163, test=1
# train=2164, test=1
# train=2165, test=1
# train=2166, test=1
# train=2167, test=1
# train=2168, test=1
# train=2169, test=1
# train=2170, test=1
# train=2171, test=1
# train=2172, test=1
# train=2173, test=1
# train=2174, test=1
# train=2175, test=1
# train=2176, test=1
# train=2177, test=1
# train=2178, test=1
# train=2179, test=1
# train=2180, test=1
# train=2181, test=1
# train=2182, test=1
# train=2183, test=1
# train=2184, test=1
# train=2185, test=1
# train=2186, test=1
# train=2187, test=1
# train=2188, test=1
# train=2189, test=1
# train=2190, test=1
# train=2191, test=1
# train=2192, test=1
# train=2193, test=1
# train=2194, test=1
# train=2195, test=1
# train=2196, test=1
# train=2197, test=1
# train=2198, test=1
# train=2199, test=1
# train=2200, test=1
# train=2201, test=1
# train=2202, test=1
# train=2203, test=1
# train=2204, test=1
# train=2205, test=1
# train=2206, test=1
# train=2207, test=1
# train=2208, test=1
# train=2209, test=1
# train=2210, test=1
# train=2211, test=1
# train=2212, test=1
# train=2213, test=1
# train=2214, test=1
# train=2215, test=1
# train=2216, test=1
# train=2217, test=1
# train=2218, test=1
# train=2219, test=1
# train=2220, test=1
# train=2221, test=1
# train=2222, test=1
# train=2223, test=1
# train=2224, test=1
# train=2225, test=1
# train=2226, test=1
# train=2227, test=1
# train=2228, test=1
# train=2229, test=1
# train=2230, test=1
# train=2231, test=1
# train=2232, test=1
# train=2233, test=1
# train=2234, test=1
# train=2235, test=1
# train=2236, test=1
# train=2237, test=1
# train=2238, test=1
# train=2239, test=1
# train=2240, test=1
# train=2241, test=1
# train=2242, test=1
# train=2243, test=1
# train=2244, test=1
# train=2245, test=1
# train=2246, test=1
# train=2247, test=1
# train=2248, test=1
# train=2249, test=1
# train=2250, test=1
# train=2251, test=1
# train=2252, test=1
# train=2253, test=1
# train=2254, test=1
# train=2255, test=1
# train=2256, test=1
# train=2257, test=1
# train=2258, test=1
# train=2259, test=1
# train=2260, test=1
# train=2261, test=1
# train=2262, test=1
# train=2263, test=1
# train=2264, test=1
# train=2265, test=1
# train=2266, test=1
# train=2267, test=1
# train=2268, test=1
# train=2269, test=1
# train=2270, test=1
# train=2271, test=1
# train=2272, test=1
# train=2273, test=1
# train=2274, test=1
# train=2275, test=1
# train=2276, test=1
# train=2277, test=1
# train=2278, test=1
# train=2279, test=1
# train=2280, test=1
# train=2281, test=1
# train=2282, test=1
# train=2283, test=1
# train=2284, test=1
# train=2285, test=1
# train=2286, test=1
# train=2287, test=1
# train=2288, test=1
# train=2289, test=1
# train=2290, test=1
# train=2291, test=1
# train=2292, test=1
# train=2293, test=1
# train=2294, test=1
# train=2295, test=1
# train=2296, test=1
# train=2297, test=1
# train=2298, test=1
# train=2299, test=1
# train=2300, test=1
# train=2301, test=1
# train=2302, test=1
# train=2303, test=1
# train=2304, test=1
# train=2305, test=1
# train=2306, test=1
# train=2307, test=1
# train=2308, test=1
# train=2309, test=1
# train=2310, test=1
# train=2311, test=1
# train=2312, test=1
# train=2313, test=1
# train=2314, test=1
# train=2315, test=1
# train=2316, test=1
# train=2317, test=1
# train=2318, test=1
# train=2319, test=1
# train=2320, test=1
# train=2321, test=1
# train=2322, test=1
# train=2323, test=1
# train=2324, test=1
# train=2325, test=1
# train=2326, test=1
# train=2327, test=1
# train=2328, test=1
# train=2329, test=1
# train=2330, test=1
# train=2331, test=1
# train=2332, test=1
# train=2333, test=1
# train=2334, test=1
# train=2335, test=1
# train=2336, test=1
# train=2337, test=1
# train=2338, test=1
# train=2339, test=1
# train=2340, test=1
# train=2341, test=1
# train=2342, test=1
# train=2343, test=1
# train=2344, test=1
# train=2345, test=1
# train=2346, test=1
# train=2347, test=1
# train=2348, test=1
# train=2349, test=1
# train=2350, test=1
# train=2351, test=1
# train=2352, test=1
# train=2353, test=1
# train=2354, test=1
# train=2355, test=1
# train=2356, test=1
# train=2357, test=1
# train=2358, test=1
# train=2359, test=1
# train=2360, test=1
# train=2361, test=1
# train=2362, test=1
# train=2363, test=1
# train=2364, test=1
# train=2365, test=1
# train=2366, test=1
# train=2367, test=1
# train=2368, test=1
# train=2369, test=1
# train=2370, test=1
# train=2371, test=1
# train=2372, test=1
# train=2373, test=1
# train=2374, test=1
# train=2375, test=1
# train=2376, test=1
# train=2377, test=1
# train=2378, test=1
# train=2379, test=1
# train=2380, test=1
# train=2381, test=1
# train=2382, test=1
# train=2383, test=1
# train=2384, test=1
# train=2385, test=1
# train=2386, test=1
# train=2387, test=1
# train=2388, test=1
# train=2389, test=1
# train=2390, test=1
# train=2391, test=1
# train=2392, test=1
# train=2393, test=1
# train=2394, test=1
# train=2395, test=1
# train=2396, test=1
# train=2397, test=1
# train=2398, test=1
# train=2399, test=1
# train=2400, test=1
# train=2401, test=1
# train=2402, test=1
# train=2403, test=1
# train=2404, test=1
# train=2405, test=1
# train=2406, test=1
# train=2407, test=1
# train=2408, test=1
# train=2409, test=1
# train=2410, test=1
# train=2411, test=1
# train=2412, test=1
# train=2413, test=1
# train=2414, test=1
# train=2415, test=1
# train=2416, test=1
# train=2417, test=1
# train=2418, test=1
# train=2419, test=1
# train=2420, test=1
# train=2421, test=1
# train=2422, test=1
# train=2423, test=1
# train=2424, test=1
# train=2425, test=1
# train=2426, test=1
# train=2427, test=1
# train=2428, test=1
# train=2429, test=1
# train=2430, test=1
# train=2431, test=1
# train=2432, test=1
# train=2433, test=1
# train=2434, test=1
# train=2435, test=1
# train=2436, test=1
# train=2437, test=1
# train=2438, test=1
# train=2439, test=1
# train=2440, test=1
# train=2441, test=1
# train=2442, test=1
# train=2443, test=1
# train=2444, test=1
# train=2445, test=1
# train=2446, test=1
# train=2447, test=1
# train=2448, test=1
# train=2449, test=1
# train=2450, test=1
# train=2451, test=1
# train=2452, test=1
# train=2453, test=1
# train=2454, test=1
# train=2455, test=1
# train=2456, test=1
# train=2457, test=1
# train=2458, test=1
# train=2459, test=1
# train=2460, test=1
# train=2461, test=1
# train=2462, test=1
# train=2463, test=1
# train=2464, test=1
# train=2465, test=1
# train=2466, test=1
# train=2467, test=1
# train=2468, test=1
# train=2469, test=1
# train=2470, test=1
# train=2471, test=1
# train=2472, test=1
# train=2473, test=1
# train=2474, test=1
# train=2475, test=1
# train=2476, test=1
# train=2477, test=1
# train=2478, test=1
# train=2479, test=1
# train=2480, test=1
# train=2481, test=1
# train=2482, test=1
# train=2483, test=1
# train=2484, test=1
# train=2485, test=1
# train=2486, test=1
# train=2487, test=1
# train=2488, test=1
# train=2489, test=1
# train=2490, test=1
# train=2491, test=1
# train=2492, test=1
# train=2493, test=1
# train=2494, test=1
# train=2495, test=1
# train=2496, test=1
# train=2497, test=1
# train=2498, test=1
# train=2499, test=1
# train=2500, test=1
# train=2501, test=1
# train=2502, test=1
# train=2503, test=1
# train=2504, test=1
# train=2505, test=1
# train=2506, test=1
# train=2507, test=1
# train=2508, test=1
# train=2509, test=1
# train=2510, test=1
# train=2511, test=1
# train=2512, test=1
# train=2513, test=1
# train=2514, test=1
# train=2515, test=1
# train=2516, test=1
# train=2517, test=1
# train=2518, test=1
# train=2519, test=1
# train=2520, test=1
# train=2521, test=1
# train=2522, test=1
# train=2523, test=1
# train=2524, test=1
# train=2525, test=1
# train=2526, test=1
# train=2527, test=1
# train=2528, test=1
# train=2529, test=1
# train=2530, test=1
# train=2531, test=1
# train=2532, test=1
# train=2533, test=1
# train=2534, test=1
# train=2535, test=1
# train=2536, test=1
# train=2537, test=1
# train=2538, test=1
# train=2539, test=1
# train=2540, test=1
# train=2541, test=1
# train=2542, test=1
# train=2543, test=1
# train=2544, test=1
# train=2545, test=1
# train=2546, test=1
# train=2547, test=1
# train=2548, test=1
# train=2549, test=1
# train=2550, test=1
# train=2551, test=1
# train=2552, test=1
# train=2553, test=1
# train=2554, test=1
# train=2555, test=1
# train=2556, test=1
# train=2557, test=1
# train=2558, test=1
# train=2559, test=1
# train=2560, test=1
# train=2561, test=1
# train=2562, test=1
# train=2563, test=1
# train=2564, test=1
# train=2565, test=1
# train=2566, test=1
# train=2567, test=1
# train=2568, test=1
# train=2569, test=1
# train=2570, test=1
# train=2571, test=1
# train=2572, test=1
# train=2573, test=1
# train=2574, test=1
# train=2575, test=1
# train=2576, test=1
# train=2577, test=1
# train=2578, test=1
# train=2579, test=1
# train=2580, test=1
# train=2581, test=1
# train=2582, test=1
# train=2583, test=1
# train=2584, test=1
# train=2585, test=1
# train=2586, test=1
# train=2587, test=1
# train=2588, test=1
# train=2589, test=1
# train=2590, test=1
# train=2591, test=1
# train=2592, test=1
# train=2593, test=1
# train=2594, test=1
# train=2595, test=1
# train=2596, test=1
# train=2597, test=1
# train=2598, test=1
# train=2599, test=1
# train=2600, test=1
# train=2601, test=1
# train=2602, test=1
# train=2603, test=1
# train=2604, test=1
# train=2605, test=1
# train=2606, test=1
# train=2607, test=1
# train=2608, test=1
# train=2609, test=1
# train=2610, test=1
# train=2611, test=1
# train=2612, test=1
# train=2613, test=1
# train=2614, test=1
# train=2615, test=1
# train=2616, test=1
# train=2617, test=1
# train=2618, test=1
# train=2619, test=1
# train=2620, test=1
# train=2621, test=1
# train=2622, test=1
# train=2623, test=1
# train=2624, test=1
# train=2625, test=1
# train=2626, test=1
# train=2627, test=1
# train=2628, test=1
# train=2629, test=1
# train=2630, test=1
# train=2631, test=1
# train=2632, test=1
# train=2633, test=1
# train=2634, test=1
# train=2635, test=1
# train=2636, test=1
# train=2637, test=1
# train=2638, test=1
# train=2639, test=1
# train=2640, test=1
# train=2641, test=1
# train=2642, test=1
# train=2643, test=1
# train=2644, test=1
# train=2645, test=1
# train=2646, test=1
# train=2647, test=1
# train=2648, test=1
# train=2649, test=1
# train=2650, test=1
# train=2651, test=1
# train=2652, test=1
# train=2653, test=1
# train=2654, test=1
# train=2655, test=1
# train=2656, test=1
# train=2657, test=1
# train=2658, test=1
# train=2659, test=1
# train=2660, test=1
# train=2661, test=1
# train=2662, test=1
# train=2663, test=1
# train=2664, test=1
# train=2665, test=1
# train=2666, test=1
# train=2667, test=1
# train=2668, test=1
# train=2669, test=1
# train=2670, test=1
# train=2671, test=1
# train=2672, test=1
# train=2673, test=1
# train=2674, test=1
# train=2675, test=1
# train=2676, test=1
# train=2677, test=1
# train=2678, test=1
# train=2679, test=1
# train=2680, test=1
# train=2681, test=1
# train=2682, test=1
# train=2683, test=1
# train=2684, test=1
# train=2685, test=1
# train=2686, test=1
# train=2687, test=1
# train=2688, test=1
# train=2689, test=1
# train=2690, test=1
# train=2691, test=1
# train=2692, test=1
# train=2693, test=1
# train=2694, test=1
# train=2695, test=1
# train=2696, test=1
# train=2697, test=1
# train=2698, test=1
# train=2699, test=1
# train=2700, test=1
# train=2701, test=1
# train=2702, test=1
# train=2703, test=1
# train=2704, test=1
# train=2705, test=1
# train=2706, test=1
# train=2707, test=1
# train=2708, test=1
# train=2709, test=1
# train=2710, test=1
# train=2711, test=1
# train=2712, test=1
# train=2713, test=1
# train=2714, test=1
# train=2715, test=1
# train=2716, test=1
# train=2717, test=1
# train=2718, test=1
# train=2719, test=1
# train=2720, test=1
# train=2721, test=1
# train=2722, test=1
# train=2723, test=1
# train=2724, test=1
# train=2725, test=1
# train=2726, test=1
# train=2727, test=1
# train=2728, test=1
# train=2729, test=1
# train=2730, test=1
# train=2731, test=1
# train=2732, test=1
# train=2733, test=1
# train=2734, test=1
# train=2735, test=1
# train=2736, test=1
# train=2737, test=1
# train=2738, test=1
# train=2739, test=1
# train=2740, test=1
# train=2741, test=1
# train=2742, test=1
# train=2743, test=1
# train=2744, test=1
# train=2745, test=1
# train=2746, test=1
# train=2747, test=1
# train=2748, test=1
# train=2749, test=1
# train=2750, test=1
# train=2751, test=1
# train=2752, test=1
# train=2753, test=1
# train=2754, test=1
# train=2755, test=1
# train=2756, test=1
# train=2757, test=1
# train=2758, test=1
# train=2759, test=1
# train=2760, test=1
# train=2761, test=1
# train=2762, test=1
# train=2763, test=1
# train=2764, test=1
# train=2765, test=1
# train=2766, test=1
# train=2767, test=1
# train=2768, test=1
# train=2769, test=1
# train=2770, test=1
# train=2771, test=1
# train=2772, test=1
# train=2773, test=1
# train=2774, test=1
# train=2775, test=1
# train=2776, test=1
# train=2777, test=1
# train=2778, test=1
# train=2779, test=1
# train=2780, test=1
# train=2781, test=1
# train=2782, test=1
# train=2783, test=1
# train=2784, test=1
# train=2785, test=1
# train=2786, test=1
# train=2787, test=1
# train=2788, test=1
# train=2789, test=1
# train=2790, test=1
# train=2791, test=1
# train=2792, test=1
# train=2793, test=1
# train=2794, test=1
# train=2795, test=1
# train=2796, test=1
# train=2797, test=1
# train=2798, test=1
# train=2799, test=1
# train=2800, test=1
# train=2801, test=1
# train=2802, test=1
# train=2803, test=1
# train=2804, test=1
# train=2805, test=1
# train=2806, test=1
# train=2807, test=1
# train=2808, test=1
# train=2809, test=1
# train=2810, test=1
# train=2811, test=1
# train=2812, test=1
# train=2813, test=1
# train=2814, test=1
# train=2815, test=1
# train=2816, test=1
# train=2817, test=1
# train=2818, test=1
# train=2819, test=1

# %% [markdown]
# How to Use and Remove Trend Information from Time Series Data in Python

# %% [markdown]
# Trends in Time Series: In general, a systematic change in a time series that does not appear to be periodic is known as a trend.

# %% [markdown]
# Types of Trends
#
# There are all kinds of trends.
#
# Two general classes that we may think about are:
#
#     Deterministic Trends: These are trends that consistently increase or decrease.
#     Stochastic Trends: These are trends that increase and decrease inconsistently.
#
# In general, deterministic trends are easier to identify and remove, but the methods discussed in this tutorial can still be useful for stochastic trends.
#
# We can think about trends in terms of their scope of observations.
#
#     Global Trends: These are trends that apply to the whole time series.
#     Local Trends: These are trends that apply to parts or subsequences of a time series.
#
# Generally, global trends are easier to identify and address.

# %% [markdown]
# Using Time Series Trends in Machine Learning
#
# From a machine learning perspective, a trend in your data represents two opportunities:
#
#     Remove Information: To remove systematic information that distorts the relationship between input and output variables.
#     Add Information: To add systematic information to improve the relationship between input and output variables.

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
series.plot()
pyplot.show()
# Out:
# <ipython-input-35-cb6cce8ab533>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %% [markdown]
# Detrend by Differencing

# %%
X = series.values
diff = list()
for i in range(1, len(X)):
	value = X[i] - X[i - 1]
	diff.append(value)
pyplot.plot(diff)
pyplot.show()

# %% [markdown]
# Detrend by Model Fitting

# %%
from pandas import read_csv
from pandas import datetime
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
import numpy
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# fit linear model
X = [i for i in range(0, len(series))]
X = numpy.reshape(X, (len(X), 1))
y = series.values
model = LinearRegression()
model.fit(X, y)
# calculate trend
trend = model.predict(X)
# plot trend
pyplot.plot(y)
pyplot.plot(trend)
pyplot.show()
# detrend
detrended = [y[i]-trend[i] for i in range(0, len(series))]
# plot detrended
pyplot.plot(detrended)
pyplot.show()
# Out:
# <ipython-input-38-c71d1c8f27f5>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %% [markdown]
# ### How to Identify and Remove Seasonality from Time Series Data with Python

# %% [markdown]
# Minimum Daily Temperatures Dataset

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('temperature_dataset.csv', header=0, index_col=0)
series.plot()
pyplot.show()

# %% [markdown]
# Seasonal Adjustment with Differencing

# %%
X = series.values
diff = list()
days_in_year = 365
for i in range(days_in_year, len(X)):
	value = X[i] - X[i - days_in_year]
	diff.append(value)
pyplot.plot(diff)
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('temperature_dataset.csv', header=0, index_col=0)
resample = series.resample('M')
monthly_mean = resample.mean()
print(monthly_mean.head(13))
monthly_mean.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-2a94637ac37f> in <module>
#       2 from matplotlib import pyplot
#       3 series = read_csv('temperature_dataset.csv', header=0, index_col=0)
# ----> 4 resample = series.resample('M')
#       5 monthly_mean = resample.mean()
#       6 print(monthly_mean.head(13))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1474             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1475
# -> 1476         raise TypeError(
#    1477             "Only valid with DatetimeIndex, "
#    1478             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %%
X = series.values
diff = list()
days_in_year = 365
for i in range(days_in_year, len(X)):
	month_str = str(series.index[i].year-1)+'-'+str(series.index[i].month)
	month_mean_last_year = series[month_str].mean()
	value = X[i] - month_mean_last_year
	diff.append(value)
pyplot.plot(diff)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-baefff97b9cc> in <module>
#       3 days_in_year = 365
#       4 for i in range(days_in_year, len(X)):
# ----> 5         month_str = str(series.index[i].year-1)+'-'+str(series.index[i].month)
#       6         month_mean_last_year = series[month_str].mean()
#       7         value = X[i] - month_mean_last_year
#
# AttributeError: 'str' object has no attribute 'year'

# %% [markdown]
# Seasonal Adjustment with Modeling

# %%
from pandas import read_csv
from matplotlib import pyplot
from numpy import polyfit
series = read_csv('temperature_dataset.csv', header=0, index_col=0)
# fit polynomial: x^2*b1 + x*b2 + ... + bn
X = [i%365 for i in range(0, len(series))]
y = series.values
degree = 4
coef = polyfit(X, y, degree)
print('Coefficients: %s' % coef)
# create curve
curve = list()
for i in range(len(X)):
	value = coef[-1]
	for d in range(degree):
		value += X[i]**(degree-d) * coef[d]
	curve.append(value)
# plot curve over original data
pyplot.plot(series.values)
pyplot.plot(curve, color='red', linewidth=3)
pyplot.show()
# Out:
# Coefficients: [[-1.17308000e-08]
#  [ 9.30253946e-06]
#  [-2.15977594e-03]
#  [ 1.19147966e-01]
#  [ 1.38980178e+01]]

# %%
# fit polynomial: x^2*b1 + x*b2 + ... + bn
X = [i%365 for i in range(0, len(series))]
y = series.values
degree = 4
coef = polyfit(X, y, degree)
print('Coefficients: %s' % coef)
# create curve
curve = list()
for i in range(len(X)):
	value = coef[-1]
	for d in range(degree):
		value += X[i]**(degree-d) * coef[d]
	curve.append(value)
# create seasonally adjusted
values = series.values
diff = list()
for i in range(len(values)):
	value = values[i] - curve[i]
	diff.append(value)
pyplot.plot(diff)
pyplot.show()
# Out:
# Coefficients: [[-1.17308000e-08]
#  [ 9.30253946e-06]
#  [-2.15977594e-03]
#  [ 1.19147966e-01]
#  [ 1.38980178e+01]]

# %% [markdown]
# ### How to Make Baseline Predictions for Time Series Forecasting with Python

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
series.plot()
pyplot.show()
# Out:
# <ipython-input-47-cb6cce8ab533>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
# Create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
print(dataframe.head(5))
# Out:
#      t-1    t+1
# 0    NaN  266.0
# 1  266.0  145.9
# 2  145.9  183.1
# 3  183.1  119.3
# 4  119.3  180.3

# %%
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
def model_persistence(x):
	return x

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# Create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
print(dataframe.head(5))
 
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
 
# persistence model
def model_persistence(x):
	return x
 
# walk-forward validation
predictions = list()
for x in test_X:
	yhat = model_persistence(x)
	predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print('Test MSE: %.3f' % test_score)
 
# plot predictions and expected results
pyplot.plot(train_y)
pyplot.plot([None for i in train_y] + [x for x in test_y])
pyplot.plot([None for i in train_y] + [x for x in predictions])
pyplot.show()
# Out:
# <ipython-input-52-e9500a7d0c83>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
#      t-1    t+1
# 0    NaN  266.0
# 1  266.0  145.9
# 2  145.9  183.1
# 3  183.1  119.3
# 4  119.3  180.3
# Test MSE: 17730.518

# %% [markdown]
# ### Moving Average Smoothing for Data Preparation and Time Series Forecasting in Python

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# Tail-rolling average transform
rolling = series.rolling(window=3)
rolling_mean = rolling.mean()
print(rolling_mean.head(10))
# plot original and transformed dataset
series.plot()
rolling_mean.plot(color='red')
pyplot.show()
# Out:
#                Births
# Date
# 1959-01-01        NaN
# 1959-01-02        NaN
# 1959-01-03  32.333333
# 1959-01-04  31.000000
# 1959-01-05  35.000000
# 1959-01-06  34.666667
# 1959-01-07  39.333333
# 1959-01-08  39.000000
# 1959-01-09  42.000000
# 1959-01-10  36.000000

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
df = DataFrame(series.values)
width = 3
lag1 = df.shift(1)
lag3 = df.shift(width - 1)
window = lag3.rolling(window=width)
means = window.mean()
dataframe = concat([means, lag1, df], axis=1)
dataframe.columns = ['mean', 't-1', 't+1']
print(dataframe.head(10))
# Out:
#         mean   t-1  t+1
# 0        NaN   NaN   35
# 1        NaN  35.0   32
# 2        NaN  32.0   30
# 3        NaN  30.0   31
# 4  32.333333  31.0   44
# 5  31.000000  44.0   29
# 6  35.000000  29.0   45
# 7  34.666667  45.0   43
# 8  39.333333  43.0   38
# 9  39.000000  38.0   27

# %%
from pandas import read_csv
from numpy import mean
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# prepare situation
X = series.values
window = 3
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
	length = len(history)
	yhat = mean([history[i] for i in range(length-window,length)])
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# zoom plot
pyplot.plot(test[0:100])
pyplot.plot(predictions[0:100], color='red')
pyplot.show()
# Out:
# predicted=32.333333, expected=31.000000
# predicted=31.000000, expected=44.000000
# predicted=35.000000, expected=29.000000
# predicted=34.666667, expected=45.000000
# predicted=39.333333, expected=43.000000
# predicted=39.000000, expected=38.000000
# predicted=42.000000, expected=27.000000
# predicted=36.000000, expected=38.000000
# predicted=34.333333, expected=33.000000
# predicted=32.666667, expected=55.000000
# predicted=42.000000, expected=47.000000
# predicted=45.000000, expected=45.000000
# predicted=49.000000, expected=37.000000
# predicted=43.000000, expected=50.000000
# predicted=44.000000, expected=43.000000
# predicted=43.333333, expected=41.000000
# predicted=44.666667, expected=52.000000
# predicted=45.333333, expected=34.000000
# predicted=42.333333, expected=53.000000
# predicted=46.333333, expected=39.000000
# predicted=42.000000, expected=32.000000
# predicted=41.333333, expected=37.000000
# predicted=36.000000, expected=43.000000
# predicted=37.333333, expected=39.000000
# predicted=39.666667, expected=35.000000
# predicted=39.000000, expected=44.000000
# predicted=39.333333, expected=38.000000
# predicted=39.000000, expected=24.000000
# predicted=35.333333, expected=23.000000
# predicted=28.333333, expected=31.000000
# predicted=26.000000, expected=44.000000
# predicted=32.666667, expected=38.000000
# predicted=37.666667, expected=50.000000
# predicted=44.000000, expected=38.000000
# predicted=42.000000, expected=51.000000
# predicted=46.333333, expected=31.000000
# predicted=40.000000, expected=31.000000
# predicted=37.666667, expected=51.000000
# predicted=37.666667, expected=36.000000
# predicted=39.333333, expected=45.000000
# predicted=44.000000, expected=51.000000
# predicted=44.000000, expected=34.000000
# predicted=43.333333, expected=52.000000
# predicted=45.666667, expected=47.000000
# predicted=44.333333, expected=45.000000
# predicted=48.000000, expected=46.000000
# predicted=46.000000, expected=39.000000
# predicted=43.333333, expected=48.000000
# predicted=44.333333, expected=37.000000
# predicted=41.333333, expected=35.000000
# predicted=40.000000, expected=52.000000
# predicted=41.333333, expected=42.000000
# predicted=43.000000, expected=45.000000
# predicted=46.333333, expected=39.000000
# predicted=42.000000, expected=37.000000
# predicted=40.333333, expected=30.000000
# predicted=35.333333, expected=35.000000
# predicted=34.000000, expected=28.000000
# predicted=31.000000, expected=45.000000
# predicted=36.000000, expected=34.000000
# predicted=35.666667, expected=36.000000
# predicted=38.333333, expected=50.000000
# predicted=40.000000, expected=44.000000
# predicted=43.333333, expected=39.000000
# predicted=44.333333, expected=32.000000
# predicted=38.333333, expected=39.000000
# predicted=36.666667, expected=45.000000
# predicted=38.666667, expected=43.000000
# predicted=42.333333, expected=39.000000
# predicted=42.333333, expected=31.000000
# predicted=37.666667, expected=27.000000
# predicted=32.333333, expected=30.000000
# predicted=29.333333, expected=42.000000
# predicted=33.000000, expected=46.000000
# predicted=39.333333, expected=41.000000
# predicted=43.000000, expected=36.000000
# predicted=41.000000, expected=45.000000
# predicted=40.666667, expected=46.000000
# predicted=42.333333, expected=43.000000
# predicted=44.666667, expected=38.000000
# predicted=42.333333, expected=34.000000
# predicted=38.333333, expected=35.000000
# predicted=35.666667, expected=56.000000
# predicted=41.666667, expected=36.000000
# predicted=42.333333, expected=32.000000
# predicted=41.333333, expected=50.000000
# predicted=39.333333, expected=41.000000
# predicted=41.000000, expected=39.000000
# predicted=43.333333, expected=41.000000
# predicted=40.333333, expected=47.000000
# predicted=42.333333, expected=34.000000
# predicted=40.666667, expected=36.000000
# predicted=39.000000, expected=33.000000
# predicted=34.333333, expected=35.000000
# predicted=34.666667, expected=38.000000
# predicted=35.333333, expected=38.000000
# predicted=37.000000, expected=34.000000
# predicted=36.666667, expected=53.000000
# predicted=41.666667, expected=34.000000
# predicted=40.333333, expected=34.000000
# predicted=40.333333, expected=38.000000
# predicted=35.333333, expected=35.000000
# predicted=35.666667, expected=32.000000
# predicted=35.000000, expected=42.000000
# predicted=36.333333, expected=34.000000
# predicted=36.000000, expected=46.000000
# predicted=40.666667, expected=30.000000
# predicted=36.666667, expected=46.000000
# predicted=40.666667, expected=45.000000
# predicted=40.333333, expected=54.000000
# predicted=48.333333, expected=34.000000
# predicted=44.333333, expected=37.000000
# predicted=41.666667, expected=35.000000
# predicted=35.333333, expected=40.000000
# predicted=37.333333, expected=42.000000
# predicted=39.000000, expected=58.000000
# predicted=46.666667, expected=51.000000
# predicted=50.333333, expected=32.000000
# predicted=47.000000, expected=35.000000
# predicted=39.333333, expected=38.000000
# predicted=35.000000, expected=33.000000
# predicted=35.333333, expected=39.000000
# predicted=36.666667, expected=47.000000
# predicted=39.666667, expected=38.000000
# predicted=41.333333, expected=52.000000
# predicted=45.666667, expected=30.000000
# predicted=40.000000, expected=34.000000
# predicted=38.666667, expected=40.000000
# predicted=34.666667, expected=35.000000
# predicted=36.333333, expected=42.000000
# predicted=39.000000, expected=41.000000
# predicted=39.333333, expected=42.000000
# predicted=41.666667, expected=38.000000
# predicted=40.333333, expected=24.000000
# predicted=34.666667, expected=34.000000
# predicted=32.000000, expected=43.000000
# predicted=33.666667, expected=36.000000
# predicted=37.666667, expected=55.000000
# predicted=44.666667, expected=41.000000
# predicted=44.000000, expected=45.000000
# predicted=47.000000, expected=41.000000
# predicted=42.333333, expected=37.000000
# predicted=41.000000, expected=43.000000
# predicted=40.333333, expected=39.000000
# predicted=39.666667, expected=33.000000
# predicted=38.333333, expected=43.000000
# predicted=38.333333, expected=40.000000
# predicted=38.666667, expected=38.000000
# predicted=40.333333, expected=45.000000
# predicted=41.000000, expected=46.000000
# predicted=43.000000, expected=34.000000
# predicted=41.666667, expected=35.000000
# predicted=38.333333, expected=48.000000
# predicted=39.000000, expected=51.000000
# predicted=44.666667, expected=36.000000
# predicted=45.000000, expected=33.000000
# predicted=40.000000, expected=46.000000
# predicted=38.333333, expected=42.000000
# predicted=40.333333, expected=48.000000
# predicted=45.333333, expected=34.000000
# predicted=41.333333, expected=41.000000
# predicted=41.000000, expected=35.000000
# predicted=36.666667, expected=40.000000
# predicted=38.666667, expected=34.000000
# predicted=36.333333, expected=30.000000
# predicted=34.666667, expected=36.000000
# predicted=33.333333, expected=40.000000
# predicted=35.333333, expected=39.000000
# predicted=38.333333, expected=45.000000
# predicted=41.333333, expected=38.000000
# predicted=40.666667, expected=47.000000
# predicted=43.333333, expected=33.000000
# predicted=39.333333, expected=30.000000
# predicted=36.666667, expected=42.000000
# predicted=35.000000, expected=43.000000
# predicted=38.333333, expected=41.000000
# predicted=42.000000, expected=41.000000
# predicted=41.666667, expected=59.000000
# predicted=47.000000, expected=43.000000
# predicted=47.666667, expected=45.000000
# predicted=49.000000, expected=38.000000
# predicted=42.000000, expected=37.000000
# predicted=40.000000, expected=45.000000
# predicted=40.000000, expected=42.000000
# predicted=41.333333, expected=57.000000
# predicted=48.000000, expected=46.000000
# predicted=48.333333, expected=51.000000
# predicted=51.333333, expected=41.000000
# predicted=46.000000, expected=47.000000
# predicted=46.333333, expected=26.000000
# predicted=38.000000, expected=35.000000
# predicted=36.000000, expected=44.000000
# predicted=35.000000, expected=41.000000
# predicted=40.000000, expected=42.000000
# predicted=42.333333, expected=36.000000
# predicted=39.666667, expected=45.000000
# predicted=41.000000, expected=45.000000
# predicted=42.000000, expected=45.000000
# predicted=45.000000, expected=47.000000
# predicted=45.666667, expected=38.000000
# predicted=43.333333, expected=42.000000
# predicted=42.333333, expected=35.000000
# predicted=38.333333, expected=36.000000
# predicted=37.666667, expected=39.000000
# predicted=36.666667, expected=45.000000
# predicted=40.000000, expected=43.000000
# predicted=42.333333, expected=47.000000
# predicted=45.000000, expected=36.000000
# predicted=42.000000, expected=41.000000
# predicted=41.333333, expected=50.000000
# predicted=42.333333, expected=39.000000
# predicted=43.333333, expected=41.000000
# predicted=43.333333, expected=46.000000
# predicted=42.000000, expected=64.000000
# predicted=50.333333, expected=45.000000
# predicted=51.666667, expected=34.000000
# predicted=47.666667, expected=38.000000
# predicted=39.000000, expected=44.000000
# predicted=38.666667, expected=48.000000
# predicted=43.333333, expected=46.000000
# predicted=46.000000, expected=44.000000
# predicted=46.000000, expected=37.000000
# predicted=42.333333, expected=39.000000
# predicted=40.000000, expected=44.000000
# predicted=40.000000, expected=45.000000
# predicted=42.666667, expected=33.000000
# predicted=40.666667, expected=44.000000
# predicted=40.666667, expected=38.000000
# predicted=38.333333, expected=46.000000
# predicted=42.666667, expected=46.000000
# predicted=43.333333, expected=40.000000
# predicted=44.000000, expected=39.000000
# predicted=41.666667, expected=44.000000
# predicted=41.000000, expected=48.000000
# predicted=43.666667, expected=50.000000
# predicted=47.333333, expected=41.000000
# predicted=46.333333, expected=42.000000
# predicted=44.333333, expected=51.000000
# predicted=44.666667, expected=41.000000
# predicted=44.666667, expected=44.000000
# predicted=45.333333, expected=38.000000
# predicted=41.000000, expected=68.000000
# predicted=50.000000, expected=40.000000
# predicted=48.666667, expected=42.000000
# predicted=50.000000, expected=51.000000
# predicted=44.333333, expected=44.000000
# predicted=45.666667, expected=45.000000
# predicted=46.666667, expected=36.000000
# predicted=41.666667, expected=57.000000
# predicted=46.000000, expected=44.000000
# predicted=45.666667, expected=42.000000
# predicted=47.666667, expected=53.000000
# predicted=46.333333, expected=42.000000
# predicted=45.666667, expected=34.000000
# predicted=43.000000, expected=40.000000
# predicted=38.666667, expected=56.000000
# predicted=43.333333, expected=44.000000
# predicted=46.666667, expected=53.000000
# predicted=51.000000, expected=55.000000
# predicted=50.666667, expected=39.000000
# predicted=49.000000, expected=59.000000
# predicted=51.000000, expected=55.000000
# predicted=51.000000, expected=73.000000
# predicted=62.333333, expected=55.000000
# predicted=61.000000, expected=44.000000
# predicted=57.333333, expected=43.000000
# predicted=47.333333, expected=40.000000
# predicted=42.333333, expected=47.000000
# predicted=43.333333, expected=51.000000
# predicted=46.000000, expected=56.000000
# predicted=51.333333, expected=49.000000
# predicted=52.000000, expected=54.000000
# predicted=53.000000, expected=56.000000
# predicted=53.000000, expected=47.000000
# predicted=52.333333, expected=44.000000
# predicted=49.000000, expected=43.000000
# predicted=44.666667, expected=42.000000
# predicted=43.000000, expected=45.000000
# predicted=43.333333, expected=50.000000
# predicted=45.666667, expected=48.000000
# predicted=47.666667, expected=43.000000
# predicted=47.000000, expected=40.000000
# predicted=43.666667, expected=59.000000
# predicted=47.333333, expected=41.000000
# predicted=46.666667, expected=42.000000
# predicted=47.333333, expected=51.000000
# predicted=44.666667, expected=49.000000
# predicted=47.333333, expected=45.000000
# predicted=48.333333, expected=43.000000
# predicted=45.666667, expected=42.000000
# predicted=43.333333, expected=38.000000
# predicted=41.000000, expected=47.000000
# predicted=42.333333, expected=38.000000
# predicted=41.000000, expected=36.000000
# predicted=40.333333, expected=42.000000
# predicted=38.666667, expected=35.000000
# predicted=37.666667, expected=28.000000
# predicted=35.000000, expected=44.000000
# predicted=35.666667, expected=36.000000
# predicted=36.000000, expected=45.000000
# predicted=41.666667, expected=46.000000
# predicted=42.333333, expected=48.000000
# predicted=46.333333, expected=49.000000
# predicted=47.666667, expected=43.000000
# predicted=46.666667, expected=42.000000
# predicted=44.666667, expected=59.000000
# predicted=48.000000, expected=45.000000
# predicted=48.666667, expected=52.000000
# predicted=52.000000, expected=46.000000
# predicted=47.666667, expected=42.000000
# predicted=46.666667, expected=40.000000
# predicted=42.666667, expected=40.000000
# predicted=40.666667, expected=45.000000
# predicted=41.666667, expected=35.000000
# predicted=40.000000, expected=35.000000
# predicted=38.333333, expected=40.000000
# predicted=36.666667, expected=39.000000
# predicted=38.000000, expected=33.000000
# predicted=37.333333, expected=42.000000
# predicted=38.000000, expected=47.000000
# predicted=40.666667, expected=51.000000
# predicted=46.666667, expected=44.000000
# predicted=47.333333, expected=40.000000
# predicted=45.000000, expected=57.000000
# predicted=47.000000, expected=49.000000
# predicted=48.666667, expected=45.000000
# predicted=50.333333, expected=49.000000
# predicted=47.666667, expected=51.000000
# predicted=48.333333, expected=46.000000
# predicted=48.666667, expected=44.000000
# predicted=47.000000, expected=52.000000
# predicted=47.333333, expected=45.000000
# predicted=47.000000, expected=32.000000
# predicted=43.000000, expected=46.000000
# predicted=41.000000, expected=41.000000
# predicted=39.666667, expected=34.000000
# predicted=40.333333, expected=33.000000
# predicted=36.000000, expected=36.000000
# predicted=34.333333, expected=49.000000
# predicted=39.333333, expected=43.000000
# predicted=42.666667, expected=43.000000
# predicted=45.000000, expected=34.000000
# predicted=40.000000, expected=39.000000
# predicted=38.666667, expected=35.000000
# predicted=36.000000, expected=52.000000
# predicted=42.000000, expected=47.000000
# predicted=44.666667, expected=52.000000
# predicted=50.333333, expected=39.000000
# predicted=46.000000, expected=40.000000
# predicted=43.666667, expected=42.000000
# predicted=40.333333, expected=42.000000
# predicted=41.333333, expected=53.000000
# predicted=45.666667, expected=39.000000
# predicted=44.666667, expected=40.000000
# predicted=44.000000, expected=38.000000
# predicted=39.000000, expected=44.000000
# predicted=40.666667, expected=34.000000
# predicted=38.666667, expected=37.000000
# predicted=38.333333, expected=52.000000
# predicted=41.000000, expected=48.000000
# predicted=45.666667, expected=55.000000
# predicted=51.666667, expected=50.000000
# Test MSE: 61.379

# %% [markdown]
# ## Autoregression Models for Time Series Forecasting With Python

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from matplotlib.pyplot import figure

figure(figsize=(20, 16), dpi=200)
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %% [markdown]
# Quick Check for Autocorrelation

# %%
from pandas.plotting import lag_plot
lag_plot(series)
pyplot.show()

# %%
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
#          t-1      t+1
# t-1  1.00000  0.77487
# t+1  0.77487  1.00000

# %% [markdown]
# Autocorrelation Plots

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(series, lags=31)
pyplot.show()

# %% [markdown]
# Persistence Model

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train, test = X[1:len(X)-7], X[len(X)-7:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
 
# persistence model
def model_persistence(x):
	return x
 
# walk-forward validation
predictions = list()
for x in test_X:
	yhat = model_persistence(x)
	predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print('Test MSE: %.3f' % test_score)
# plot predictions vs expected
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test MSE: 3.423

# %% [markdown]
# Autoregression Model

# %%
# create and evaluate a static autoregressive model
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# split dataset
X = series.values
train, test = X[1:len(X)-7], X[len(X)-7:]
# train autoregression
model = AutoReg(train, lags=29)
model_fit = model.fit()
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
	print('predicted=%f, expected=%f' % (predictions[i], test[i]))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot results
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# Coefficients: [ 5.57543506e-01  5.88595221e-01 -9.08257090e-02  4.82615092e-02
#   4.00650265e-02  3.93020055e-02  2.59463738e-02  4.46675960e-02
#   1.27681498e-02  3.74362239e-02 -8.11700276e-04  4.79081949e-03
#   1.84731397e-02  2.68908418e-02  5.75906178e-04  2.48096415e-02
#   7.40316579e-03  9.91622149e-03  3.41599123e-02 -9.11961877e-03
#   2.42127561e-02  1.87870751e-02  1.21841870e-02 -1.85534575e-02
#  -1.77162867e-03  1.67319894e-02  1.97615668e-02  9.83245087e-03
#   6.22710723e-03 -1.37732255e-03]
# predicted=11.871275, expected=12.900000
# predicted=13.053794, expected=14.600000
# predicted=13.532591, expected=14.000000
# predicted=13.243126, expected=13.600000
# predicted=13.091438, expected=13.500000
# predicted=13.146989, expected=15.700000
# predicted=13.176153, expected=13.000000
# Test RMSE: 1.225

# %%
# create and evaluate an updated autoregressive model
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# split dataset
X = series.values
train, test = X[1:len(X)-7], X[len(X)-7:]
# train autoregression
window = 29
model = AutoReg(train, lags=29)
model_fit = model.fit()
coef = model_fit.params
# walk forward over time steps in test
history = train[len(train)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	yhat = coef[0]
	for d in range(window):
		yhat += coef[d+1] * lag[window-d-1]
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# predicted=11.871275, expected=12.900000
# predicted=13.659297, expected=14.600000
# predicted=14.349246, expected=14.000000
# predicted=13.427454, expected=13.600000
# predicted=13.374877, expected=13.500000
# predicted=13.479991, expected=15.700000
# predicted=14.765146, expected=13.000000
# Test RMSE: 1.204

# %% [markdown]
# ## Time Series Data Visualization with Python

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
print(series.head())
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# Name: Temp, dtype: float64

# %%
series.plot()
pyplot.show()

# %%
series.plot(style='k.')
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years.plot(subplots=True, legend=False)
pyplot.show()

# %% [markdown]
# Time Series Histogram and Density Plots

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.hist()
pyplot.show()

# %%
series.plot(kind='kde')
pyplot.show()

# %% [markdown]
# Time Series Box and Whisker Plots by Interval

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years.boxplot()
pyplot.show()

# %%
# create a boxplot of monthly data
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
from pandas import concat
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
one_year = series['1990']
groups = one_year.groupby(Grouper(freq='M'))
months = concat([DataFrame(x[1].values) for x in groups], axis=1)
months = DataFrame(months)
months.columns = range(1,13)
months.boxplot()
pyplot.show()

# %% [markdown]
# Time Series Heat Maps

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years = years.T
pyplot.matshow(years, interpolation=None, aspect='auto')
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
from pandas import concat
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
one_year = series['1990']
groups = one_year.groupby(Grouper(freq='M'))
months = concat([DataFrame(x[1].values) for x in groups], axis=1)
months = DataFrame(months)
months.columns = range(1,13)
pyplot.matshow(months, interpolation=None, aspect='auto')
pyplot.show()

# %% [markdown]
# Time Series Lag Scatter Plots

# %%
# create a scatter plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
lag_plot(series)
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
values = DataFrame(series.values)
lags = 7
columns = [values]
for i in range(1,(lags + 1)):
	columns.append(values.shift(i))
dataframe = concat(columns, axis=1)
columns = ['t+1']
for i in range(1,(lags + 1)):
	columns.append('t-' + str(i))
dataframe.columns = columns
pyplot.figure(1)
for i in range(1,(lags + 1)):
	ax = pyplot.subplot(240 + i)
	ax.set_title('t+1 vs t-' + str(i))
	pyplot.scatter(x=dataframe['t+1'].values, y=dataframe['t-'+str(i)].values)
pyplot.show()

# %% [markdown]
# Time Series Autocorrelation Plots

# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
autocorrelation_plot(series)
pyplot.show()

# %% [markdown]
# ## How to Visualize Time Series Residual Forecast Errors with Python

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %% [markdown]
# Persistence Forecast Model

# %%
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']

# %%
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [x for x in test_X]
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = DataFrame(residuals)
print(residuals.head())
# Out:
#       0
# 0   9.0
# 1 -10.0
# 2   3.0
# 3  -6.0
# 4  30.0

# %% [markdown]
# ### Residual Line Plot
# The array of residual errors can be wrapped in a Pandas DataFrame and plotted directly.

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [x for x in test_X]
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = DataFrame(residuals)
# plot residuals
residuals.plot()
pyplot.show()

# %% [markdown]
# ### Residual Summary Statistics
# This includes the mean and standard deviation of the distribution, as well as percentiles and the minimum and maximum errors observed.

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [x for x in test_X]
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = DataFrame(residuals)
# summary statistics
print(residuals.describe())
# Out:
#                 0
# count  125.000000
# mean     0.064000
# std      9.187776
# min    -28.000000
# 25%     -6.000000
# 50%     -1.000000
# 75%      5.000000
# max     30.000000

# %% [markdown]
# ### Residual Histogram and Density Plots
# We can use both histograms and density plots to better understand the distribution of residual errors.

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [(x-0.064000) for x in test_X]
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = DataFrame(residuals)
# histogram plot
residuals.hist()
pyplot.show()
# density plot
residuals.plot(kind='kde')
pyplot.show()

# %% [markdown]
# ### Residual Q-Q Plot
# A Q-Q plot, or quantile plot, compares two distributions and can be used to see how similar or different they happen to be.
# The Q-Q plot can be used to quickly check the normality of the distribution of residual errors.
# Below is an example of a Q-Q plot of the residual errors. The x-axis shows the theoretical quantiles and the y-axis shows the sample quantiles.

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
import numpy
from statsmodels.graphics.gofplots import qqplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [(x-0.064000) for x in test_X]
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = numpy.array(residuals)
qqplot(residuals)
pyplot.show()

# %% [markdown]
# ### Residual Autocorrelation Plot
# Autocorrelation calculates the strength of the relationship between an observation and observations at prior time steps.
# A significant autocorrelation in the residual plot suggests that the model could be doing a better job of incorporating the relationship between observations and lagged observations, called autoregression.
#
# Below is an example of visualizing the autocorrelation for the residual errors. The x-axis shows the lag and the y-axis shows the correlation between an observation and the lag variable, where correlation values are between -1 and 1 for negative and positive correlations respectively

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [x for x in test_X]
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = DataFrame(residuals)
autocorrelation_plot(residuals)
pyplot.show()

# %% [markdown]
# # How to Create an ARIMA Model for Time Series Forecasting in Python

# %% [markdown]
# ### Autoregressive Integrated Moving Average Model
# An ARIMA model is a class of statistical models for analyzing and forecasting time series data.
# The parameters of the ARIMA model are defined as follows:
#
#     p: The number of lag observations included in the model, also called the lag order.
#     d: The number of times that the raw observations are differenced, also called the degree of differencing.
#     q: The size of the moving average window, also called the order of moving average.
#
# A linear regression model is constructed including the specified number and type of terms, and the data is prepared by a degree of differencing in order to make it stationary, i.e. to remove trend and seasonal structures that negatively affect the regression model

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('sh', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
# <ipython-input-10-b22d4efe88dd>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
autocorrelation_plot(series)
pyplot.show()
# Out:
# <ipython-input-14-34e199a44e78>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %% [markdown]
# ### ARIMA with Python
# The statsmodels library provides the capability to fit an ARIMA model.
#
# An ARIMA model can be created using the statsmodels library as follows:
#
#     Define the model by calling ARIMA() and passing in the p, d, and q parameters.
#     The model is prepared on the training data by calling the fit() function.
#     Predictions can be made by calling the predict() function and specifying the index of the time or times to be predicted.

# %%
# fit an ARIMA model and plot residual errors
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = read_csv('shampoo.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)
series.index = series.index.to_period('M')
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# <ipython-input-2-538fba6a166a>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                   36
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -198.485
# Date:                Fri, 09 Jul 2021   AIC                            408.969
# Time:                        21:59:13   BIC                            418.301
# Sample:                    01-31-1901   HQIC                           412.191
#                          - 12-31-1903
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9014      0.247     -3.647      0.000      -1.386      -0.417
# ar.L2         -0.2284      0.268     -0.851      0.395      -0.754       0.298
# ar.L3          0.0747      0.291      0.256      0.798      -0.497       0.646
# ar.L4          0.2519      0.340      0.742      0.458      -0.414       0.918
# ar.L5          0.3344      0.210      1.593      0.111      -0.077       0.746
# sigma2      4728.9608   1316.021      3.593      0.000    2149.607    7308.314
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.61   Jarque-Bera (JB):                 0.96
# Prob(Q):                              0.44   Prob(JB):                         0.62
# Heteroskedasticity (H):               1.07   Skew:                             0.28
# Prob(H) (two-sided):                  0.90   Kurtosis:                         2.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                 0
# count   36.000000
# mean    21.936145
# std     80.774430
# min   -122.292030
# 25%    -35.040859
# 50%     13.147219
# 75%     68.848286
# max    266.000000

# %% [markdown]
# ### Rolling Forecast ARIMA Model
# We can use the predict() function on the ARIMAResults object to make predictions. It accepts the index of the time steps to make predictions as arguments. These indexes are relative to the start of the training dataset used to make predictions.

# %%
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = read_csv('shampoo.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)
series.index = series.index.to_period('M')
# split into train and test sets
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# <ipython-input-3-b96bdd23f68b>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# predicted=343.272180, expected=342.300000
# predicted=293.329674, expected=339.700000
# predicted=368.668956, expected=440.400000
# predicted=335.044741, expected=315.900000
# predicted=363.220222, expected=439.300000
# predicted=357.645324, expected=401.300000
# predicted=443.047835, expected=437.400000
# predicted=378.365674, expected=575.500000
# predicted=459.415020, expected=407.600000
# predicted=526.890876, expected=682.000000
# predicted=457.231275, expected=475.300000
# predicted=672.914944, expected=581.300000
# predicted=531.541449, expected=646.900000
# Test RMSE: 89.021

# %% [markdown]
# ### Configuring an ARIMA Model
# This is a process that uses time series analysis and diagnostics to discover good parameters for the ARIMA model.
#
# In summary, the steps of this process are as follows:
#
#     Model Identification. Use plots and summary statistics to identify trends, seasonality, and autoregression elements to get an idea of the amount of differencing and the size of the lag that will be required.
#     Parameter Estimation. Use a fitting procedure to find the coefficients of the regression model.
#     Model Checking. Use plots and statistical tests of the residual errors to determine the amount and type of temporal structure not captured by the model.
#
# The process is repeated until either a desirable level of fit is achieved on the in-sample or out-of-sample observations (e.g. training or test datasets).
#
# The process was described in the classic 1970 textbook on the topic titled Time Series Analysis: Forecasting and Control by George Box and Gwilym Jenkins. An updated 5th edition is now available if you are interested in going deeper into this type of model and methodology.
#
# Given that the model can be fit efficiently on modest-sized time series datasets, grid searching parameters of the model can be a valuable approach.

# %% [markdown]
# # How to Model Residual Errors to Correct Time Series Forecasts with Python

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %% [markdown]
# ### Persistence Forecast Model
# The simplest forecast that we can make is to forecast that what happened in the previous time step will be the same as what will happen in the next time step.
#
# This is called the “naive forecast” or the persistence forecast model. This model will provide the predictions from which we can calculate the residual error time series. Alternately, we could develop an autoregression model of the time series and use that as our model. We will not develop an autoregression model in this case for brevity and to focus on the model of residual error.

# %%
# calculate residual errors for a persistence forecast model
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.metrics import mean_squared_error
from math import sqrt
# load data
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model
predictions = [x for x in test_X]
# skill of persistence model
rmse = sqrt(mean_squared_error(test_y, predictions))
print('Test RMSE: %.3f' % rmse)
# calculate residuals
residuals = [test_y[i]-predictions[i] for i in range(len(predictions))]
residuals = DataFrame(residuals)
print(residuals.head())
# Out:
# Test RMSE: 9.151
#       0
# 0   9.0
# 1 -10.0
# 2   3.0
# 3  -6.0
# 4  30.0

# %% [markdown]
# ### Autoregression of Residual Error
# Building on the persistence model in the previous section, we can first train the model on the residual errors calculated on the training dataset. This requires that we make persistence predictions for each observation in the training dataset, then create the AR model, as follows.

# %%
# autoregressive model of residual errors
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from statsmodels.tsa.ar_model import AutoReg
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model on training set
train_pred = [x for x in train_X]
# calculate residuals
train_resid = [train_y[i]-train_pred[i] for i in range(len(train_pred))]
# model the training set residuals
model = AutoReg(train_resid, lags=15)
model_fit = model.fit()
print('Coef=%s' % (model_fit.params))
# Out:
# Coef=[ 0.10120699 -0.84940615 -0.77783609 -0.73345006 -0.68902061 -0.59270551
#  -0.5376728  -0.42553356 -0.24861246 -0.19972102 -0.15954013 -0.11045476
#  -0.14045572 -0.13299964 -0.12515801 -0.03615774]
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(

# %%
# forecast residual forecast error
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from statsmodels.tsa.ar_model import AutoReg
from matplotlib import pyplot
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model on training set
train_pred = [x for x in train_X]
# calculate residuals
train_resid = [train_y[i]-train_pred[i] for i in range(len(train_pred))]
# model the training set residuals
window = 15
model = AutoReg(train_resid, lags=window)
model_fit = model.fit()
coef = model_fit.params
# walk forward over time steps in test
history = train_resid[len(train_resid)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
expected_error = list()
for t in range(len(test_y)):
	# persistence
	yhat = test_X[t]
	error = test_y[t] - yhat
	expected_error.append(error)
	# predict error
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	pred_error = coef[0]
	for d in range(window):
		pred_error += coef[d+1] * lag[window-d-1]
	predictions.append(pred_error)
	history.append(error)
	print('predicted error=%f, expected error=%f' % (pred_error, error))
# plot predicted error
pyplot.plot(expected_error)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# predicted error=1.155523, expected error=9.000000
# predicted error=-7.108809, expected error=-10.000000
# predicted error=3.007486, expected error=3.000000
# predicted error=-0.756446, expected error=-6.000000
# predicted error=5.511163, expected error=30.000000
# predicted error=-19.991264, expected error=-28.000000
# predicted error=4.842429, expected error=2.000000
# predicted error=3.050883, expected error=9.000000
# predicted error=-5.141585, expected error=-7.000000
# predicted error=1.161119, expected error=1.000000
# predicted error=-0.241928, expected error=-9.000000
# predicted error=9.159826, expected error=21.000000
# predicted error=-7.117974, expected error=-13.000000
# predicted error=1.182992, expected error=-2.000000
# predicted error=2.769363, expected error=11.000000
# predicted error=-4.959337, expected error=-11.000000
# predicted error=2.566233, expected error=-8.000000
# predicted error=9.084498, expected error=6.000000
# predicted error=3.020899, expected error=16.000000
# predicted error=-6.542098, expected error=-12.000000
# predicted error=1.328116, expected error=9.000000
# predicted error=-7.774412, expected error=2.000000
# predicted error=-6.294076, expected error=-16.000000
# predicted error=5.166344, expected error=20.000000
# predicted error=-13.378129, expected error=-4.000000
# predicted error=-7.038503, expected error=18.000000
# predicted error=-19.735568, expected error=-18.000000
# predicted error=-4.362409, expected error=-11.000000
# predicted error=7.123282, expected error=-1.000000
# predicted error=7.785200, expected error=-3.000000
# predicted error=8.690567, expected error=7.000000
# predicted error=3.500174, expected error=4.000000
# predicted error=0.130549, expected error=5.000000
# predicted error=-1.811749, expected error=-7.000000
# predicted error=1.995458, expected error=5.000000
# predicted error=-4.591734, expected error=2.000000
# predicted error=-5.494546, expected error=-9.000000
# predicted error=0.020975, expected error=-3.000000
# predicted error=4.641492, expected error=-1.000000
# predicted error=7.207017, expected error=-1.000000
# predicted error=9.613038, expected error=3.000000
# predicted error=5.174955, expected error=5.000000
# predicted error=-0.436590, expected error=-2.000000
# predicted error=0.422524, expected error=-5.000000
# predicted error=2.388220, expected error=-3.000000
# predicted error=4.981921, expected error=19.000000
# predicted error=-11.288698, expected error=-18.000000
# predicted error=5.147986, expected error=1.000000
# predicted error=3.865771, expected error=9.000000
# predicted error=-3.277999, expected error=-2.000000
# predicted error=-0.328287, expected error=-4.000000
# predicted error=0.981738, expected error=-2.000000
# predicted error=2.633858, expected error=-1.000000
# predicted error=4.559883, expected error=-4.000000
# predicted error=5.408289, expected error=9.000000
# predicted error=-1.823765, expected error=-9.000000
# predicted error=8.047069, expected error=-2.000000
# predicted error=7.282588, expected error=6.000000
# predicted error=1.124918, expected error=-7.000000
# predicted error=6.895100, expected error=-7.000000
# predicted error=12.342543, expected error=16.000000
# predicted error=-3.285082, expected error=-8.000000
# predicted error=4.364352, expected error=9.000000
# predicted error=-4.532403, expected error=1.000000
# predicted error=-5.265932, expected error=2.000000
# predicted error=-5.765866, expected error=1.000000
# predicted error=-8.800388, expected error=-6.000000
# predicted error=-2.571719, expected error=-1.000000
# predicted error=-0.150937, expected error=17.000000
# predicted error=-14.494473, expected error=-14.000000
# predicted error=-0.114606, expected error=7.000000
# predicted error=-5.868570, expected error=-6.000000
# predicted error=-0.205353, expected error=-4.000000
# predicted error=4.016041, expected error=-2.000000
# predicted error=2.984783, expected error=0.000000
# predicted error=5.020990, expected error=5.000000
# predicted error=1.396176, expected error=-10.000000
# predicted error=8.752806, expected error=0.000000
# predicted error=8.978962, expected error=5.000000
# predicted error=3.711492, expected error=-1.000000
# predicted error=2.921583, expected error=-6.000000
# predicted error=7.074578, expected error=9.000000
# predicted error=-1.851417, expected error=5.000000
# predicted error=-4.197715, expected error=4.000000
# predicted error=-9.049831, expected error=-7.000000
# predicted error=-2.456229, expected error=-4.000000
# predicted error=1.665645, expected error=17.000000
# predicted error=-14.051443, expected error=-8.000000
# predicted error=-5.753231, expected error=-4.000000
# predicted error=-0.848182, expected error=4.000000
# predicted error=-3.202769, expected error=2.000000
# predicted error=-4.138705, expected error=-5.000000
# predicted error=-0.582258, expected error=-2.000000
# predicted error=1.584679, expected error=8.000000
# predicted error=-3.529759, expected error=-7.000000
# predicted error=0.971086, expected error=-13.000000
# predicted error=12.106665, expected error=14.000000
# predicted error=0.980507, expected error=-5.000000
# predicted error=5.379313, expected error=-7.000000
# predicted error=9.587488, expected error=-1.000000
# predicted error=8.858736, expected error=3.000000
# predicted error=7.924774, expected error=13.000000
# predicted error=-5.759085, expected error=-6.000000
# predicted error=-1.890846, expected error=0.000000
# predicted error=-0.449702, expected error=-9.000000
# predicted error=5.917587, expected error=5.000000
# predicted error=0.387708, expected error=-4.000000
# predicted error=4.226554, expected error=17.000000
# predicted error=-9.526920, expected error=-5.000000
# predicted error=-3.676687, expected error=5.000000
# predicted error=-9.200521, expected error=-13.000000
# predicted error=2.704441, expected error=1.000000
# predicted error=1.615921, expected error=2.000000
# predicted error=-1.389975, expected error=0.000000
# predicted error=-0.533753, expected error=11.000000
# predicted error=-8.422371, expected error=-14.000000
# predicted error=5.806719, expected error=1.000000
# predicted error=4.079252, expected error=-2.000000
# predicted error=4.386951, expected error=6.000000
# predicted error=-1.951332, expected error=-10.000000
# predicted error=6.675538, expected error=3.000000
# predicted error=3.419129, expected error=15.000000
# predicted error=-7.160046, expected error=-4.000000
# predicted error=-4.179003, expected error=7.000000
# predicted error=-10.425124, expected error=-5.000000

# %% [markdown]
# ### Correct Predictions with a Model of Residual Errors
# A model of forecast residual error is interesting, but it can also be useful to make better predictions.
#
# With a good estimate of forecast error at a time step, we can make better predictions.

# %%
# correct forecasts with a model of forecast residual errors
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from statsmodels.tsa.ar_model import AutoReg
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from math import sqrt
# load data
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
# persistence model on training set
train_pred = [x for x in train_X]
# calculate residuals
train_resid = [train_y[i]-train_pred[i] for i in range(len(train_pred))]
# model the training set residuals
window = 15
model = AutoReg(train_resid, lags=15)
model_fit = model.fit()
coef = model_fit.params
# walk forward over time steps in test
history = train_resid[len(train_resid)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test_y)):
	# persistence
	yhat = test_X[t]
	error = test_y[t] - yhat
	# predict error
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	pred_error = coef[0]
	for d in range(window):
		pred_error += coef[d+1] * lag[window-d-1]
	# correct the prediction
	yhat = yhat + pred_error
	predictions.append(yhat)
	history.append(error)
	print('predicted=%f, expected=%f' % (yhat, test_y[t]))
# error
rmse = sqrt(mean_squared_error(test_y, predictions))
print('Test RMSE: %.3f' % rmse)
# plot predicted error
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# predicted=43.155523, expected=51.000000
# predicted=43.891191, expected=41.000000
# predicted=44.007486, expected=44.000000
# predicted=43.243554, expected=38.000000
# predicted=43.511163, expected=68.000000
# predicted=48.008736, expected=40.000000
# predicted=44.842429, expected=42.000000
# predicted=45.050883, expected=51.000000
# predicted=45.858415, expected=44.000000
# predicted=45.161119, expected=45.000000
# predicted=44.758072, expected=36.000000
# predicted=45.159826, expected=57.000000
# predicted=49.882026, expected=44.000000
# predicted=45.182992, expected=42.000000
# predicted=44.769363, expected=53.000000
# predicted=48.040663, expected=42.000000
# predicted=44.566233, expected=34.000000
# predicted=43.084498, expected=40.000000
# predicted=43.020899, expected=56.000000
# predicted=49.457902, expected=44.000000
# predicted=45.328116, expected=53.000000
# predicted=45.225588, expected=55.000000
# predicted=48.705924, expected=39.000000
# predicted=44.166344, expected=59.000000
# predicted=45.621871, expected=55.000000
# predicted=47.961497, expected=73.000000
# predicted=53.264432, expected=55.000000
# predicted=50.637591, expected=44.000000
# predicted=51.123282, expected=43.000000
# predicted=50.785200, expected=40.000000
# predicted=48.690567, expected=47.000000
# predicted=50.500174, expected=51.000000
# predicted=51.130549, expected=56.000000
# predicted=54.188251, expected=49.000000
# predicted=50.995458, expected=54.000000
# predicted=49.408266, expected=56.000000
# predicted=50.505454, expected=47.000000
# predicted=47.020975, expected=44.000000
# predicted=48.641492, expected=43.000000
# predicted=50.207017, expected=42.000000
# predicted=51.613038, expected=45.000000
# predicted=50.174955, expected=50.000000
# predicted=49.563410, expected=48.000000
# predicted=48.422524, expected=43.000000
# predicted=45.388220, expected=40.000000
# predicted=44.981921, expected=59.000000
# predicted=47.711302, expected=41.000000
# predicted=46.147986, expected=42.000000
# predicted=45.865771, expected=51.000000
# predicted=47.722001, expected=49.000000
# predicted=48.671713, expected=45.000000
# predicted=45.981738, expected=43.000000
# predicted=45.633858, expected=42.000000
# predicted=46.559883, expected=38.000000
# predicted=43.408289, expected=47.000000
# predicted=45.176235, expected=38.000000
# predicted=46.047069, expected=36.000000
# predicted=43.282588, expected=42.000000
# predicted=43.124918, expected=35.000000
# predicted=41.895100, expected=28.000000
# predicted=40.342543, expected=44.000000
# predicted=40.714918, expected=36.000000
# predicted=40.364352, expected=45.000000
# predicted=40.467597, expected=46.000000
# predicted=40.734068, expected=48.000000
# predicted=42.234134, expected=49.000000
# predicted=40.199612, expected=43.000000
# predicted=40.428281, expected=42.000000
# predicted=41.849063, expected=59.000000
# predicted=44.505527, expected=45.000000
# predicted=44.885394, expected=52.000000
# predicted=46.131430, expected=46.000000
# predicted=45.794647, expected=42.000000
# predicted=46.016041, expected=40.000000
# predicted=42.984783, expected=40.000000
# predicted=45.020990, expected=45.000000
# predicted=46.396176, expected=35.000000
# predicted=43.752806, expected=35.000000
# predicted=43.978962, expected=40.000000
# predicted=43.711492, expected=39.000000
# predicted=41.921583, expected=33.000000
# predicted=40.074578, expected=42.000000
# predicted=40.148583, expected=47.000000
# predicted=42.802285, expected=51.000000
# predicted=41.950169, expected=44.000000
# predicted=41.543771, expected=40.000000
# predicted=41.665645, expected=57.000000
# predicted=42.948557, expected=49.000000
# predicted=43.246769, expected=45.000000
# predicted=44.151818, expected=49.000000
# predicted=45.797231, expected=51.000000
# predicted=46.861295, expected=46.000000
# predicted=45.417742, expected=44.000000
# predicted=45.584679, expected=52.000000
# predicted=48.470241, expected=45.000000
# predicted=45.971086, expected=32.000000
# predicted=44.106665, expected=46.000000
# predicted=46.980507, expected=41.000000
# predicted=46.379313, expected=34.000000
# predicted=43.587488, expected=33.000000
# predicted=41.858736, expected=36.000000
# predicted=43.924774, expected=49.000000
# predicted=43.240915, expected=43.000000
# predicted=41.109154, expected=43.000000
# predicted=42.550298, expected=34.000000
# predicted=39.917587, expected=39.000000
# predicted=39.387708, expected=35.000000
# predicted=39.226554, expected=52.000000
# predicted=42.473080, expected=47.000000
# predicted=43.323313, expected=52.000000
# predicted=42.799479, expected=39.000000
# predicted=41.704441, expected=40.000000
# predicted=41.615921, expected=42.000000
# predicted=40.610025, expected=42.000000
# predicted=41.466247, expected=53.000000
# predicted=44.577629, expected=39.000000
# predicted=44.806719, expected=40.000000
# predicted=44.079252, expected=38.000000
# predicted=42.386951, expected=44.000000
# predicted=42.048668, expected=34.000000
# predicted=40.675538, expected=37.000000
# predicted=40.419129, expected=52.000000
# predicted=44.839954, expected=48.000000
# predicted=43.820997, expected=55.000000
# predicted=44.574876, expected=50.000000
# Test RMSE: 7.499

# %% [markdown]
# # A Gentle Introduction to the Box-Jenkins Method for Time Series Forecasting
#
# Box and Jenkins also suggest a process for identifying, estimating, and checking models for a specific time series dataset. This process is now referred to as the Box-Jenkins Method.

# %% [markdown]
# ### Box-Jenkins Method
# the process as a stochastic model building and that it is an iterative approach that consists of the following 3 steps:
#
#     Identification: Use the data and all related information to help select a sub-class of model that may best summarize the data.
#
#     Assess whether the time series is stationary, and if not, how many differences are required to make it stationary.
#     Identify the parameters of an ARMA model for the data.
#
#     *Differentiation:
#
#     1.Unit Root Tests. Use unit root statistical tests on the time series to determine whether or not it is stationary. Repeat after each round of differencing.
#     2.Avoid over differencing. Differencing the time series more than is required can result in the addition of extra serial correlation and additional complexity.
#
#     *configuring AR and MA:
#
#     1.Autocorrelation Function (ACF): The plot summarizes the correlation of an observation with lag values. The x-axis shows the lag and the y-axis shows the correlation coefficient between -1 and 1 for negative and positive correlation.
#
#     2.Partial Autocorrelation Function (PACF): The plot summarizes the correlations for an observation with lag values that is not accounted for by prior lagged observations.
#
#
#
#     Estimation: Use the data to train the parameters of the model (i.e. the coefficients).
#                *Estimation involves using numerical methods to minimize a loss or error term.
#
#     Diagnostic Checking: Evaluate the fitted model in the context of the available data and check for areas where the model may be improved.
#
#     The idea of diagnostic checking is to look for evidence that the model is not a good fit for the data.
#
#     Two useful areas to investigate diagnostics are:
#     Overfitting
#     Residual Errors.

# %% [markdown]
# # How to Grid Search ARIMA Model Hyperparameters with Python

# %% [markdown]
# ### Evaluate ARIMA Model
# we will develop a method to grid search ARIMA hyperparameters for a one-step rolling forecast.
#
# The approach is broken down into two parts:
#
#     Evaluate an ARIMA model.
#     Evaluate sets of ARIMA parameters.
#
#
#     Evaluate ARIMA Model
#
# We can evaluate an ARIMA model by preparing it on a training dataset and evaluating predictions on a test dataset.
#
# This approach involves the following steps:
#
#     Split the dataset into training and test sets.
#     Walk the time steps in the test dataset.
#         Train an ARIMA model.
#         Make a one-step prediction.
#         Store prediction; get and store actual observation.
#     Calculate error score for predictions compared to expected values.

# %%
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	error = mean_squared_error(test, predictions)
	return error

# %% [markdown]
# ## Iterate ARIMA Parameters

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
 
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse
 
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))
 
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = read_csv('shampoo.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# <ipython-input-4-e7e853cbdeb7>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# ARIMA(0, 0, 0) RMSE=228.966
# ARIMA(0, 0, 1) RMSE=195.596
# ARIMA(0, 0, 2) RMSE=154.886
# ARIMA(0, 1, 0) RMSE=133.156
# ARIMA(0, 1, 1) RMSE=104.077
# ARIMA(0, 1, 2) RMSE=68.345
# ARIMA(0, 2, 0) RMSE=255.187
# ARIMA(0, 2, 1) RMSE=134.168
# ARIMA(0, 2, 2) RMSE=74.643
# ARIMA(1, 0, 0) RMSE=152.028
# ARIMA(1, 0, 1) RMSE=111.787
# ARIMA(1, 0, 2) RMSE=77.082
# ARIMA(1, 1, 0) RMSE=88.631
# ARIMA(1, 1, 1) RMSE=87.942
# ARIMA(1, 1, 2) RMSE=90.986
# ARIMA(1, 2, 0) RMSE=134.576
# ARIMA(1, 2, 1) RMSE=86.157
# ARIMA(1, 2, 2) RMSE=65.511
# ARIMA(2, 0, 0) RMSE=100.879
# ARIMA(2, 0, 1) RMSE=98.953
# ARIMA(2, 0, 2) RMSE=98.689
# ARIMA(2, 1, 0) RMSE=85.063
# ARIMA(2, 1, 1) RMSE=88.428
# ARIMA(2, 1, 2) RMSE=83.497
# ARIMA(2, 2, 0) RMSE=97.829
# ARIMA(2, 2, 1) RMSE=76.846
# ARIMA(2, 2, 2) RMSE=80.808
# ARIMA(4, 0, 0) RMSE=100.975
# ARIMA(4, 0, 1) RMSE=101.463
# ARIMA(4, 0, 2) RMSE=97.959
# ARIMA(4, 1, 0) RMSE=95.068
# ARIMA(4, 1, 1) RMSE=84.816
# ARIMA(4, 1, 2) RMSE=84.205
# ARIMA(4, 2, 0) RMSE=85.397
# ARIMA(4, 2, 1) RMSE=74.219
# ARIMA(4, 2, 2) RMSE=70.141
# ARIMA(6, 0, 0) RMSE=95.980
# ARIMA(6, 0, 1) RMSE=85.151
# ARIMA(6, 0, 2) RMSE=93.960
# ARIMA(6, 1, 0) RMSE=84.633
# ARIMA(6, 1, 1) RMSE=78.365
# ARIMA(6, 1, 2) RMSE=73.994
# ARIMA(6, 2, 0) RMSE=77.305
# ARIMA(6, 2, 1) RMSE=77.721
# ARIMA(6, 2, 2) RMSE=82.203
# ARIMA(8, 0, 0) RMSE=88.697
# ARIMA(8, 0, 1) RMSE=95.611
# ARIMA(8, 0, 2) RMSE=100.432
# ARIMA(8, 1, 0) RMSE=79.987
# ARIMA(8, 1, 1) RMSE=79.961
# ARIMA(8, 1, 2) RMSE=74.643
# ARIMA(8, 2, 0) RMSE=81.882
# ARIMA(8, 2, 1) RMSE=83.655
# ARIMA(8, 2, 2) RMSE=90.894
# ARIMA(10, 0, 0) RMSE=91.006
# ARIMA(10, 0, 1) RMSE=91.810
# ARIMA(10, 0, 2) RMSE=97.246
# ARIMA(10, 1, 0) RMSE=84.839
# ARIMA(10, 1, 1) RMSE=84.964
# ARIMA(10, 1, 2) RMSE=77.826
# ARIMA(10, 2, 0) RMSE=84.942
# ARIMA(10, 2, 1) RMSE=75.481
# ARIMA(10, 2, 2) RMSE=74.344
# Best ARIMA(1, 2, 2) RMSE=65.511

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# load dataset
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=8.189
# ARIMA(0, 0, 1) RMSE=7.884
# ARIMA(0, 0, 2) RMSE=7.771
# ARIMA(0, 1, 0) RMSE=9.151
# ARIMA(0, 1, 1) RMSE=7.427
# ARIMA(0, 1, 2) RMSE=7.352
# ARIMA(0, 2, 0) RMSE=15.670
# ARIMA(0, 2, 1) RMSE=9.167
# ARIMA(0, 2, 2) RMSE=7.456
# ARIMA(1, 0, 0) RMSE=7.802
# ARIMA(1, 0, 1) RMSE=7.568
# ARIMA(1, 0, 2) RMSE=7.551
# ARIMA(1, 1, 0) RMSE=8.106
# ARIMA(1, 1, 1) RMSE=7.340
# ARIMA(1, 1, 2) RMSE=7.329
# ARIMA(1, 2, 0) RMSE=11.968
# ARIMA(1, 2, 1) RMSE=8.120
# ARIMA(1, 2, 2) RMSE=7.408
# ARIMA(2, 0, 0) RMSE=7.697
# ARIMA(2, 0, 1) RMSE=7.538
# ARIMA(2, 1, 0) RMSE=7.700
# ARIMA(2, 1, 1) RMSE=7.332
# ARIMA(2, 1, 2) RMSE=7.356
# ARIMA(2, 2, 0) RMSE=10.355
# ARIMA(2, 2, 1) RMSE=7.714
# ARIMA(2, 2, 2) RMSE=16970.884
# ARIMA(4, 0, 0) RMSE=7.693
# ARIMA(4, 0, 1) RMSE=7.506
# ARIMA(4, 0, 2) RMSE=25.660
# ARIMA(4, 1, 0) RMSE=7.565
# ARIMA(4, 1, 1) RMSE=7.396
# ARIMA(4, 2, 0) RMSE=8.940
# ARIMA(4, 2, 1) RMSE=7.576
# ARIMA(6, 0, 0) RMSE=7.666
# ARIMA(6, 1, 0) RMSE=7.281
# ARIMA(6, 1, 1) RMSE=7.340
# ARIMA(6, 1, 2) RMSE=7.433
# ARIMA(6, 2, 0) RMSE=8.337
# ARIMA(6, 2, 1) RMSE=7.292
# ARIMA(8, 0, 0) RMSE=7.549

# %% [markdown]
# ### A Gentle Introduction to the Random Walk for Times Series Forecasting with Python

# %%
from random import seed
from random import randrange
from matplotlib import pyplot
seed(1)
series = [randrange(10) for i in range(1000)]
pyplot.plot(series)
pyplot.show()
