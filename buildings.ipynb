# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv(r'buildings.csv',low_memory=False)

# %%
df1.isnull()
# Out:
#          BUILDING_ID  COUNTY_NUMBER  COUNTY_NAME  CITY_NUMBER  CITY_NAME  \
# 0              False          False        False        False      False
# 1              False          False        False        False      False
# 2              False          False        False        False      False
# 3              False          False        False        False      False
# 4              False          False        False        False      False
# ...              ...            ...          ...          ...        ...
# 5535854        False          False        False        False      False
# 5535855        False          False        False        False      False
# 5535856        False          False        False        False      False
# 5535857        False          False        False        False      False
# 5535858        False          False        False        False      False
#
#          BUILDING_NUMBER  BUILDING_ENR  BUILDING_TYPE_NUMBER  \
# ...

# %%
df1.head()
# Out:
#    BUILDING_ID  COUNTY_NUMBER           COUNTY_NAME  CITY_NUMBER    CITY_NAME  \
# 0     10858657             38  VESTFOLD OG TELEMARK         3812       SILJAN
# 1            0             34             INNLANDET         3401  KONGSVINGER
# 2     10858677             38  VESTFOLD OG TELEMARK         3812       SILJAN
# 3     10862762             38  VESTFOLD OG TELEMARK         3812       SILJAN
# 4     10862774             38  VESTFOLD OG TELEMARK         3812       SILJAN
#
#    BUILDING_NUMBER  BUILDING_ENR  BUILDING_TYPE_NUMBER  \
# 0          8543127             0                 111.0
# 1        300846630             0                 111.0
# 2          8543178             0                 111.0
# 3          8547424             0                 111.0
# 4          8547459             0                 182.0
#
#               BUILDING_TYPE_NAME BUILDING_STATUS_NUMBER  ...  \
# 0                       Enebolig                     TB  ...
# ...

# %%
len(df1['APPROVED_DATE'].unique())
# Out:
# 33343

# %% [markdown]
# ##### df1[df1['HAS_ELEVATOR']==False].count()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5535859 entries, 0 to 5535858
# Data columns (total 35 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   BUILDING_ID                int64
#  1   COUNTY_NUMBER              int64
#  2   COUNTY_NAME                object
#  3   CITY_NUMBER                int64
#  4   CITY_NAME                  object
#  5   BUILDING_NUMBER            int64
#  6   BUILDING_ENR               int64
#  7   BUILDING_TYPE_NUMBER       float64
#  8   BUILDING_TYPE_NAME         object
#  9   BUILDING_STATUS_NUMBER     object
#  10  BUILDING_STATUS_NAME       object
#  11  APPROVED_DATE              int64
#  12  STARTED_DATE               int64
#  13  IN_USE_DATE                int64
#  14  INDUSTRY_GROUP_CODE        object
#  15  INDUSTRY_GROUP_NAME        object
#  16  EXTENSION_CODE             object
#  17  EXTENSION_NAME             object
#  18  WATER_SUPPLY_NUMBER        float64
# ...

# %%
df1.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5535859 entries, 0 to 5535858
# Data columns (total 35 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   BUILDING_ID                bool
#  1   COUNTY_NUMBER              bool
#  2   COUNTY_NAME                bool
#  3   CITY_NUMBER                bool
#  4   CITY_NAME                  bool
#  5   BUILDING_NUMBER            bool
#  6   BUILDING_ENR               bool
#  7   BUILDING_TYPE_NUMBER       bool
#  8   BUILDING_TYPE_NAME         bool
#  9   BUILDING_STATUS_NUMBER     bool
#  10  BUILDING_STATUS_NAME       bool
#  11  APPROVED_DATE              bool
#  12  STARTED_DATE               bool
#  13  IN_USE_DATE                bool
#  14  INDUSTRY_GROUP_CODE        bool
#  15  INDUSTRY_GROUP_NAME        bool
#  16  EXTENSION_CODE             bool
#  17  EXTENSION_NAME             bool
#  18  WATER_SUPPLY_NUMBER        bool
#  19  WATER_SUPPLY_NAME          bool
# ...

# %%
df2.shape

# %%
df1.isnull().sum()
# Out:
# BUILDING_ID                        0
# COUNTY_NUMBER                      0
# COUNTY_NAME                        0
# CITY_NUMBER                        0
# CITY_NAME                          0
# BUILDING_NUMBER                    0
# BUILDING_ENR                       0
# BUILDING_TYPE_NUMBER          694658
# BUILDING_TYPE_NAME            733910
# BUILDING_STATUS_NUMBER             0
# BUILDING_STATUS_NAME               0
# APPROVED_DATE                      0
# STARTED_DATE                       0
# IN_USE_DATE                        0
# INDUSTRY_GROUP_CODE          1045218
# INDUSTRY_GROUP_NAME          1045218
# EXTENSION_CODE               4841207
# EXTENSION_NAME               4842535
# WATER_SUPPLY_NUMBER          4300925
# WATER_SUPPLY_NAME            4300925
# UFS_TOTAL                          0
# UFS_HOME                           0
# UFS_OTHER                          0
# FLOORS                             0
# HOMES                              0
# ...

# %%
df3.isnull().sum()

# %%
df4 = pd.read_csv(r'D:/NMA Valuation/Datasets/properties.csv',low_memory=False)
#df4.head()

# %%
df4.shape

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3865589 entries, 0 to 3865588
# Data columns (total 35 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   PROPERTY_ID                int64
#  1   COUNTY_NUMBER              int64
#  2   COUNTY_NAME                object
#  3   CITY_NUMBER                int64
#  4   CITY_NAME                  object
#  5   GNR                        int64
#  6   UNR                        int64
#  7   LNR                        int64
#  8   SNR                        int64
#  9   USAGE_NAME                 object
#  10  PLOTS                      int64
#  11  AREA                       float64
#  12  AREA_NUMBER                int64
#  13  AREA_SOURCE_NAME           object
#  14  INDUSTRY_CODE              object
#  15  INDUSTRY_CODE_NAME         object
#  16  REGISTERED                 bool
#  17  TRANSACTION_DATE           float64
#  18  PURCHASE_PRICE             float64
# ...

# %%
df4.isnull().sum()

# %%
df=merge_datasets()

# %%
df.head()
# Out:
#    TRANSACTION_ID  TRANSACTION_DATE  PURCHASE_PRICE SOLD_ON_THE_OPEN_MARKET  \
# 0     280222516.0               NaN         15000.0                   False
# 1     280222516.0               NaN         15000.0                   False
# 2     280222516.0               NaN         15000.0                   False
# 3     126433852.0        19490507.0          1800.0                    True
# 4     126454337.0        19600908.0             4.0                    True
#
#    CITY_NUMBER   PROPERTY_ID_NMA  PROPERTY_TYPE_CODE  COUNTY_NUMBER  PLOTS  \
# 0       4601.0  4601-41-1127-0-0                 1.0           46.0    1.0
# 1       4601.0  4601-41-1127-0-0                 1.0           46.0    1.0
# 2       4601.0  4601-41-1127-0-0                 1.0           46.0    1.0
# 3       4601.0  4601-186-231-0-0                 1.0           46.0    1.0
# 4       4601.0  4601-165-563-0-0                 1.0           46.0    1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10011196 entries, 0 to 10011195
# Data columns (total 18 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   TRANSACTION_ID           float64
#  1   TRANSACTION_DATE         float64
#  2   PURCHASE_PRICE           float64
#  3   SOLD_ON_THE_OPEN_MARKET  object
#  4   CITY_NUMBER              float64
#  5   PROPERTY_ID_NMA          object
#  6   PROPERTY_TYPE_CODE       float64
#  7   COUNTY_NUMBER            float64
#  8   PLOTS                    float64
#  9   AREA                     float64
#  10  BUILDINGS                float64
#  11  ADDRESSES                float64
#  12  UFS_TOTAL                float64
#  13  UFS_HOME                 float64
#  14  UFS_OTHER                float64
#  15  FLOORS                   float64
#  16  HOMES                    float64
#  17  BUILT_AREA               float64
# dtypes: float64(16), object(2)
# memory usage: 1.4+ GB

# %%
len(df['CITY_NUMBER'].unique())
# Out:
# 730

# %%
df['PROPERTY_TYPE_CODE'].unique()
# Out:
# array([ 1.,  0.,  2., nan,  3.])

# %%
len(df['COUNTY_NUMBER'].unique())
# Out:
# 19

# %%
df['PLOTS'].unique()
# Out:
# array([1.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 7.000e+00, 6.000e+00,
#        5.000e+00,       nan, 1.300e+01, 1.100e+01, 1.000e+01, 8.000e+00,
#        9.000e+00, 2.600e+01, 1.500e+01, 1.700e+01, 1.900e+01, 4.400e+01,
#        2.500e+01, 3.200e+01, 1.200e+01, 4.200e+01, 2.900e+01, 2.700e+01,
#        2.300e+01, 7.300e+01, 2.100e+01, 2.400e+01, 2.800e+01, 2.200e+01,
#        1.400e+01, 1.600e+01, 3.400e+01, 1.800e+01, 2.000e+01, 3.100e+01,
#        5.400e+01, 1.060e+02, 6.700e+01, 3.300e+01, 6.100e+01, 6.300e+01,
#        6.000e+01, 3.700e+01, 3.900e+01, 9.900e+01, 4.800e+01, 4.900e+01,
#        1.080e+02, 3.000e+01, 3.500e+01, 5.000e+01, 4.100e+01, 4.000e+01,
#        9.600e+01, 3.600e+01, 3.800e+01, 4.500e+01, 7.600e+01, 5.500e+01,
#        7.100e+01, 4.300e+01, 6.400e+01, 7.700e+01, 5.700e+01, 8.200e+01,
#        6.500e+01, 1.510e+02, 1.630e+02, 1.570e+02, 8.900e+01, 5.600e+01,
#        1.610e+02, 2.220e+02, 5.100e+01, 6.200e+01, 4.600e+01, 1.070e+02,
# ...

# %%
df1.isnull().sum()
# Out:
# BUILDING_ID                        0
# COUNTY_NUMBER                      0
# COUNTY_NAME                        0
# CITY_NUMBER                        0
# CITY_NAME                          0
# BUILDING_NUMBER                    0
# BUILDING_ENR                       0
# BUILDING_TYPE_NUMBER          694658
# BUILDING_TYPE_NAME            733910
# BUILDING_STATUS_NUMBER             0
# BUILDING_STATUS_NAME               0
# APPROVED_DATE                      0
# STARTED_DATE                       0
# IN_USE_DATE                        0
# INDUSTRY_GROUP_CODE          1045218
# INDUSTRY_GROUP_NAME          1045218
# EXTENSION_CODE               4841207
# EXTENSION_NAME               4842535
# WATER_SUPPLY_NUMBER          4300925
# WATER_SUPPLY_NAME            4300925
# UFS_TOTAL                          0
# UFS_HOME                           0
# UFS_OTHER                          0
# FLOORS                             0
# HOMES                              0
# ...

# %%
df['FLOORS'].unique()
# Out:
# array([ 2.,  1.,  4.,  5.,  3., nan, 12.,  7.,  6.,  8., 10., 11.,  9.,
#        13., 17., 15., 14., 16., 21., 18., 20., 19.])

# %%
len(df['BUILT_AREA'].unique())
# Out:
# 8661

# %%
corrmat = df.corr()
cmap = sns.diverging_palette(260,-10,s=50, l=75, n=6, as_cmap=True)
plt.subplots(figsize=(15,15))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (10011196, 18)

# %%
df.shape
# Out:
# (5061516, 16)

# %%
corrmat = df.corr()
cmap = sns.diverging_palette(260,-10,s=50, l=75, n=6, as_cmap=True)
plt.subplots(figsize=(15,15))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
# Out:
# <AxesSubplot:>

# %%
df.describe().T
# Out:
#                       count          mean           std          min  \
# TRANSACTION_ID    5061516.0  2.103963e+08  1.450941e+08  126433852.0
# TRANSACTION_DATE  5061508.0  2.004918e+07  8.403525e+04   18921027.0
# PURCHASE_PRICE    5061516.0  2.860606e+06  3.016237e+07          1.0
# CITY_NUMBER       5061516.0  3.418670e+03  1.225516e+03       1001.0
# COUNTY_NUMBER     5061516.0  3.397724e+01  1.227792e+01         10.0
# PLOTS             5061516.0  1.425270e+00  3.394632e+00          1.0
# AREA              5061516.0  3.663706e+05  1.262311e+07          0.0
# BUILDINGS         5061516.0  3.666863e+00  6.036018e+00          0.0
# ADDRESSES         5061516.0  1.322416e+00  3.095495e+00          0.0
# UFS_TOTAL         4644464.0  1.070135e+02  7.601745e+02      -4890.0
# UFS_HOME          4644464.0  6.068287e+01  5.653013e+02      -2066.8
# UFS_OTHER         4644464.0  4.639750e+01  5.115829e+02     -12026.0
# FLOORS            4644464.0  1.485376e+00  7.539813e-01          1.0
# ...

# %%
import pickle
with open('processed_nma.pickle', 'wb') as f:
    pickle.dump(pdf, f)

# %%
pdf.to_csv('D:/NMA Valuation/Datasets/processed.csv', index=False)

# %%
pdf.shape
# Out:
# (2391851, 14)

# %%
corrmat = pdf.corr()
cmap = sns.diverging_palette(260,-10,s=50, l=75, n=6, as_cmap=True)
plt.subplots(figsize=(15,15))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
# Out:
# <AxesSubplot:>
